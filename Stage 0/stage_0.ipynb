# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolLuca/NER_Legal_Domain_RO/blob/main/Stage%200/stage_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA

# %%
TRAIN_DATA2=[("ORDIN nr. 1.615 din 19 noiembrie 2018",{"entities":[(0,37,"LAW")]}),
("19 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("Dolj",{"entities":[(0,4,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("7 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("Legea cadastrului și a publicității imobiliare nr. 7 / 1996",{"entities":[(0,62,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Legea cadastrului și a publicității imobiliare nr. 7 / 1996",{"entities":[(0,62,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Agenției Naționale de Cadastru și Publicitate Imobiliară",{"entities":[(0,60,"ORG")]}),
("Dolj",{"entities":[(0,4,"LOC")]}),
("27 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("01 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Agenției Naționale de Cadastru și Publicitate Imobiliară",{"entities":[(0,60,"ORG")]}),
("Radu-Codruț Ștefănescu",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("19 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("01-02-2019",{"entities":[(0,10,"TIME")]}),
("ORDIN nr. 1.519 din 19 decembrie 2018",{"entities":[(0,37,"LAW")]}),
("19 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Grădiștea - Terasă din județul Călărași,",{"entities":[(0,101,"ORG")]}),
("Călărași",{"entities":[(0,11,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("27 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Referatul de aprobare nr. 293.908 / 2018",{"entities":[(0,40,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Călărași",{"entities":[(0,11,"LOC")]}),
("Organizației utilizatorilor de apă pentru irigații Grădiștea - Terasă din județul Călărași",{"entities":[(0,100,"ORG")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("5 zile",{"entities":[(0,6,"TIME")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("organizația utilizatorilor de apă pentru irigații",{"entities":[(0,52,"ORG")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Dumitru Daniel Botănoiu",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("19 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Grădiștea - Terasă din județul Călărași",{"entities":[(0,100,"ORG")]}),
("Călărași",{"entities":[(0,11,"LOC")]}),
("Ordinul ministrului finanțelor publice nr. 668 / 2014",{"entities":[(0,54,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Agenția Națională de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizația utilizatorilor de apă pentru irigații Grădiștea - Terasă",{"entities":[(0,74,"ORG")]}),
("Grădiștea",{"entities":[(0,11,"LOC")]}),
("S.C. Arfis Impex - S.R.L.",{"entities":[(0,25,"ORG")]}),
("Grădiștea",{"entities":[(0,11,"LOC")]}),
("Călărași",{"entities":[(0,11,"LOC")]}),
("Registrul național al organizațiilor de îmbunătățiri funciare cu nr. 318 din 22.11.2007",{"entities":[(0,93,"LAW")]}),
("22.11.2007",{"entities":[(0,10,"TIME")]}),
("Grădiștea",{"entities":[(0,11,"LOC")]}),
("Brăila",{"entities":[(0,7,"LOC")]}),
("Grădiștea",{"entities":[(0,11,"LOC")]}),
("Brăila",{"entities":[(0,7,"LOC")]}),
("ORDIN nr. 940 / 944 / 650 / 2019",{"entities":[(0,32,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("10 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 50 / 2015",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale pentru Persoanele cu Dizabilități",{"entities":[(0,60,"ORG")]}),
("Hotărârea Guvernului nr. 12 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Muncii și Justiției Sociale",{"entities":[(0,42,"ORG")]}),
("Hotărârea Guvernului nr. 144 / 2010",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Hotărârea Guvernului nr. 972 / 2006",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("12.06.2019",{"entities":[(0,10,"TIME")]}),
("25.06.2019",{"entities":[(0,10,"TIME")]}),
("3.07.2019",{"entities":[(0,9,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("3 aprilie 2019",{"entities":[(0,14,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Mergeani Nicea",{"entities":[(0,14,"PER")]}),
("Sorina Pintea",{"entities":[(0,13,"PER")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Răzvan Teohari Vulcănescu",{"entities":[(0,27,"PER")]}),
("HOTĂRÂRE nr. 26 din 25 ianuarie 2019",{"entities":[(0,38,"LAW")]}),
("25 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Direcția Generală Anticorupție",{"entities":[(0,33,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("30 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 213 / 1998",{"entities":[(0,20,"LAW")]}),
("1998",{"entities":[(0,4,"TIME")]}),
("Legea nr. 287 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Codul civil",{"entities":[(0,11,"LAW")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ministerului Apărării Naționale î",{"entities":[(0,37,"ORG")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Direcția Generală Anticorupție",{"entities":[(0,33,"ORG")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("60 de zile",{"entities":[(0,10,"TIME")]}),
("Ministerul Apărării Naționale",{"entities":[(0,32,"ORG")]}),
("Ministerul Afacerilor Interne",{"entities":[(0,29,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Gabriel-Beniamin Leș",{"entities":[(0,21,"PER")]}),
("Carmen Daniela Dan",{"entities":[(0,18,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("25 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Ordinului ministrului finanțelor publice nr. 1.718 / 2011",{"entities":[(0,58,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Direcția Generală Anticorupție",{"entities":[(0,33,"ORG")]}),
("Ordinului ministrului finanțelor publice nr. 1.718 / 2011",{"entities":[(0,58,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("ORDIN nr. 58 din 17 ianuarie 2019",{"entities":[(0,33,"LAW")]}),
("17 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("2019-2023",{"entities":[(0,9,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("30 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Referatul de aprobare al Direcției generale politici agricole nr. 243.259 din 26.11.2018",{"entities":[(0,89,"LAW")]}),
("Direcției generale politici agricole",{"entities":[(0,37,"ORG")]}),
("26.11.2018",{"entities":[(0,10,"TIME")]}),
("Regulamentului (UE) nr. 1.306 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("17 decembrie 2013",{"entities":[(0,17,"TIME")]}),
("Regulamentelor (CEE) nr. 352 / 78",{"entities":[(0,33,"LAW")]}),
("(CE) nr. 165 / 94",{"entities":[(0,17,"LAW")]}),
("(CE) nr. 2.799 / 98",{"entities":[(0,19,"LAW")]}),
("(CE) nr. 814 / 2000",{"entities":[(0,19,"LAW")]}),
("(CE) nr. 1.290 / 2005",{"entities":[(0,21,"LAW")]}),
("(CE) nr. 485 / 2008",{"entities":[(0,19,"LAW")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Regulamentului (UE) nr. 1.308 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("17 decembrie 2013",{"entities":[(0,17,"TIME")]}),
("Regulamentelor (CEE) nr. 922 / 72",{"entities":[(0,33,"LAW")]}),
("(CEE) nr. 234 / 79",{"entities":[(0,18,"LAW")]}),
("(CE) nr. 1.037 / 2001",{"entities":[(0,21,"LAW")]}),
("(CE) nr. 1.234 / 2007",{"entities":[(0,21,"LAW")]}),
("2001",{"entities":[(0,4,"TIME")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Regulamentului (UE) 2016 / 1.149",{"entities":[(0,32,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Regulamentului (UE) nr. 1.308 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Regulamentului (CE) nr. 555 / 2008",{"entities":[(0,34,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("Regulamentului (UE) 2016 / 1.150",{"entities":[(0,32,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Regulamentului (UE) nr. 1.308 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Regulamentului de punere în aplicare (UE) 2017 / 256",{"entities":[(0,53,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Regulamentului de punere în aplicare (UE) 2016 / 1.150",{"entities":[(0,55,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Regulamentului (UE) nr. 1.308 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Ordonanței de urgență a Guvernului nr. 49 / 2015",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2014-2020",{"entities":[(0,9,"TIME")]}),
("Legea nr. 56 / 2016",{"entities":[(0,19,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("Ordonanței de urgență a Guvernului nr. 66 / 2011",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Legea nr. 142 / 2012",{"entities":[(0,20,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 98 / 2017",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Legea nr. 186 / 2018",{"entities":[(0,20,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 868 / 2018",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("2019-2023",{"entities":[(0,9,"TIME")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("2019-2023",{"entities":[(0,9,"TIME")]}),
("Regulamentului (UE) nr. 1.308 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("17 decembrie 2013",{"entities":[(0,17,"TIME")]}),
("Regulamentelor (CEE) nr. 922 / 72",{"entities":[(0,33,"LAW")]}),
("(CEE) nr. 234 / 79",{"entities":[(0,18,"LAW")]}),
("(CE) nr. 1.037 / 2001",{"entities":[(0,21,"LAW")]}),
("(CE) nr. 1.234 / 2007",{"entities":[(0,21,"LAW")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Petre Daea",{"entities":[(0,10,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("17 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("2019-2023",{"entities":[(0,9,"TIME")]}),
("HOTĂRÂRE nr. 431 din 23 martie 2019",{"entities":[(0,37,"LAW")]}),
("23 martie 2019",{"entities":[(0,14,"TIME")]}),
("Hotărârea Consiliului Uniunii Naționale a Barourilor din România nr. 64 / 2011",{"entities":[(0,82,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Consiliului Uniunii Naționale a Barourilor din România",{"entities":[(0,56,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("12 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Legea nr. 51 / 1995",{"entities":[(0,19,"LAW")]}),
("1995",{"entities":[(0,4,"TIME")]}),
("Hotărârea Congresului Avocaților nr. 5 din 20-21 aprilie 2018",{"entities":[(0,64,"LAW")]}),
("20-21 aprilie 2018",{"entities":[(0,18,"TIME")]}),
("Consiliul Uniunii Naționale a Barourilor din România",{"entities":[(0,54,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("U.N.B.R.",{"entities":[(0,8,"ORG")]}),
("Consiliului U.N.B.R.",{"entities":[(0,20,"ORG")]}),
("Consiliului U.N.B.R.",{"entities":[(0,20,"ORG")]}),
("Consiliului U.N.B.R.",{"entities":[(0,20,"ORG")]}),
("Hotărârii Consiliului Uniunii Naționale a Barourilor din România nr. 428 / 2018",{"entities":[(0,83,"LAW")]}),
("Consiliului Uniunii Naționale a Barourilor din România",{"entities":[(0,56,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Hotărârea Consiliului Uniunii Naționale a Barourilor din România nr. 64 / 2011",{"entities":[(0,82,"LAW")]}),
("Consiliului Uniunii Naționale a Barourilor din România",{"entities":[(0,56,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("U.N.B.R.",{"entities":[(0,8,"ORG")]}),
("Hotărârea Înaltei Curți de Casație și Justiție nr. 2.188 din 24.05.2018",{"entities":[(0,78,"LAW")]}),
("Înaltei Curți de Casație și Justiție",{"entities":[(0,41,"ORG")]}),
("24.05.2018",{"entities":[(0,10,"TIME")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Sentinței nr. 234 / F-Cont din 29.11.2016 a Curții de Apel Argeș",{"entities":[(0,67,"LAW")]}),
("29.11.2016",{"entities":[(0,10,"TIME")]}),
("Argeș",{"entities":[(0,6,"LOC")]}),
("Curții de Apel Argeș",{"entities":[(0,22,"ORG")]}),
("U.N.B.R.",{"entities":[(0,8,"ORG")]}),
("Consiliului U.N.B.R.",{"entities":[(0,20,"ORG")]}),
("Consiliului U.N.B.R.",{"entities":[(0,20,"ORG")]}),
("Cluj",{"entities":[(0,4,"LOC")]}),
("Hotărârea Consiliului Uniunii Naționale a Barourilor din România nr. 64 / 2011",{"entities":[(0,82,"LAW")]}),
("Consiliului Uniunii Naționale a Barourilor din România",{"entities":[(0,56,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Consiliul Uniunii Naționale a Barourilor din România",{"entities":[(0,54,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("23 martie 2019",{"entities":[(0,14,"TIME")]}),
("Hotărârea Consiliului Uniunii Naționale a Barourilor din România nr. 64 / 2011",{"entities":[(0,82,"LAW")]}),
("Consiliului Uniunii Naționale a Barourilor din România",{"entities":[(0,56,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"TIME")]}),
("19 decembrie 2011",{"entities":[(0,17,"TIME")]}),
("U.N.B.R.",{"entities":[(0,8,"ORG")]}),
("Hotărârea Consiliului Uniunii Naționale a Barourilor din România nr. 64 / 2011",{"entities":[(0,82,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Consiliului Uniunii Naționale a Barourilor din România",{"entities":[(0,56,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Gheorghe Florea",{"entities":[(0,15,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("23 martie 2019",{"entities":[(0,14,"TIME")]}),
("HOTĂRÂRE nr. 1.028 din 21 decembrie 2018",{"entities":[(0,42,"LAW")]}),
("21 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Mediaș",{"entities":[(0,7,"LOC")]}),
("Sibiu",{"entities":[(0,5,"LOC")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("3 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 213 / 1998",{"entities":[(0,20,"LAW")]}),
("1998",{"entities":[(0,4,"TIME")]}),
("Legea nr. 287 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Codul civil",{"entities":[(0,11,"LAW")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Mediaș",{"entities":[(0,7,"LOC")]}),
("Sibiu",{"entities":[(0,5,"LOC")]}),
("Școala Gimnazială  Mihai Eminescu  Mediaș",{"entities":[(0,44,"ORG")]}),
("Mediaș",{"entities":[(0,7,"LOC")]}),
("Consiliului Local al Municipiului Mediaș",{"entities":[(0,41,"ORG")]}),
("Mediaș",{"entities":[(0,7,"LOC")]}),
("Hotărârii Consiliului Local al Municipiului Mediaș nr. 312 / 2016",{"entities":[(0,68,"LAW")]}),
("Consiliului Local al Municipiului Mediaș",{"entities":[(0,41,"ORG")]}),
("Mediaș",{"entities":[(0,7,"LOC")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Hotărârea Consiliului Local al Municipiului Mediaș nr. 206 / 2017",{"entities":[(0,68,"LAW")]}),
("Consiliului Local al Municipiului Mediaș",{"entities":[(0,41,"ORG")]}),
("Mediaș",{"entities":[(0,7,"LOC")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("60 de zile",{"entities":[(0,10,"TIME")]}),
("Ministerul Apărării Naționale",{"entities":[(0,32,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Nicolae Nasta",{"entities":[(0,13,"PER")]}),
("Sirma Caraman",{"entities":[(0,13,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("21 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("ORDIN nr. 275 din 28 februarie 2019",{"entities":[(0,35,"LAW")]}),
("28 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Ordinul ministrului sănătății nr. 1.468 / 2018",{"entities":[(0,50,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("28 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Referatul de aprobare nr. SP 2.811 / 2019",{"entities":[(0,41,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Ordinului ministrului sănătății nr. 368 / 2017",{"entities":[(0,50,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 144 / 2010",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Ordinul ministrului sănătății nr. 1.468 / 2018",{"entities":[(0,50,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("22 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Sorina Pintea",{"entities":[(0,13,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("28 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Ordinul ministrului sănătății nr. 1.468 / 2018",{"entities":[(0,50,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("MERUS LABS LUXCO II S.A.R.L.",{"entities":[(0,28,"ORG")]}),
("MERCK SHARP & DOHME B.V.",{"entities":[(0,24,"ORG")]}),
("MERCK SHARP & DOHME B.V.",{"entities":[(0,24,"ORG")]}),
("1.01.2020",{"entities":[(0,9,"TIME")]}),
("ORDIN nr. 128 din 31 ianuarie 2019",{"entities":[(0,34,"LAW")]}),
("31 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Ordinul președintelui Agenției Naționale pentru Resurse Minerale nr. 139 / 2010",{"entities":[(0,82,"LAW")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("8 februarie 2019",{"entities":[(0,16,"TIME")]}),
("Referatul de aprobare înregistrat la Direcția generală gestionare, evaluare și concesionare, resurse / rezerve petroliere cu nr. 200.034 din 23.01.2019",{"entities":[(0,155,"LAW")]}),
("Direcția generală gestionare, evaluare și concesionare, resurse / rezerve petroliere",{"entities":[(0,87,"ORG")]}),
("23.01.2019",{"entities":[(0,10,"TIME")]}),
("Hotărârea Guvernului nr. 1.419 / 2009",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Ordinul președintelui Agenției Naționale pentru Resurse Minerale nr. 139 / 2010",{"entities":[(0,82,"LAW")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("4 octombrie 2010",{"entities":[(0,16,"TIME")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("10 ani",{"entities":[(0,6,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Gigi Dragomir",{"entities":[(0,13,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("31 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("10-20 de ani",{"entities":[(0,12,"TIME")]}),
("20-40 de ani",{"entities":[(0,12,"TIME")]}),
("10 ani",{"entities":[(0,6,"TIME")]}),
("40 de ani",{"entities":[(0,9,"TIME")]}),
("DECIZIE nr. 848 din 1 octombrie 2019",{"entities":[(0,36,"LAW")]}),
("1 octombrie 2019",{"entities":[(0,16,"TIME")]}),
("Deciziei Consiliului Național al Audiovizualului nr. 781 / 2019",{"entities":[(0,64,"LAW")]}),
("Consiliului Național al Audiovizualului",{"entities":[(0,40,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("4 octombrie 2019",{"entities":[(0,16,"TIME")]}),
("Consiliului Național al Audiovizualului",{"entities":[(0,40,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 64 / 2019",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Legii nr. 370 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legii nr. 208 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Senatului",{"entities":[(0,9,"ORG")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("Autorității Electorale Permanente",{"entities":[(0,35,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("12 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Legea nr. 370 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Hotărârii Guvernului nr. 630 / 2019",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("Legea audiovizualului nr. 504 / 2002",{"entities":[(0,36,"LAW")]}),
("2002",{"entities":[(0,4,"TIME")]}),
("Consiliul Național al Audiovizualului",{"entities":[(0,38,"ORG")]}),
("Decizia Consiliului Național al Audiovizualului nr. 781 / 2019",{"entities":[(0,63,"LAW")]}),
("Consiliului Național al Audiovizualului",{"entities":[(0,40,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("6 septembrie 2019",{"entities":[(0,17,"TIME")]}),
("Legea nr. 370 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 370 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 334 / 2006",{"entities":[(0,20,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Consiliului Național al Audiovizualului",{"entities":[(0,40,"ORG")]}),
("Maria Monica Gubernat",{"entities":[(0,21,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("1 octombrie 2019",{"entities":[(0,16,"TIME")]}),
("Decizia nr. 781 / 2019",{"entities":[(0,22,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Consiliul Național al Audiovizualului",{"entities":[(0,38,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Bd. Libertății nr. 14",{"entities":[(0,23,"LOC")]}),
("sectorul 5",{"entities":[(0,10,"LOC")]}),
("Deciziei Consiliului Național al Audiovizualului nr. 781 / 2019",{"entities":[(0,64,"LAW")]}),
("Consiliului Național al Audiovizualului",{"entities":[(0,40,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Consiliului Național al Audiovizualului",{"entities":[(0,40,"ORG")]}),
("LEGE nr. 238 din 18 decembrie 2019",{"entities":[(0,34,"LAW")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("18 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("19 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("Parlamentul României",{"entities":[(0,21,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea responsabilității fiscal-bugetare nr. 69 / 2010",{"entities":[(0,55,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("anul 2021",{"entities":[(0,9,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("anul 2021",{"entities":[(0,9,"TIME")]}),
("anului 2020",{"entities":[(0,11,"TIME")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("Guvern",{"entities":[(0,6,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Uniunea Europeană",{"entities":[(0,18,"ORG")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("Legea nr. 69 / 2010",{"entities":[(0,19,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("Legea nr. 69 / 2010",{"entities":[(0,19,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("Legea nr. 69 / 2010",{"entities":[(0,19,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("Legea nr. 69 / 2010",{"entities":[(0,19,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("Legii nr. 69 / 2010",{"entities":[(0,19,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("Senatului",{"entities":[(0,9,"ORG")]}),
("12 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("ION-MARCEL CIOLACU",{"entities":[(0,18,"PER")]}),
("CAMEREI DEPUTAȚILOR",{"entities":[(0,20,"ORG")]}),
("SENATULUI",{"entities":[(0,9,"ORG")]}),
("TEODOR-VIOREL MELEȘCANU",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("18 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("ORDIN nr. 1.439 din 7 octombrie 2019",{"entities":[(0,36,"LAW")]}),
("7 octombrie 2019",{"entities":[(0,16,"TIME")]}),
("Ordinului ministrului pentru mediul de afaceri, comerț și antreprenoriat nr. 1.229 / 2019",{"entities":[(0,91,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("14 octombrie 2019",{"entities":[(0,17,"TIME")]}),
("Legii bugetului de stat pe anul 2019 nr. 50 / 2019",{"entities":[(0,50,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("Legea nr. 346 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Referatul de aprobare nr. 94.310 / DAPIMM din 18 septembrie 2019",{"entities":[(0,64,"LAW")]}),
("18 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Hotărârea Guvernului nr. 23 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului pentru Mediul de Afaceri, Comerț și Antreprenoriat",{"entities":[(0,65,"ORG")]}),
("Ordinul ministrului pentru mediul de afaceri, comerț și antreprenoriat nr. 1.229 / 2019",{"entities":[(0,89,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("19 august 2019",{"entities":[(0,14,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("AIMMAIPE",{"entities":[(0,8,"ORG")]}),
("3 zile",{"entities":[(0,6,"TIME")]}),
("AIMMAIPE",{"entities":[(0,8,"ORG")]}),
("AIMMAIPE",{"entities":[(0,8,"ORG")]}),
("UNCTAD",{"entities":[(0,6,"ORG")]}),
("UNCTAD",{"entities":[(0,6,"ORG")]}),
("Legii contenciosului administrativ nr. 554 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("UNCTAD",{"entities":[(0,6,"ORG")]}),
("AIMMAIPE",{"entities":[(0,8,"ORG")]}),
("10 zile",{"entities":[(0,7,"TIME")]}),
("Ministerului pentru Mediul de Afaceri, Comerț și Antreprenoriat",{"entities":[(0,65,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ștefan-Radu Oprea",{"entities":[(0,18,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("7 octombrie 2019",{"entities":[(0,16,"TIME")]}),
("REZOLUȚIE MSC.441(99) din 24 mai 2018",{"entities":[(0,38,"LAW")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("26 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("ORDINUL nr. 1.264 din 12 septembrie 2019",{"entities":[(0,40,"LAW")]}),
("12 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("26 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Organizației Maritime Internaționale",{"entities":[(0,38,"ORG")]}),
("Comitetului",{"entities":[(0,11,"ORG")]}),
("Rezoluția MSC.5(48)",{"entities":[(0,20,"LAW")]}),
("1974",{"entities":[(0,4,"TIME")]}),
("1 iulie 2019",{"entities":[(0,12,"TIME")]}),
("1 ianuarie 2020",{"entities":[(0,15,"TIME")]}),
("Rezoluția MSC.441(99)",{"entities":[(0,22,"LAW")]}),
("DECIZIE nr. 2 / 2CN din 19 ianuarie 2019",{"entities":[(0,40,"LAW")]}),
("19 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Decizia Consiliului național al Colegiului Medicilor Dentiști din România nr. 10 / 2007",{"entities":[(0,90,"LAW")]}),
("Consiliului național al Colegiului Medicilor Dentiști",{"entities":[(0,55,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("10 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Consiliul național al Colegiului Medicilor Dentiști",{"entities":[(0,53,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Decizia Consiliului național al Colegiului Medicilor Dentiști din România nr. 10 / 2007",{"entities":[(0,90,"LAW")]}),
("Consiliului național al Colegiului Medicilor Dentiști",{"entities":[(0,55,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("18 decembrie 2007",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Colegiului Medicilor Dentiști",{"entities":[(0,30,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ecaterina Ionescu",{"entities":[(0,17,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("19 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Decizia nr. 10 / 2007",{"entities":[(0,21,"LAW")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("5 min",{"entities":[(0,5,"TIME")]}),
("10-15 minute",{"entities":[(0,12,"TIME")]}),
("10-15 minute",{"entities":[(0,12,"TIME")]}),
("ORDIN nr. 869 din 27 decembrie 2018",{"entities":[(0,35,"LAW")]}),
("27 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Legii nr. 85 / 2018",{"entities":[(0,19,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("17 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Legea nr. 85 / 2018",{"entities":[(0,19,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 980 / 2015",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ministerului Energiei",{"entities":[(0,21,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Anton Anton",{"entities":[(0,11,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("27 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("HOTĂRÂRE nr. 36 din 9 octombrie 2019",{"entities":[(0,38,"LAW")]}),
("9 octombrie 2019",{"entities":[(0,16,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("10 octombrie 2019",{"entities":[(0,17,"TIME")]}),
("Legea nr. 370 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Legea nr. 115 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Legii administrației publice locale nr. 215 / 2001",{"entities":[(0,51,"LAW")]}),
("2001",{"entities":[(0,4,"TIME")]}),
("Legii nr. 393 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Legea nr. 208 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("Autorității Electorale Permanente",{"entities":[(0,35,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 64 / 2019",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Legii nr. 370 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legii nr. 208 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Senatului",{"entities":[(0,9,"ORG")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("Autorității Electorale Permanente",{"entities":[(0,35,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Legea nr. 115 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Legea nr. 208 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Autoritatea Electorală Permanentă",{"entities":[(0,35,"ORG")]}),
("Hotărârea Autorității Electorale Permanente nr. 9 / 2015",{"entities":[(0,60,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Autorității Electorale Permanente",{"entities":[(0,35,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("2 noiembrie 2015",{"entities":[(0,16,"TIME")]}),
("Hotărârea Autorității Electorale Permanente nr. 11 / 2019",{"entities":[(0,61,"LAW")]}),
("Autorității Electorale Permanente",{"entities":[(0,35,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Parlamentul European",{"entities":[(0,20,"ORG")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("23 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Autorității Electorale Permanente",{"entities":[(0,35,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Hotărârea Autorității Electorale Permanente nr. 12 / 2019",{"entities":[(0,61,"LAW")]}),
("26 mai 2019,",{"entities":[(0,12,"TIME")]}),
("Hotărârii Autorității Electorale Permanente nr. 11 / 2019",{"entities":[(0,61,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Autorității Electorale Permanente",{"entities":[(0,35,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Parlamentul European",{"entities":[(0,20,"ORG")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("10 mai 2019",{"entities":[(0,11,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Autorității Electorale Permanente",{"entities":[(0,35,"ORG")]}),
("Constantin-Florin Mitulețu-Buică",{"entities":[(0,34,"PER")]}),
("Marian Muhuleț",{"entities":[(0,15,"PER")]}),
("Zsombor Vajda",{"entities":[(0,13,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("9 octombrie 2019",{"entities":[(0,16,"TIME")]}),
("ORDIN nr. 21 din 21 ianuarie 2020",{"entities":[(0,33,"LAW")]}),
("21 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("29 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("Referatul de aprobare nr. 387.868 / 30.12.2019",{"entities":[(0,46,"LAW")]}),
("30.12.2019",{"entities":[(0,10,"TIME")]}),
("Direcției generale buget finanțe si fonduri europene",{"entities":[(0,54,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 79 / 2009",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Legea nr. 373 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 79 / 2009",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 1.262 / 2009",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Legii nr. 218 / 2005",{"entities":[(0,20,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 876 / 2005",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("Legii nr. 218 / 2005",{"entities":[(0,20,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("Ministerul Agriculturii și Dezvoltării Rurale",{"entities":[(0,47,"ORG")]}),
("31 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("Legea nr. 218 / 2005",{"entities":[(0,20,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 79 / 2009",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Legea nr. 373 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Agenției pentru Finanțarea Investițiilor Rurale",{"entities":[(0,50,"ORG")]}),
("Ordonanței de urgență a Guvernului nr. 79 / 2009",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Legea nr. 373 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("2020",{"entities":[(0,4,"TIME")]}),
("Agenția pentru Finanțarea Investițiilor Rurale",{"entities":[(0,49,"ORG")]}),
("2007-2013",{"entities":[(0,9,"TIME")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("2020",{"entities":[(0,4,"TIME")]}),
("31 decembrie 2015",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Nechita-Adrian Oros",{"entities":[(0,19,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("21 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("DECIZIE nr. 957 din 24 iulie 2019",{"entities":[(0,33,"LAW")]}),
("24 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Societății MAKLER - SIG BROKER DE ASIGURARE - S.R.L.",{"entities":[(0,54,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("8 august 2019",{"entities":[(0,13,"TIME")]}),
("Autoritatea de Supraveghere Financiară",{"entities":[(0,39,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Splaiul Independenței nr. 15",{"entities":[(0,29,"LOC")]}),
("sectorul 5",{"entities":[(0,10,"LOC")]}),
("Ordonanța de urgență a Guvernului nr. 93 / 2012",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Autorității de Supraveghere Financiară",{"entities":[(0,41,"ORG")]}),
("Legea nr. 113 / 2013",{"entities":[(0,20,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 93 / 2012",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Legea nr. 113 / 2013",{"entities":[(0,20,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Legea nr. 236 / 2018",{"entities":[(0,20,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Autorității de Supraveghere Financiară",{"entities":[(0,41,"ORG")]}),
("Norma Autorității de Supraveghere Financiară nr. 19 / 2018",{"entities":[(0,61,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("18.07.2019",{"entities":[(0,10,"TIME")]}),
("Autorității de Supraveghere Financiară",{"entities":[(0,41,"ORG")]}),
("5.07.2019",{"entities":[(0,9,"TIME")]}),
("Societatea MAKLER - SIG BROKER DE ASIGURARE - S.R.L.",{"entities":[(0,52,"ORG")]}),
("Odorheiu Secuiesc",{"entities":[(0,17,"LOC")]}),
("strada Rakoczi Ferencz nr. 12",{"entities":[(0,29,"LOC")]}),
("Harghita",{"entities":[(0,8,"LOC")]}),
("Oficiul Național al Registrului Comerțului",{"entities":[(0,44,"ORG")]}),
("13.02.1998",{"entities":[(0,10,"TIME")]}),
("10.04.2003",{"entities":[(0,10,"TIME")]}),
("Koffol Alfred",{"entities":[(0,13,"PER")]}),
("Societatea MAKLER-SIG Broker de asigurare - S.R.L.",{"entities":[(0,50,"ORG")]}),
("1.04.2019",{"entities":[(0,9,"TIME")]}),
("Autorității de Supraveghere Financiară",{"entities":[(0,41,"ORG")]}),
("Societății MAKLER - SIG BROKER DE ASIGURARE - S.R.L",{"entities":[(0,53,"ORG")]}),
("Autoritatea de Supraveghere Financiară",{"entities":[(0,39,"ORG")]}),
("Norma Autorității de Supraveghere Financiară nr. 19 / 2018",{"entities":[(0,61,"LAW")]}),
("Autorității de Supraveghere Financiară",{"entities":[(0,41,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Societatea MAKLER - SIG BROKER DE ASIGURARE - S.R.L.",{"entities":[(0,52,"ORG")]}),
("Societatea MAKLER - SIG BROKER DE ASIGURARE - S.R.L.",{"entities":[(0,52,"ORG")]}),
("Societatea MAKLER - SIG BROKER DE ASIGURARE - S.R.L.",{"entities":[(0,52,"ORG")]}),
("Societatea MAKLER - SIG BROKER DE ASIGURARE - S.R.L.",{"entities":[(0,52,"ORG")]}),
("Autoritatea de Supraveghere Financiară",{"entities":[(0,39,"ORG")]}),
("Societatea MAKLER - SIG BROKER DE ASIGURARE - S.R.L.",{"entities":[(0,52,"ORG")]}),
("Autoritatea de Supraveghere Financiară",{"entities":[(0,39,"ORG")]}),
("Autoritatea de Supraveghere Financiară",{"entities":[(0,39,"ORG")]}),
("Societății MAKLER - SIG BROKER DE ASIGURARE - S.R.L",{"entities":[(0,53,"ORG")]}),
("Odorheiu Secuiesc",{"entities":[(0,17,"LOC")]}),
("strada Rakoczi Ferencz nr. 12",{"entities":[(0,29,"LOC")]}),
("Harghita",{"entities":[(0,8,"LOC")]}),
("Oficiul Național al Registrului Comerțului",{"entities":[(0,44,"ORG")]}),
("13.02.1998",{"entities":[(0,10,"TIME")]}),
("10.04.2003",{"entities":[(0,10,"TIME")]}),
("Koffol Alfred",{"entities":[(0,13,"PER")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Autorității de Supraveghere Financiară",{"entities":[(0,41,"ORG")]}),
("Leonardo Badea",{"entities":[(0,14,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("24 iulie 2019",{"entities":[(0,13,"TIME")]}),
("ORDIN nr. 1.491 / 2.534 / 2018",{"entities":[(0,30,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului sănătății și al ministrului muncii, familiei, protecției sociale și persoanelor vârstnice nr. 1.306 / 1.883 / 2016",{"entities":[(0,142,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("20 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Referatul de aprobare al Secretariatului general al Ministerului Sănătății nr. S.P. 14.210 din 23.11.2018",{"entities":[(0,109,"LAW")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("23.11.2018",{"entities":[(0,10,"TIME")]}),
("Ministerului Muncii și Justiției Sociale",{"entities":[(0,42,"ORG")]}),
("11.12.2018",{"entities":[(0,10,"TIME")]}),
("Legii nr. 18 / 1990",{"entities":[(0,19,"LAW")]}),
("1990",{"entities":[(0,4,"TIME")]}),
("Legii nr. 221 / 2010",{"entities":[(0,20,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("New York",{"entities":[(0,8,"LOC")]}),
("Organizației Națiunilor Unite",{"entities":[(0,31,"ORG")]}),
("13 decembrie 2006",{"entities":[(0,17,"TIME")]}),
("30 martie 2007",{"entities":[(0,14,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("26 septembrie 2007",{"entities":[(0,18,"TIME")]}),
("Organizația Mondială a Sănătății",{"entities":[(0,38,"ORG")]}),
("anul 2007",{"entities":[(0,9,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("Ministerul Educației, Cercetării, Tineretului și Sportului",{"entities":[(0,61,"ORG")]}),
("Ministerul Muncii, Familiei, Protecției Sociale și Persoanelor Vârstnice",{"entities":[(0,75,"ORG")]}),
("Hotărârea Guvernului nr. 144 / 2010",{"entities":[(0,37,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Hotărârea Guvernului nr. 12 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Muncii și Justiției Sociale",{"entities":[(0,42,"ORG")]}),
("Ordinul ministrului sănătății și al ministrului muncii, familiei, protecției sociale și persoanelor vârstnice nr. 1.306 / 1.883 / 2016",{"entities":[(0,142,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("9 decembrie 2016",{"entities":[(0,16,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Sorina Pintea",{"entities":[(0,13,"PER")]}),
("Marius-Costantin Budăi",{"entities":[(0,23,"PER")]}),
("ORDIN nr. 3.695 din 29 noiembrie 2018",{"entities":[(0,37,"LAW")]}),
("29 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("Casa de Economii și Consemnațiuni C.E.C. - S.A.",{"entities":[(0,49,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("17 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Hotărârea Guvernului nr. 34 / 2009",{"entities":[(0,36,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Ministerului Finanțelor Publice",{"entities":[(0,32,"ORG")]}),
("Ordonanței de urgență a Guvernului nr. 64 / 2007",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Legea nr. 109 / 2008",{"entities":[(0,20,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 64 / 2007",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 1.470 / 2007",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Legii nr. 9 / 2014",{"entities":[(0,18,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 156 / 2007",{"entities":[(0,52,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Casa de Economii și Consemnațiuni C.E.C. - S.A.",{"entities":[(0,49,"ORG")]}),
("Hotărârii Guvernului nr. 392 / 2014",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Casa de Economii și Consemnațiuni C.E.C. - S.A.",{"entities":[(0,49,"ORG")]}),
("29.11.2018",{"entities":[(0,10,"TIME")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("B.R.D. Groupe Société Générale - S.A.",{"entities":[(0,41,"ORG")]}),
("Casa de Economii și Consemnațiuni C.E.C. - S.A.",{"entities":[(0,49,"ORG")]}),
("B.R.D. Groupe Société Générale - S.A.",{"entities":[(0,41,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("29 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("Casa de Economii și Consemnațiuni C.E.C. - S.A.",{"entities":[(0,49,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("B.R.D. Groupe Société Générale - S.A.",{"entities":[(0,41,"ORG")]}),
("20 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("22 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("1 ianuarie 1990",{"entities":[(0,15,"TIME")]}),
("31 decembrie 2013",{"entities":[(0,17,"TIME")]}),
("Casa de Economii și Consemnațiuni C.E.C. - S.A.",{"entities":[(0,49,"ORG")]}),
("1 ianuarie 1990",{"entities":[(0,15,"TIME")]}),
("Hotărârea Guvernului nr. 392 / 2014",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Casa de Economii și Consemnațiuni C.E.C. - S.A.",{"entities":[(0,49,"ORG")]}),
("22 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("B.R.D. Groupe Société Générale - S.A.",{"entities":[(0,41,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("B.R.D. Groupe Société Générale - S.A.",{"entities":[(0,41,"ORG")]}),
("ORDIN nr. 551 din 4 decembrie 2018",{"entities":[(0,34,"LAW")]}),
("4 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("Ordinul președintelui Autorității Naționale pentru Protecția Consumatorilor nr. 103 / 2010",{"entities":[(0,95,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("27 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Hotărârea Guvernului nr. 700 / 2012",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale pentru Protecția Consumatorilor",{"entities":[(0,57,"ORG")]}),
("Ordonanței Guvernului nr. 2 / 2001",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2001",{"entities":[(0,4,"TIME")]}),
("Legea nr. 180 / 2002",{"entities":[(0,20,"LAW")]}),
("2002",{"entities":[(0,4,"TIME")]}),
("Ordinul președintelui Autorității Naționale pentru Protecția Consumatorilor nr. 103 / 2010",{"entities":[(0,95,"LAW")]}),
("Autorității Naționale pentru Protecția Consumatorilor",{"entities":[(0,57,"ORG")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Autoritatea Națională pentru Protecția Consumatorilor",{"entities":[(0,56,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("27 aprilie 2010",{"entities":[(0,15,"TIME")]}),
("Ordinul președintelui Autorității Naționale pentru Protecția Consumatorilor nr. 211 / 2014",{"entities":[(0,95,"LAW")]}),
("Autorității Naționale pentru Protecția Consumatorilor",{"entities":[(0,57,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Ordinul președintelui Autorității Naționale pentru Protecția Consumatorilor nr. 103 / 2010",{"entities":[(0,95,"LAW")]}),
("Autorității Naționale pentru Protecția Consumatorilor",{"entities":[(0,57,"ORG")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Autoritatea Națională pentru Protecția Consumatorilor",{"entities":[(0,56,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("6 iunie 2014",{"entities":[(0,12,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Autorității Naționale pentru Protecția Consumatorilor",{"entities":[(0,57,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("4 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("Ordinul nr. 103 / 2010",{"entities":[(0,22,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Ordinul nr. 103 / 2010",{"entities":[(0,22,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Autoritatea Națională pentru Protecția Consumatorilor",{"entities":[(0,56,"ORG")]}),
("ORDIN nr. 303 din 15 mai 2019",{"entities":[(0,29,"LAW")]}),
("15 mai 2019",{"entities":[(0,11,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Leu Nord 74 din județul Dolj",{"entities":[(0,83,"ORG")]}),
("Dolj",{"entities":[(0,4,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("16 mai 2019",{"entities":[(0,11,"TIME")]}),
("Referatul de aprobare nr. 302.606 / 2019",{"entities":[(0,40,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Direcției îmbunătățiri funciare și fond funciar",{"entities":[(0,53,"ORG")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,84,"ORG")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Leu Nord 74 din județul Dolj",{"entities":[(0,83,"ORG")]}),
("Dolj",{"entities":[(0,4,"LOC")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("5 zile",{"entities":[(0,6,"TIME")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"ORG")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Dumitru Daniel Botănoiu",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("15 mai 2019",{"entities":[(0,11,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Leu Nord 74 din județul Dolj",{"entities":[(0,83,"ORG")]}),
("Dolj",{"entities":[(0,4,"LOC")]}),
("Ordinul ministrului finanțelor publice și al ministrului delegat pentru buget nr. 668 / 2014",{"entities":[(0,94,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Agenția Națională de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizația utilizatorilor de apă pentru irigații Leu Nord 74",{"entities":[(0,64,"ORG")]}),
("Cârcea",{"entities":[(0,7,"LOC")]}),
("str. Tudor Vladimirescu nr. 16",{"entities":[(0,30,"LOC")]}),
("Dolj",{"entities":[(0,4,"LOC")]}),
("Registrul național al organizațiilor de îmbunătățiri funciare cu nr. 612 din 6.12.2018",{"entities":[(0,92,"LAW")]}),
("6.12.2018",{"entities":[(0,9,"TIME")]}),
("ORDIN nr. 664 din 7 februarie 2019",{"entities":[(0,34,"LAW")]}),
("7 februarie 2019",{"entities":[(0,16,"TIME")]}),
("Mureș",{"entities":[(0,6,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("26 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Legea cadastrului și a publicității imobiliare nr. 7 / 1996",{"entities":[(0,62,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Legea cadastrului și a publicității imobiliare nr. 7 / 1996",{"entities":[(0,62,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Agenției Naționale de Cadastru și Publicitate Imobiliară",{"entities":[(0,60,"ORG")]}),
("Mureș",{"entities":[(0,6,"LOC")]}),
("Apold",{"entities":[(0,5,"LOC")]}),
("Acățari",{"entities":[(0,9,"LOC")]}),
("Ațintiș",{"entities":[(0,9,"LOC")]}),
("Band",{"entities":[(0,4,"LOC")]}),
("Batoș",{"entities":[(0,6,"LOC")]}),
("Crăciunești",{"entities":[(0,13,"LOC")]}),
("Daneș",{"entities":[(0,6,"LOC")]}),
("Fântânele",{"entities":[(0,11,"LOC")]}),
("Gănești",{"entities":[(0,9,"LOC")]}),
("Gornești",{"entities":[(0,9,"LOC")]}),
("Hodac",{"entities":[(0,5,"LOC")]}),
("Iernut",{"entities":[(0,6,"LOC")]}),
("Luduș",{"entities":[(0,6,"LOC")]}),
("Mădăraș",{"entities":[(0,10,"LOC")]}),
("Miercurea Nirajului",{"entities":[(0,19,"LOC")]}),
("Pănet",{"entities":[(0,6,"LOC")]}),
("Râciu",{"entities":[(0,6,"LOC")]}),
("Rușii-Munți",{"entities":[(0,13,"LOC")]}),
("Sângeorgiu de Pădure",{"entities":[(0,22,"LOC")]}),
("Sânger",{"entities":[(0,7,"LOC")]}),
("Șăulia",{"entities":[(0,8,"LOC")]}),
("Șincai",{"entities":[(0,7,"LOC")]}),
("Vărgata",{"entities":[(0,8,"LOC")]}),
("Vânători",{"entities":[(0,10,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Agenției Naționale de Cadastru și Publicitate Imobiliară",{"entities":[(0,60,"ORG")]}),
("Vasile Marcel Grigore",{"entities":[(0,21,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("7 februarie 2019",{"entities":[(0,16,"TIME")]}),
("ORDIN nr. 618 din 8 aprilie 2019",{"entities":[(0,32,"LAW")]}),
("8 aprilie 2019",{"entities":[(0,14,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("19 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Hotărârea Guvernului nr. 16 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Afacerilor Externe",{"entities":[(0,31,"ORG")]}),
("Legea nr. 590 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("21 mai 2019",{"entities":[(0,11,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Varșovia",{"entities":[(0,9,"LOC")]}),
("23 iunie 1994",{"entities":[(0,13,"TIME")]}),
("Legea nr. 109 / 1994",{"entities":[(0,20,"LAW")]}),
("1994",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("2 decembrie 1994",{"entities":[(0,16,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Varșovia",{"entities":[(0,9,"LOC")]}),
("23 iunie 1994",{"entities":[(0,13,"TIME")]}),
("București",{"entities":[(0,10,"LOC")]}),
("14 martie 2018",{"entities":[(0,14,"TIME")]}),
("București",{"entities":[(0,10,"LOC")]}),
("18 iunie 2018",{"entities":[(0,13,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Teodor-Viorel Meleșcanu",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("8 aprilie 2019",{"entities":[(0,14,"TIME")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ambasada Republicii Polonia la București",{"entities":[(0,41,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Ministerului Afacerilor Externe",{"entities":[(0,31,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("14 martie 2018",{"entities":[(0,14,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("23 iunie 1994",{"entities":[(0,13,"TIME")]}),
("Varșovia",{"entities":[(0,9,"LOC")]}),
("MINISTERUL AFACERILOR EXTERNE DIN ROMÂNIA",{"entities":[(0,42,"ORG")]}),
("ROMÂNIA",{"entities":[(0,8,"LOC")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("MINISTERUL AFACERILOR EXTERNE DIN ROMÂNIA",{"entities":[(0,42,"ORG")]}),
("ROMÂNIA",{"entities":[(0,8,"LOC")]}),
("14 martie 2018",{"entities":[(0,14,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("23 iunie 1994",{"entities":[(0,13,"TIME")]}),
("Varșovia",{"entities":[(0,9,"LOC")]}),
("3 luni",{"entities":[(0,6,"TIME")]}),
("Ambasada Republicii Polone",{"entities":[(0,26,"ORG")]}),
("Republicii Polone",{"entities":[(0,17,"LOC")]}),
("Ministerului Afacerilor Externe al României",{"entities":[(0,44,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("18 iunie 2018",{"entities":[(0,13,"TIME")]}),
("Ministerul Afacerilor Externe al României",{"entities":[(0,42,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ambasadei Republicii Polonia la București",{"entities":[(0,42,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("23 iunie 1994",{"entities":[(0,13,"TIME")]}),
("Varșovia",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("23 iunie 1994",{"entities":[(0,13,"TIME")]}),
("Varșovia",{"entities":[(0,9,"LOC")]}),
("Ministerul Afacerilor Externe al României",{"entities":[(0,42,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("23 iunie 1994",{"entities":[(0,13,"TIME")]}),
("Varșovia",{"entities":[(0,9,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("3 luni",{"entities":[(0,6,"TIME")]}),
("Ministerul Afacerilor Externe al României",{"entities":[(0,42,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ambasadei Republicii Polonia la București",{"entities":[(0,42,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("14 martie 2018",{"entities":[(0,14,"TIME")]}),
("Ambasada Republicii Polonia",{"entities":[(0,27,"ORG")]}),
("Republicii Polonia",{"entities":[(0,18,"LOC")]}),
("ORDONANȚĂ DE URGENȚĂ nr. 79 din 20 decembrie 2019",{"entities":[(0,53,"LAW")]}),
("20 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("23 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("Guvern",{"entities":[(0,6,"ORG")]}),
("Legea educației naționale nr. 1 / 2011",{"entities":[(0,40,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("2017-2018",{"entities":[(0,9,"TIME")]}),
("2020-2024",{"entities":[(0,9,"TIME")]}),
("Ministerul Educației și Cercetării",{"entities":[(0,37,"ORG")]}),
("2014-2020",{"entities":[(0,9,"TIME")]}),
("2017-2018",{"entities":[(0,9,"TIME")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("2020",{"entities":[(0,4,"TIME")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("31 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("Ministerul Educației și Cercetării",{"entities":[(0,37,"ORG")]}),
("MEC",{"entities":[(0,3,"ORG")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea educației naționale nr. 1 / 2011",{"entities":[(0,40,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("10 ianuarie 2011",{"entities":[(0,16,"TIME")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("Legea nr. 1 / 2011",{"entities":[(0,18,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("31 decembrie 2021",{"entities":[(0,17,"TIME")]}),
("LUDOVIC ORBAN",{"entities":[(0,13,"PER")]}),
("Cristina Monica Anisie",{"entities":[(0,22,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("20 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("ORDIN nr. 90 din 13 februarie 2019",{"entities":[(0,34,"LAW")]}),
("13 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Ordinului ministrului agriculturii și dezvoltării rurale nr. 619 / 2015",{"entities":[(0,73,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 3 / 2015",{"entities":[(0,49,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Legea nr. 36 / 1991",{"entities":[(0,19,"LAW")]}),
("1991",{"entities":[(0,4,"TIME")]}),
("2015-2020",{"entities":[(0,9,"TIME")]}),
("2014-2020",{"entities":[(0,9,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("14 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Referatul de aprobare al Direcției generale politici agricole nr. 279.211 din 11.02.2019",{"entities":[(0,89,"LAW")]}),
("Direcției generale politici agricole",{"entities":[(0,37,"ORG")]}),
("11.02.2019",{"entities":[(0,10,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 3 / 2015",{"entities":[(0,49,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2015-2020",{"entities":[(0,9,"TIME")]}),
("Legea nr. 36 / 1991",{"entities":[(0,19,"LAW")]}),
("1991",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Legea nr. 104 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului agriculturii și dezvoltării rurale nr. 619 / 2015",{"entities":[(0,71,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 3 / 2015",{"entities":[(0,49,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2015-2020",{"entities":[(0,9,"TIME")]}),
("Legea nr. 36 / 1991",{"entities":[(0,19,"LAW")]}),
("1991",{"entities":[(0,4,"TIME")]}),
("2014-2020",{"entities":[(0,9,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("6 aprilie 2015",{"entities":[(0,14,"TIME")]}),
("1 septembrie",{"entities":[(0,12,"TIME")]}),
("1 septembrie",{"entities":[(0,12,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Petre Daea",{"entities":[(0,10,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("13 februarie 2019",{"entities":[(0,17,"TIME")]}),
("ORDIN nr. 1.364 din 9 septembrie 2019",{"entities":[(0,37,"LAW")]}),
("9 septembrie 2019",{"entities":[(0,17,"TIME")]}),
("Ordinul ministrului sănătății nr. 1.468 / 2018",{"entities":[(0,50,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("11 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Referatul de aprobare nr. SP 11.463 / 2019",{"entities":[(0,42,"LAW")]}),
("Direcției politica medicamentului și a dispozitivelor medicale",{"entities":[(0,64,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Ordinului ministrului sănătății nr. 368 / 2017",{"entities":[(0,50,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 144 / 2010",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Ordinul ministrului sănătății nr. 1.468 / 2018",{"entities":[(0,50,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("22 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Dan Dumitrescu",{"entities":[(0,14,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("9 septembrie 2019",{"entities":[(0,17,"TIME")]}),
("Ordinul ministrului sănătății nr. 1.468 / 2018",{"entities":[(0,50,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("ORDIN nr. 41 din 15 martie 2019",{"entities":[(0,31,"LAW")]}),
("15 martie 2019",{"entities":[(0,14,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("18 martie 2019",{"entities":[(0,14,"TIME")]}),
("Regulamentul (UE) 2017 / 460",{"entities":[(0,28,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("16 martie 2017",{"entities":[(0,14,"TIME")]}),
("Legea energiei electrice și a gazelor naturale nr. 123 / 2012",{"entities":[(0,62,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 33 / 2007",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Legea nr. 160 / 2012",{"entities":[(0,20,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 33 / 2007",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Legea nr. 160 / 2012",{"entities":[(0,20,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 168 / 2018",{"entities":[(0,100,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("1 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("Ordinul nr. 61 din 23 mai 2019",{"entities":[(0,30,"LAW")]}),
("23 mai 2019",{"entities":[(0,11,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("24 mai 2019",{"entities":[(0,11,"TIME")]}),
("Legea energiei electrice și a gazelor naturale nr. 123 / 2012",{"entities":[(0,62,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 41 / 2019",{"entities":[(0,99,"LAW")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("18 martie 2019",{"entities":[(0,14,"TIME")]}),
("90 de zile",{"entities":[(0,10,"TIME")]}),
("Regulamentul (UE) 2017 / 459",{"entities":[(0,28,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("16 martie 2017",{"entities":[(0,14,"TIME")]}),
("Regulamentului (UE) 984 / 2013",{"entities":[(0,30,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 32 / 2014",{"entities":[(0,99,"LAW")]}),
("i Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,64,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("26 mai 2014",{"entities":[(0,11,"TIME")]}),
("Autoritatea Națională de Reglementare în Domeniul Energiei",{"entities":[(0,61,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("18 martie 2019",{"entities":[(0,14,"TIME")]}),
("Dumitru Chiriță",{"entities":[(0,17,"PER")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("15 martie 2019",{"entities":[(0,14,"TIME")]}),
("ORDIN nr. 49 din 14 ianuarie 2019",{"entities":[(0,33,"LAW")]}),
("14 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Ordinul ministrului agriculturii și dezvoltării rurale nr. 52 / 2017",{"entities":[(0,70,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("5 februarie 2019",{"entities":[(0,16,"TIME")]}),
("Referatul de aprobare nr. 2.046 din data de 26 noiembrie 2018",{"entities":[(0,61,"LAW")]}),
("26 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("Agenția Zonei Montane",{"entities":[(0,22,"ORG")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("Ordinul ministrului agriculturii și dezvoltării rurale nr. 52 / 2017",{"entities":[(0,70,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("14 martie 2017",{"entities":[(0,14,"TIME")]}),
("Agenției Zonei Montane",{"entities":[(0,23,"ORG")]}),
("Agenția Zonei Montane",{"entities":[(0,22,"ORG")]}),
("Regulamentul (UE) nr. 1.151 / 2012",{"entities":[(0,34,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Regulamentul delegat (UE) nr. 665 / 2014",{"entities":[(0,40,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Ordinului ministrului agriculturii și dezvoltării rurale nr. 52 / 2017",{"entities":[(0,72,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Petre Daea",{"entities":[(0,10,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("14 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("ORDIN nr. 717 din 16 iulie 2019",{"entities":[(0,31,"LAW")]}),
("16 iulie 2019",{"entities":[(0,13,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("23 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Referatul de aprobare nr. 113.049 din 15.07.2019",{"entities":[(0,48,"LAW")]}),
("15.07.2019",{"entities":[(0,10,"TIME")]}),
("Avizul Academiei Române nr. 4.220 din 16.07.2019",{"entities":[(0,49,"LAW")]}),
("16.07.2019",{"entities":[(0,10,"TIME")]}),
("Ordinul ministrului mediului și al ministrului agriculturii, pădurilor și dezvoltării rurale nr. 203 / 14 / 2009",{"entities":[(0,116,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 57 / 2007",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Legea nr. 49 / 2011",{"entities":[(0,19,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 19 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Mediului",{"entities":[(0,21,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 57 / 2007",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Legea nr. 49 / 2011",{"entities":[(0,19,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Râșnov",{"entities":[(0,8,"LOC")]}),
("Brașov",{"entities":[(0,7,"LOC")]}),
("31 august 2019",{"entities":[(0,14,"TIME")]}),
("Râșnov",{"entities":[(0,8,"LOC")]}),
("Legii vânătorii și a protecției fondului cinegetic nr. 407 / 2006",{"entities":[(0,69,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("7 zile",{"entities":[(0,6,"TIME")]}),
("Agenției Naționale pentru Protecția Mediului",{"entities":[(0,47,"ORG")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Grațiela Leocadia Gavrilescu",{"entities":[(0,29,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("16 iulie 2019",{"entities":[(0,13,"TIME")]}),
("ORDIN nr. 269 din 20 martie 2019",{"entities":[(0,32,"LAW")]}),
("20 martie 2019",{"entities":[(0,14,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 5 / 2015",{"entities":[(0,49,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("19 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Referatul de aprobare nr. 94.077 / DGDSCSP din 3.12.2018",{"entities":[(0,56,"LAW")]}),
("3.12.2018",{"entities":[(0,9,"TIME")]}),
("DGDSCSP",{"entities":[(0,7,"ORG")]}),
("Direcției generale deșeuri, situri contaminate și substanțe periculoase",{"entities":[(0,75,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 5 / 2015",{"entities":[(0,49,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 19 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Mediului",{"entities":[(0,21,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 5 / 2015",{"entities":[(0,49,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului mediului și gospodăririi apelor și al ministrului economiei și comerțului nr. 1.223 / 715 / 2005",{"entities":[(0,121,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("180 de zile",{"entities":[(0,11,"TIME")]}),
("Agenției Naționale pentru Protecția Mediului",{"entities":[(0,47,"ORG")]}),
("ANPM",{"entities":[(0,4,"ORG")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("Agenția Națională pentru Protecția Mediului",{"entities":[(0,47,"ORG")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("ANPM",{"entities":[(0,4,"ORG")]}),
("Agenția Națională pentru Protecția Mediului",{"entities":[(0,47,"ORG")]}),
("Agenția Națională pentru Protecția Mediului",{"entities":[(0,47,"ORG")]}),
("anului 2018",{"entities":[(0,11,"TIME")]}),
("30 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Ordinul ministrului mediului și gospodăririi apelor și al ministrului economiei și comerțului nr. 1.223 / 715 / 2005",{"entities":[(0,121,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("20 martie 2020",{"entities":[(0,14,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului mediului și gospodăririi apelor și al ministrului economiei și comerțului nr. 1.223 / 715 / 2005",{"entities":[(0,121,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("3 ianuarie 2006",{"entities":[(0,15,"TIME")]}),
("Agenția Națională pentru Protecția Mediului",{"entities":[(0,47,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Grațiela Leocadia Gavrilescu",{"entities":[(0,29,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("20 martie 2019",{"entities":[(0,14,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 5 / 2015",{"entities":[(0,49,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("HOTĂRÂRE nr. 7 din 9 ianuarie 2019",{"entities":[(0,36,"LAW")]}),
("9 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("Institutului Regional de Oncologie Iași",{"entities":[(0,40,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Universității de Medicină și Farmacie  Grigore T. Popa  Iași",{"entities":[(0,65,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Ministerului Educației Naționale",{"entities":[(0,34,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("11 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Legea nr. 213 / 1998",{"entities":[(0,20,"LAW")]}),
("1998",{"entities":[(0,4,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 287 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Codul civil",{"entities":[(0,11,"LAW")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("31 decembrie 2028",{"entities":[(0,17,"TIME")]}),
("Institutului Regional de Oncologie Iași",{"entities":[(0,40,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Universității de Medicină și Farmacie  Grigore T. Popa  Iași",{"entities":[(0,65,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Ministerului Educației Naționale",{"entities":[(0,34,"ORG")]}),
("Universității de Medicină și Farmacie  Grigore T. Popa  Iași",{"entities":[(0,65,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Institutului Regional de Oncologie Iași",{"entities":[(0,40,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Universitatea de Medicină și Farmacie  Grigore T. Popa  Iași",{"entities":[(0,63,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("2014-2020",{"entities":[(0,9,"TIME")]}),
("Universitatea de Medicină și Farmacie  Grigore T. Popa  Iași",{"entities":[(0,63,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Institutului Regional de Oncologie Iași",{"entities":[(0,40,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Universitatea de Medicină și Farmacie  Grigore T. Popa  Iași",{"entities":[(0,63,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Institutului Regional de Oncologie Iași",{"entities":[(0,40,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Universitatea de Medicină și Farmacie  Grigore T. Popa  Iași",{"entities":[(0,63,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Institutul Regional de Oncologie Iași",{"entities":[(0,38,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Institutului Regional de Oncologie Iași",{"entities":[(0,40,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("Ministerul Educației Naționale",{"entities":[(0,32,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Sorina Pintea",{"entities":[(0,13,"PER")]}),
("Ecaterina Andronescu",{"entities":[(0,20,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("9 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("Institutului Regional de Oncologie Iași",{"entities":[(0,40,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Universității de Medicină și Farmacie  Grigore T. Popa  Iași",{"entities":[(0,65,"ORG")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Ministerului Educației Naționale",{"entities":[(0,34,"ORG")]}),
("RECTIFICARE nr. 11 din 6 februarie 2019",{"entities":[(0,39,"LAW")]}),
("6 februarie 2019",{"entities":[(0,16,"TIME")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 11 / 2019",{"entities":[(0,99,"LAW")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("4 septembrie 2019",{"entities":[(0,17,"TIME")]}),
("21.03.2018",{"entities":[(0,10,"TIME")]}),
("ANRE",{"entities":[(0,4,"ORG")]}),
("ANRE",{"entities":[(0,4,"ORG")]}),
("31 decembrie",{"entities":[(0,12,"TIME")]}),
("21.03.2018",{"entities":[(0,10,"TIME")]}),
("ANRE",{"entities":[(0,4,"ORG")]}),
("31 decembrie",{"entities":[(0,12,"TIME")]}),
("ANRE",{"entities":[(0,4,"ORG")]}),
("21.03.2018",{"entities":[(0,10,"TIME")]}),
("31 decembrie",{"entities":[(0,12,"TIME")]}),
("ANRE",{"entities":[(0,4,"ORG")]}),
("31 decembrie",{"entities":[(0,12,"TIME")]}),
("ANRE",{"entities":[(0,4,"ORG")]}),
("21.03.2018",{"entities":[(0,10,"TIME")]}),
("ANRE",{"entities":[(0,4,"ORG")]}),
("HOTĂRÂRE nr. 258 din 24 aprilie 2019",{"entities":[(0,38,"LAW")]}),
("24 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Administrației Naționale a Penitenciarelor",{"entities":[(0,44,"ORG")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("Compania Națională de Administrare a Infrastructurii Rutiere - S.A.",{"entities":[(0,69,"ORG")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("9 mai 2019",{"entities":[(0,10,"TIME")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 213 / 1998",{"entities":[(0,20,"LAW")]}),
("1998",{"entities":[(0,4,"TIME")]}),
("Legea nr. 287 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Administrației Naționale a Penitenciarelor",{"entities":[(0,44,"ORG")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("Compania Națională de Administrare a Infrastructurii Rutiere - S.A.",{"entities":[(0,69,"ORG")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Administrația Națională a Penitenciarelor",{"entities":[(0,44,"ORG")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("Ministerul Transporturilor",{"entities":[(0,26,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Nicolae Liviu Popa",{"entities":[(0,18,"PER")]}),
("Alexandru-Răzvan Cuc",{"entities":[(0,21,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("24 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Administrației Naționale a Penitenciarelor",{"entities":[(0,44,"ORG")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("Str. Gorunului",{"entities":[(0,14,"LOC")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("Hotărârea Guvernului nr. 295 / 2011",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 1.106 / 2012",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 416 / 2016",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2016În",{"entities":[(0,7,"TIME")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Administrației Naționale a Penitenciarelor",{"entities":[(0,44,"ORG")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("Compania Națională de Administrare a Infrastructurii Rutiere - S.A.",{"entities":[(0,69,"ORG")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("Str. Gorunului nr. 1",{"entities":[(0,20,"LOC")]}),
("Administrației Naționale a Penitenciarelor",{"entities":[(0,44,"ORG")]}),
("Satu Mare",{"entities":[(0,9,"LOC")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("DECIZIE nr. 162 din 25 iulie 2019",{"entities":[(0,33,"LAW")]}),
("Comisiei Naționale de Supraveghere a Sistemului Informațional din Sănătate și de Raportare",{"entities":[(0,95,"ORG")]}),
("Organizația pentru Cooperare și Dezvoltare Economică",{"entities":[(0,55,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("25 iulie 2019",{"entities":[(0,13,"TIME")]}),
("25 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Comisiei Naționale de Supraveghere a Sistemului Informațional din Sănătate și de Raportare",{"entities":[(0,95,"ORG")]}),
("O.C.D.E.",{"entities":[(0,8,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("12 iunie 2019",{"entities":[(0,13,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 57 / 2019",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Comisia Națională de Supraveghere a Sistemului Informațional din Sănătate și de Raportare",{"entities":[(0,95,"ORG")]}),
("Organizația pentru Cooperare și Dezvoltare Economică",{"entities":[(0,55,"ORG")]}),
("O.C.D.E.",{"entities":[(0,8,"ORG")]}),
("Autorității Naționale de Management al Calității în Sănătate",{"entities":[(0,68,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Autorității Naționale de Management al Calității în Sănătate",{"entities":[(0,68,"ORG")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Institutului Național de Statistică",{"entities":[(0,37,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Autoritatea Națională de Management al Calității în Sănătate",{"entities":[(0,67,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("O.C.D.E.",{"entities":[(0,8,"ORG")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("Autoritatea Națională de Management al Calității în Sănătate",{"entities":[(0,67,"ORG")]}),
("Casa Națională de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Institutul Național de Sănătate Publică",{"entities":[(0,43,"ORG")]}),
("Școala Națională de Sănătate Publică, Management și Perfecționare în Domeniul Sanitar București",{"entities":[(0,105,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Institutul Național de Statistică",{"entities":[(0,35,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("O.C.D.E.",{"entities":[(0,8,"ORG")]}),
("Autorității Naționale de Management al Calității în Sănătate",{"entities":[(0,68,"ORG")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Toni Greblă",{"entities":[(0,12,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("25 iulie 2019",{"entities":[(0,13,"TIME")]}),
("ORDIN nr. 72 din 12 iunie 2019",{"entities":[(0,30,"LAW")]}),
("12 iunie 2019",{"entities":[(0,13,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("13 iunie 2019",{"entities":[(0,13,"TIME")]}),
("Legea energiei electrice și a gazelor naturale nr. 123 / 2012",{"entities":[(0,62,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("1 iulie 2019",{"entities":[(0,12,"TIME")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 217 / 2018",{"entities":[(0,100,"LAW")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 33 / 2007",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Legea nr. 160 / 2012",{"entities":[(0,20,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 106 / 2014",{"entities":[(0,100,"LAW")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("27 octombrie 2014",{"entities":[(0,17,"TIME")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 29 / 2016",{"entities":[(0,99,"LAW")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("7 iulie 2016",{"entities":[(0,12,"TIME")]}),
("365 de zile",{"entities":[(0,11,"TIME")]}),
("ANRE",{"entities":[(0,4,"ORG")]}),
("1 ianuarie",{"entities":[(0,10,"TIME")]}),
("31 decembrie",{"entities":[(0,12,"TIME")]}),
("1 ianuarie-31 decembrie",{"entities":[(0,23,"TIME")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 174 / 2018",{"entities":[(0,100,"LAW")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("5 octombrie 2018",{"entities":[(0,16,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("1 iulie 2019",{"entities":[(0,12,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Dumitru Chiriță",{"entities":[(0,17,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("12 iunie 2019",{"entities":[(0,13,"TIME")]}),
("HOTĂRÂRE nr. 10 din 20 martie 2019",{"entities":[(0,36,"LAW")]}),
("20 martie 2019",{"entities":[(0,14,"TIME")]}),
("Parlamentul European",{"entities":[(0,20,"ORG")]}),
("Consiliu",{"entities":[(0,8,"ORG")]}),
("Comitetul Economic și Social European",{"entities":[(0,38,"ORG")]}),
("Comitetul Regiunilor",{"entities":[(0,20,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("26 martie 2019",{"entities":[(0,14,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legii nr. 373 / 2013",{"entities":[(0,20,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlament",{"entities":[(0,9,"ORG")]}),
("Guvern",{"entities":[(0,6,"ORG")]}),
("Regulamentul Camerei Deputaților",{"entities":[(0,33,"LAW")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("Hotărârea Camerei Deputaților nr. 8 / 1994",{"entities":[(0,45,"LAW")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("1994",{"entities":[(0,4,"TIME")]}),
("Camera Deputaților",{"entities":[(0,19,"ORG")]}),
("Comisia pentru afaceri europene",{"entities":[(0,31,"ORG")]}),
("19 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Camera Deputaților",{"entities":[(0,19,"ORG")]}),
("Comisiei Europene",{"entities":[(0,17,"ORG")]}),
("1990",{"entities":[(0,4,"TIME")]}),
("Uniunii",{"entities":[(0,7,"ORG")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("Camera Deputaților",{"entities":[(0,19,"ORG")]}),
("20 martie 2019",{"entities":[(0,14,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("CAMEREI DEPUTAȚILOR",{"entities":[(0,20,"ORG")]}),
("EUGEN NICOLICEA",{"entities":[(0,15,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("20 martie 2019",{"entities":[(0,14,"TIME")]}),
("ORDONANȚĂ DE URGENȚĂ nr. 85 din 27 decembrie 2019",{"entities":[(0,53,"LAW")]}),
("27 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 77 / 2011",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("30 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Hotărârea Parlamentului României nr. 22 / 2019",{"entities":[(0,49,"LAW")]}),
("Parlamentului României",{"entities":[(0,23,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 77 / 2011",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Legea nr. 184 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("anul 2018",{"entities":[(0,9,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ordonanța de urgență a Guvernului nr. 77 / 2011",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("26 septembrie 2011",{"entities":[(0,18,"TIME")]}),
("Legea nr. 184 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("anului 2019",{"entities":[(0,11,"TIME")]}),
("LUDOVIC ORBAN",{"entities":[(0,13,"PER")]}),
("Raluca Turcan",{"entities":[(0,13,"PER")]}),
("Horațiu Moldovan",{"entities":[(0,17,"PER")]}),
("Mironel Panțuroiu",{"entities":[(0,18,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("27 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("ORDIN nr. 282 din 23 iulie 2019",{"entities":[(0,31,"LAW")]}),
("23 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Ordinul președintelui Agenției Naționale pentru Resurse Minerale nr. 32 / 2018",{"entities":[(0,81,"LAW")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("1 august 2019",{"entities":[(0,13,"TIME")]}),
("Legea energiei electrice și a gazelor naturale nr. 123 / 2012",{"entities":[(0,62,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Referatul Direcției generale inspecție și supraveghere teritorială a activităților miniere și a operațiunilor petroliere nr. 400.425 din 28.06.2019",{"entities":[(0,155,"LAW")]}),
("Direcției generale inspecție și supraveghere teritorială a activităților miniere și a operațiunilor petroliere",{"entities":[(0,118,"ORG")]}),
("28.06.2019",{"entities":[(0,10,"TIME")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Hotărârea Guvernului nr. 1.419 / 2009",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Ordinul președintelui Agenției Naționale pentru Resurse Minerale nr. 32 / 2018",{"entities":[(0,81,"LAW")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("12 februarie 2018",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Gigi Dragomir",{"entities":[(0,13,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("23 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Ordinul nr. 32 / 2018",{"entities":[(0,21,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Legea energiei electrice și a gazelor naturale nr. 123 / 2012",{"entities":[(0,62,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Legea energiei electrice și a gazelor naturale nr. 123 / 2012",{"entities":[(0,62,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Societatea Națională de Transport Gaze Naturale  Transgaz  - S.A. Mediaș",{"entities":[(0,75,"ORG")]}),
("Mediaș",{"entities":[(0,7,"LOC")]}),
("Ordonanța de urgență a Guvernului nr. 114 / 2018",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("HOTĂRÂRE nr. 847 din 6 decembrie 2019",{"entities":[(0,39,"LAW")]}),
("6 decembrie 2019",{"entities":[(0,16,"TIME")]}),
("Hotărârea Guvernului nr. 1.348 / 2001",{"entities":[(0,39,"LAW")]}),
("2001",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Buzău",{"entities":[(0,6,"LOC")]}),
("Buzău",{"entities":[(0,6,"LOC")]}),
("11 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ordonanța de urgență a Guvernului nr. 57 / 2019",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Hotărârea Guvernului nr. 1.348 / 2001",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2001",{"entities":[(0,4,"TIME")]}),
("Buzău",{"entities":[(0,6,"LOC")]}),
("Buzău",{"entities":[(0,6,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("22 august 2002",{"entities":[(0,14,"TIME")]}),
("Nehoiu",{"entities":[(0,6,"LOC")]}),
("Buzău",{"entities":[(0,6,"LOC")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("Mărăcineanu Constantin",{"entities":[(0,24,"PER")]}),
("1992",{"entities":[(0,4,"TIME")]}),
("Hotărârea Consiliului Local Pănătău nr. 37 / 2018",{"entities":[(0,54,"LAW")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("Buzău",{"entities":[(0,6,"LOC")]}),
("Toma Ileana",{"entities":[(0,11,"PER")]}),
("Hotărârea Consiliului Local Pănătău nr. 37 / 2018",{"entities":[(0,54,"LAW")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("Buzău",{"entities":[(0,6,"LOC")]}),
("1992",{"entities":[(0,4,"TIME")]}),
("Hotărârea Consiliului Local Pănătău nr. 37 / 2018",{"entities":[(0,54,"LAW")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("Buzău",{"entities":[(0,6,"LOC")]}),
("Hotărârea Consiliului Local Pănătău nr. 37 / 2018",{"entities":[(0,54,"LAW")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("Buzău",{"entities":[(0,6,"LOC")]}),
("1992",{"entities":[(0,4,"TIME")]}),
("Hotărârea Consiliului Local Pănătău nr. 37 / 2018",{"entities":[(0,54,"LAW")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("Buzău",{"entities":[(0,6,"LOC")]}),
("Hotărârea Consiliului Local Pănătău nr. 37 / 2018",{"entities":[(0,54,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Pănătău",{"entities":[(0,10,"LOC")]}),
("Vintilă Vodă",{"entities":[(0,14,"LOC")]}),
("Niculești",{"entities":[(0,10,"LOC")]}),
("Vintilă Vodă",{"entities":[(0,14,"LOC")]}),
("Școala Generală Niculești",{"entities":[(0,28,"ORG")]}),
("Școala Generală Niculești",{"entities":[(0,28,"ORG")]}),
("Consum Coop Societate Cooperativa Slănic",{"entities":[(0,41,"ORG")]}),
("Slănic",{"entities":[(0,7,"LOC")]}),
("Hotărârea Consiliului Local Vintilă Vodă nr. 29 / 28.12.2018",{"entities":[(0,64,"LAW")]}),
("Vintilă Vodă",{"entities":[(0,14,"LOC")]}),
("28.12.2018",{"entities":[(0,10,"TIME")]}),
("3.08.2016",{"entities":[(0,9,"TIME")]}),
("LUDOVIC ORBAN",{"entities":[(0,13,"PER")]}),
("Ion Ștefan",{"entities":[(0,11,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("6 decembrie 2019",{"entities":[(0,16,"TIME")]}),
("ORDIN nr. 3.774 din 19 decembrie 2019",{"entities":[(0,37,"LAW")]}),
("19 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("24 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("Hotărârea Guvernului nr. 34 / 2009",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Ministerului Finanțelor Publice",{"entities":[(0,32,"ORG")]}),
("Ordonanța Guvernului nr. 17 / 2015",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Legea nr. 316 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Ordinul ministrului de stat, ministrul finanțelor, nr. 1.801 / 1995",{"entities":[(0,68,"LAW")]}),
("1995",{"entities":[(0,4,"TIME")]}),
("Ordinul viceprim-ministrului, ministrul finanțelor publice, și al ministrului delegat pentru buget nr. 2.005 / 2013",{"entities":[(0,117,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului delegat pentru buget nr. 501 / 2013",{"entities":[(0,55,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului finanțelor publice nr. 1.801 / 2014",{"entities":[(0,56,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului de stat, ministrul finanțelor, nr. 1.801 / 1995",{"entities":[(0,68,"LAW")]}),
("1995",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului delegat pentru buget nr. 720 / 2014",{"entities":[(0,55,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului finanțelor publice nr. 517 / 2016",{"entities":[(0,54,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Ordinul viceprim-ministrului, ministrul finanțelor publice, nr. 2.004 / 2013",{"entities":[(0,77,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Vasile-Florin Cîțu",{"entities":[(0,20,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("19 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("HOTĂRÂRE nr. 34 din 6 decembrie 2018",{"entities":[(0,38,"LAW")]}),
("6 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("18 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Legea nr. 53 / 2014",{"entities":[(0,19,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ordinului Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România",{"entities":[(0,96,"ORG")]}),
("Ordinului Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România nr. 31 / 2017",{"entities":[(0,110,"ORG")]}),
("Ordinului Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România",{"entities":[(0,96,"ORG")]}),
("Ordinului Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România",{"entities":[(0,96,"ORG")]}),
("Ordinului Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România",{"entities":[(0,96,"ORG")]}),
("Ordinului Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România",{"entities":[(0,96,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 144 / 2008",{"entities":[(0,51,"LAW")]}),
("Ordinul Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România",{"entities":[(0,94,"ORG")]}),
("Ordinului Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România",{"entities":[(0,96,"ORG")]}),
("Ordinului Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România",{"entities":[(0,96,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ordinul Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România",{"entities":[(0,94,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("18 decembrie 2017",{"entities":[(0,17,"TIME")]}),
("Ordinului Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România",{"entities":[(0,96,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("OAMGMAMR",{"entities":[(0,8,"ORG")]}),
("OAMGMAMR",{"entities":[(0,8,"ORG")]}),
("OAMGMAMR",{"entities":[(0,8,"ORG")]}),
("OAMGMAMR",{"entities":[(0,8,"ORG")]}),
("OAMGMAMR",{"entities":[(0,8,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("1 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("Ordinului Asistenților Medicali Generaliști, Moașelor și Asistenților Medicali din România",{"entities":[(0,96,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Mircea Timofte",{"entities":[(0,14,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("6 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("ORDIN nr. 537 din 4 noiembrie 2019",{"entities":[(0,34,"LAW")]}),
("4 noiembrie 2019",{"entities":[(0,16,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("25 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("Referatul de aprobare al Autorității Naționale Fitosanitare nr. 15.577 din 29.10.2019",{"entities":[(0,88,"LAW")]}),
("Autorității Naționale Fitosanitare",{"entities":[(0,37,"ORG")]}),
("29.10.2019",{"entities":[(0,10,"TIME")]}),
("Legea nr. 139 / 2014",{"entities":[(0,20,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 43 / 2015",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale Fitosanitare",{"entities":[(0,37,"ORG")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("Autoritatea Națională Fitosanitară",{"entities":[(0,37,"ORG")]}),
("Autorității Naționale Fitosanitare",{"entities":[(0,37,"ORG")]}),
("Autorității Naționale Fitosanitare",{"entities":[(0,37,"ORG")]}),
("Autoritatea Națională Fitosanitară",{"entities":[(0,37,"ORG")]}),
("Ordinul ministrului agriculturii și dezvoltării rurale nr. 748 / 2015",{"entities":[(0,71,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("13 mai 2015",{"entities":[(0,11,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Dumitru Daniel Botănoiu",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("4 noiembrie 2019",{"entities":[(0,16,"TIME")]}),
("HOTĂRÂRE nr. 234 din 18 aprilie 2019",{"entities":[(0,38,"LAW")]}),
("18 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Hotărârii Guvernului nr. 322 / 2013",{"entities":[(0,37,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("23 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Hotărârea Guvernului nr. 322 / 2013",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("13 iunie 2013",{"entities":[(0,13,"TIME")]}),
("22 iulie 2014",{"entities":[(0,13,"TIME")]}),
("Hotărârii Guvernului nr. 992 / 2005",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("22 iulie 2016",{"entities":[(0,13,"TIME")]}),
("22 iulie 2017",{"entities":[(0,13,"TIME")]}),
("22 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Hotărârii Guvernului nr. 992 / 2005",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("22 iulie 2019",{"entities":[(0,13,"TIME")]}),
("1 iulie 2006",{"entities":[(0,12,"TIME")]}),
("1 iulie 2016",{"entities":[(0,12,"TIME")]}),
("22 iulie 2014",{"entities":[(0,13,"TIME")]}),
("22 iulie 2024",{"entities":[(0,13,"TIME")]}),
("22 iulie 2016",{"entities":[(0,13,"TIME")]}),
("22 iulie 2026",{"entities":[(0,13,"TIME")]}),
("22 iulie 2017",{"entities":[(0,13,"TIME")]}),
("22 iulie 2027",{"entities":[(0,13,"TIME")]}),
("Hotărârii Guvernului nr. 992 / 2005",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("22 iulie 2019",{"entities":[(0,13,"TIME")]}),
("22 iulie 2029",{"entities":[(0,13,"TIME")]}),
("12 iunie 2019",{"entities":[(0,13,"TIME")]}),
("Directiva (UE) 2017 / 2.102",{"entities":[(0,27,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("15 noiembrie 2017",{"entities":[(0,17,"TIME")]}),
("Directivei 2011 / 65 / UE",{"entities":[(0,25,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("Jurnalul Oficial al Uniunii Europene, seria L, nr. 305 din 21 noiembrie 2017",{"entities":[(0,76,"LAW")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("21 noiembrie 2017",{"entities":[(0,17,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Ion Cîmpeanu",{"entities":[(0,13,"PER")]}),
("Maria Magdalena Grigore",{"entities":[(0,23,"PER")]}),
("Niculae Bădălău",{"entities":[(0,18,"PER")]}),
("Sorina Pintea",{"entities":[(0,13,"PER")]}),
("Alexandru-Victor Micula",{"entities":[(0,23,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("18 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("ORDIN nr. 14 din 13 ianuarie 2020",{"entities":[(0,33,"LAW")]}),
("13 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("Ordinul președintelui Casei Naționale de Asigurări de Sănătate nr. 141 / 2017",{"entities":[(0,82,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 720 / 2008",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("28 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("Referatul de aprobare nr. DG 45 din 10 ianuarie 2020",{"entities":[(0,52,"LAW")]}),
("10 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Hotărârea Guvernului nr. 972 / 2006",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 720 / 2008",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului sănătății publice și al președintelui Casei Naționale de Asigurări de Sănătate nr. 1.301 / 500 / 2008",{"entities":[(0,131,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 720 / 2008",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Hotărârea Guvernului nr. 972 / 2006",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Ordinul președintelui Casei Naționale de Asigurări de Sănătate nr. 141 / 2017",{"entities":[(0,82,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 720 / 2008",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("28 februarie 2017",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Adela Cojan",{"entities":[(0,11,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("13 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("HOTĂRÂRE nr. 13 din 17 ianuarie 2019",{"entities":[(0,38,"LAW")]}),
("17 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Vrancea",{"entities":[(0,7,"LOC")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("22 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Ordonanța Guvernului nr. 112 / 2000",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("Legea nr. 246 / 2001",{"entities":[(0,20,"LAW")]}),
("2001",{"entities":[(0,4,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 213 / 1998",{"entities":[(0,20,"LAW")]}),
("1998",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ministerul Apărării Naționale",{"entities":[(0,32,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Gabriel-Beniamin Leș",{"entities":[(0,21,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("17 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Focșani",{"entities":[(0,8,"LOC")]}),
("Vrancea",{"entities":[(0,7,"LOC")]}),
("Focșani",{"entities":[(0,8,"LOC")]}),
("Focșani",{"entities":[(0,8,"LOC")]}),
("Ministerul Apărării Naționale",{"entities":[(0,32,"ORG")]}),
("Sebeș",{"entities":[(0,6,"LOC")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("Ministerul Apărării Naționale",{"entities":[(0,32,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("str. Izvor nr. 110",{"entities":[(0,18,"LOC")]}),
("sectorul 5",{"entities":[(0,10,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("sectorul 5",{"entities":[(0,10,"LOC")]}),
("Ministerul Apărării Naționale",{"entities":[(0,32,"ORG")]}),
("ORDIN nr. 1.534 din 7 decembrie 2018",{"entities":[(0,36,"LAW")]}),
("7 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("Ordinul ministrului sănătății nr. 1.468 / 2018",{"entities":[(0,50,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("10 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Referatul de aprobare nr. SP 14.861 din 7.12.2018",{"entities":[(0,49,"LAW")]}),
("7.12.2018",{"entities":[(0,9,"TIME")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Ordinului ministrului sănătății nr. 368 / 2017",{"entities":[(0,50,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 144 / 2010",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Ordinul ministrului sănătății nr. 1.468 / 2018",{"entities":[(0,50,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("22 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Tiberius-Marius Brădățan",{"entities":[(0,27,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("7 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("Ordinul ministrului sănătății nr. 1.468 / 2018",{"entities":[(0,50,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("UNIFARM - S.A. - ROMÂNIA",{"entities":[(0,25,"ORG")]}),
("UNIFARM - S.A. - ROMÂNIA",{"entities":[(0,25,"ORG")]}),
("ROMÂNIAMAGNESII",{"entities":[(0,16,"LOC")]}),
("ROMÂNIA",{"entities":[(0,8,"LOC")]}),
("29 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("UNIFARM - S.A. - ROMÂNIA",{"entities":[(0,25,"ORG")]}),
("ROMÂNIA",{"entities":[(0,8,"LOC")]}),
("19 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("UNIFARM - S.A. - ROMÂNIA",{"entities":[(0,25,"ORG")]}),
("ROMÂNIA",{"entities":[(0,8,"LOC")]}),
("29 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("UNIFARM - S.A. - ROMÂNIA",{"entities":[(0,25,"ORG")]}),
("ROMÂNIA",{"entities":[(0,8,"LOC")]}),
("3 ani",{"entities":[(0,5,"TIME")]}),
("19 octombrie 2019",{"entities":[(0,17,"TIME")]}),
("COMUNICAT din 25 februarie 2019",{"entities":[(0,31,"LAW")]}),
("25 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Legea nr. 1 / 2000",{"entities":[(0,18,"LAW")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("CEDO",{"entities":[(0,4,"ORG")]}),
("HG nr. 131 / 1991",{"entities":[(0,17,"LAW")]}),
("1991",{"entities":[(0,4,"TIME")]}),
("Codul Silvic",{"entities":[(0,12,"LAW")]}),
("Legea nr. 26 / 1996",{"entities":[(0,19,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Legea nr. 1 / 2000",{"entities":[(0,18,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("25.02.2019",{"entities":[(0,10,"TIME")]}),
("Legea nr. 1 / 2000",{"entities":[(0,18,"LAW")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("Legea nr. 1 / 2000",{"entities":[(0,18,"LAW")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("CEDO",{"entities":[(0,4,"ORG")]}),
("Comisiilor de Fond Funciar",{"entities":[(0,26,"ORG")]}),
("HG nr. 131 / 1991",{"entities":[(0,17,"LAW")]}),
("1991",{"entities":[(0,4,"TIME")]}),
("13 ani",{"entities":[(0,6,"TIME")]}),
("Comisiile de Fond Funciar",{"entities":[(0,25,"ORG")]}),
("Codul Silvic",{"entities":[(0,12,"LAW")]}),
("Legea nr. 26 / 1996",{"entities":[(0,19,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("13 ani",{"entities":[(0,6,"TIME")]}),
("Legea nr. 1 / 2000",{"entities":[(0,18,"LAW")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("16 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Legea nr. 1 / 2000",{"entities":[(0,18,"LAW")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("Legii fondului funciar nr. 18 / 1991",{"entities":[(0,36,"LAW")]}),
("1991",{"entities":[(0,4,"TIME")]}),
("Legii nr. 169 / 1997",{"entities":[(0,20,"LAW")]}),
("1997",{"entities":[(0,4,"TIME")]}),
("Legea nr. 1 / 2000",{"entities":[(0,18,"LAW")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("13 ani",{"entities":[(0,6,"TIME")]}),
("Hotărârea Guvernului nr. 131 / 1991",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("1991",{"entities":[(0,4,"TIME")]}),
("Legea nr. 26 / 1996",{"entities":[(0,19,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Codul silvic",{"entities":[(0,12,"LAW")]}),
("13 ani",{"entities":[(0,6,"TIME")]}),
("Legea nr. 1 / 2000",{"entities":[(0,18,"LAW")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("Legea nr. 1 / 2000",{"entities":[(0,18,"LAW")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("Legea nr. 1 / 2000",{"entities":[(0,18,"LAW")]}),
("Codul de procedură civilă",{"entities":[(0,27,"LAW")]}),
("ORDIN nr. 2.272 din 18 aprilie 2019",{"entities":[(0,35,"LAW")]}),
("18 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Sinaia",{"entities":[(0,6,"LOC")]}),
("Str. Mănăstirii nr. 2",{"entities":[(0,23,"LOC")]}),
("Sinaia",{"entities":[(0,6,"LOC")]}),
("Prahova",{"entities":[(0,7,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("20 mai 2019",{"entities":[(0,11,"TIME")]}),
("Sinaia",{"entities":[(0,6,"LOC")]}),
("Str. Mănăstirii nr. 2",{"entities":[(0,23,"LOC")]}),
("Sinaia",{"entities":[(0,6,"LOC")]}),
("Prahova",{"entities":[(0,7,"LOC")]}),
("21.03.2019",{"entities":[(0,10,"TIME")]}),
("Legea nr. 422 / 2001",{"entities":[(0,20,"LAW")]}),
("2001",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului culturii și cultelor nr. 2.260 / 2008",{"entities":[(0,58,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 90 / 2010",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Ministerului Culturii și Identității Naționale",{"entities":[(0,50,"ORG")]}),
("Sinaia",{"entities":[(0,6,"LOC")]}),
("Sinaia",{"entities":[(0,6,"LOC")]}),
("Prahova",{"entities":[(0,7,"LOC")]}),
("Str. Mănăstirii nr. 2",{"entities":[(0,23,"LOC")]}),
("Sinaia",{"entities":[(0,6,"LOC")]}),
("Prahova",{"entities":[(0,7,"LOC")]}),
("Str. Mănăstirii nr. 2",{"entities":[(0,23,"LOC")]}),
("1847-1859",{"entities":[(0,9,"TIME")]}),
("Ordinul ministrului culturii și cultelor nr. 2.314 / 2004",{"entities":[(0,58,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("16 iulie 2004",{"entities":[(0,13,"TIME")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Prahova",{"entities":[(0,7,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Valer-Daniel Breaz",{"entities":[(0,18,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("18 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Sinaia",{"entities":[(0,6,"LOC")]}),
("Sinaia",{"entities":[(0,6,"LOC")]}),
("Prahova",{"entities":[(0,7,"LOC")]}),
("Str. Mănăstirii nr. 2",{"entities":[(0,23,"LOC")]}),
("RAPORT nr. 17.350 din 17 decembrie 2018",{"entities":[(0,39,"LAW")]}),
("17 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Autoritatea Electorală Permanentă",{"entities":[(0,35,"ORG")]}),
("Uniunea Democrată Maghiară din România",{"entities":[(0,41,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Organizația Județeană Alba",{"entities":[(0,29,"ORG")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("7 mai 2019",{"entities":[(0,10,"TIME")]}),
("Legea nr. 334 / 2006",{"entities":[(0,20,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("anul 2018",{"entities":[(0,9,"TIME")]}),
("Autorității Electorale Permanente",{"entities":[(0,35,"ORG")]}),
("2.07.2018-13.07.2018",{"entities":[(0,20,"TIME")]}),
("2.07.2018",{"entities":[(0,9,"TIME")]}),
("13.07.2018",{"entities":[(0,10,"TIME")]}),
("Uniunea Democrată Maghiară din România",{"entities":[(0,41,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Organizația Județeană Alba",{"entities":[(0,29,"ORG")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("1.01.2015",{"entities":[(0,9,"TIME")]}),
("31.12.2017",{"entities":[(0,10,"TIME")]}),
("1.01.2015-31.12.2017",{"entities":[(0,20,"TIME")]}),
("anul 2015",{"entities":[(0,9,"TIME")]}),
("Organizația Județeană Alba",{"entities":[(0,29,"ORG")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("Uniunii Democrate Maghiare din România",{"entities":[(0,39,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("31.12.2015",{"entities":[(0,10,"TIME")]}),
("anul 2016",{"entities":[(0,9,"TIME")]}),
("Organizația Județeană Alba",{"entities":[(0,29,"ORG")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("Uniunii Democrate Maghiare din România",{"entities":[(0,39,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("31.12.2016",{"entities":[(0,10,"TIME")]}),
("anul 2017",{"entities":[(0,9,"TIME")]}),
("Organizația Județeană Alba",{"entities":[(0,29,"ORG")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("Uniunii Democrate Maghiare din România",{"entities":[(0,39,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("31.12.2017",{"entities":[(0,10,"TIME")]}),
("Organizației Județene Alba",{"entities":[(0,28,"ORG")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("Uniunii Democrate Maghiare din România",{"entities":[(0,39,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("anul 2015",{"entities":[(0,9,"TIME")]}),
("Uniunea Democrată Maghiară din România",{"entities":[(0,41,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Organizația Județeană Alba",{"entities":[(0,29,"ORG")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("31.12.2015",{"entities":[(0,10,"TIME")]}),
("anul 2016",{"entities":[(0,9,"TIME")]}),
("Uniunea Democrată Maghiară din România",{"entities":[(0,41,"ORG")]}),
("Organizația Județeană Alba",{"entities":[(0,29,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("31.12.2016",{"entities":[(0,10,"TIME")]}),
("anul 2017",{"entities":[(0,9,"TIME")]}),
("Uniunea Democrată Maghiară din România",{"entities":[(0,41,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Organizația Județeană Alba,",{"entities":[(0,30,"ORG")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("31.12.2017",{"entities":[(0,10,"TIME")]}),
("Organizației Județene Alba",{"entities":[(0,28,"ORG")]}),
("Uniunii Democrate Maghiare din România",{"entities":[(0,39,"ORG")]}),
("Alba",{"entities":[(0,4,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Legea nr. 334 / 2006",{"entities":[(0,20,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 10 / 2016",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Legii nr. 334 / 2006",{"entities":[(0,20,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Legea nr. 334 / 2006",{"entities":[(0,20,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("anul 2018",{"entities":[(0,9,"TIME")]}),
("Legii nr. 334 / 2006",{"entities":[(0,20,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Legii nr. 334 / 2006",{"entities":[(0,20,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 10 / 2016",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("București",{"entities":[(0,10,"LOC")]}),
("17 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("ORDIN nr. 65 din 21 ianuarie 2019",{"entities":[(0,33,"LAW")]}),
("21 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("23 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Referatul de aprobare nr. 171.367 / 10.01.2019",{"entities":[(0,46,"LAW")]}),
("10.01.2019",{"entities":[(0,10,"TIME")]}),
("Direcției generale buget-finanțe și fonduri europene",{"entities":[(0,55,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 79 / 2009",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Legea nr. 373 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 79 / 2009",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 1.262 / 2009",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Legii nr. 218 / 2005",{"entities":[(0,20,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("SAPARD",{"entities":[(0,6,"ORG")]}),
("Hotărârea Guvernului nr. 876 / 2005",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("Legii nr. 218 / 2005",{"entities":[(0,20,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ministerul Agriculturii și Dezvoltării Rurale",{"entities":[(0,47,"ORG")]}),
("31 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Legea nr. 218 / 2005",{"entities":[(0,20,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("SAPARD",{"entities":[(0,6,"ORG")]}),
("Ordonanței de urgență a Guvernului nr. 79 / 2009",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Legea nr. 373 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Agenției pentru Finanțarea Investițiilor Rurale",{"entities":[(0,50,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Ordonanței de urgență a Guvernului nr. 79 / 2009",{"entities":[(0,51,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Legea nr. 373 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("Agenția pentru Finanțarea Investițiilor Rurale",{"entities":[(0,49,"ORG")]}),
("2007-2013",{"entities":[(0,9,"TIME")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("31 decembrie 2015",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Dumitru Daniel Botănoiu",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("21 ianuarie 201",{"entities":[(0,15,"TIME")]}),
("ORDIN nr. 511 din 14 februarie 2019",{"entities":[(0,35,"LAW")]}),
("14 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Regulamentului de punere în aplicare (UE) nr. 2017 / 373",{"entities":[(0,57,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("1 martie 2017",{"entities":[(0,13,"TIME")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("Regulamentului (CE) nr. 482 / 2008",{"entities":[(0,34,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Regulamentelor de punere în aplicare (UE) nr. 1.034 / 2011",{"entities":[(0,59,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("(UE) nr. 1.035 / 2011",{"entities":[(0,21,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("(UE) 2016 / 1.377",{"entities":[(0,17,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Regulamentului (UE) nr. 677 / 2011",{"entities":[(0,34,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("27 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Regulamentul de punere în aplicare (UE) nr. 2017 / 373",{"entities":[(0,55,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("1 martie 2017",{"entities":[(0,13,"TIME")]}),
("Regulamentului (CE) nr. 482 / 2008",{"entities":[(0,34,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Regulamentelor de punere în aplicare (UE) nr. 1.034 / 2011",{"entities":[(0,59,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("(UE) nr. 1.035 / 2011",{"entities":[(0,21,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("(UE) 2016 / 1.377",{"entities":[(0,17,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Regulamentului (UE) nr. 677 / 2011",{"entities":[(0,34,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Regulamentul (UE) nr. 2017 / 373",{"entities":[(0,32,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ordinului ministrului transporturilor, construcțiilor și turismului nr. 1.185 / 2006",{"entities":[(0,86,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Regiei Autonome  Autoritatea Aeronautică Civilă Română ",{"entities":[(0,59,"ORG")]}),
("Autorității Aeronautice Civile Române",{"entities":[(0,40,"ORG")]}),
("Hotărârea Guvernului nr. 405 / 1993",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("1993",{"entities":[(0,4,"TIME")]}),
("a Autorității Aeronautice Civile Române",{"entities":[(0,42,"ORG")]}),
("Ordonanța Guvernului nr. 29 / 1997",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("1997",{"entities":[(0,4,"TIME")]}),
("Codul aerian civil",{"entities":[(0,18,"LAW")]}),
("Hotărârea Guvernului nr. 21 / 2015",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("Autoritatea Aeronautică Civilă Română",{"entities":[(0,41,"ORG")]}),
("Regulamentului de punere în aplicare (UE) nr. 2017 / 373",{"entities":[(0,57,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("1 martie 2017",{"entities":[(0,13,"TIME")]}),
("Regulamentului (CE) nr. 482 / 2008",{"entities":[(0,34,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Regulamentelor de punere în aplicare (UE) nr. 1.034 / 2011",{"entities":[(0,59,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("(UE) nr. 1.032 / 2011",{"entities":[(0,21,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("(UE) 2016 / 1.377",{"entities":[(0,17,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Regulamentului (UE) nr. 677 / 2011",{"entities":[(0,34,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Autoritatea Aeronautică Civilă Română",{"entities":[(0,41,"ORG")]}),
("Regulamentul (UE) nr. 2017 / 373",{"entities":[(0,32,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Autoritatea Aeronautică Civilă Română",{"entities":[(0,41,"ORG")]}),
("Regulamentului (UE) nr. 2017 / 373",{"entities":[(0,34,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Autoritatea Aeronautică Civilă Română",{"entities":[(0,41,"ORG")]}),
("Agenția Europeană de Siguranță a Aviației",{"entities":[(0,46,"ORG")]}),
("EASA",{"entities":[(0,4,"ORG")]}),
("Regulamentului (CE) nr. 2018 / 1.139",{"entities":[(0,36,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Agenției Europene de Siguranță a Aviației",{"entities":[(0,45,"ORG")]}),
("Autorității Aeronautice Civile Române",{"entities":[(0,40,"ORG")]}),
("60 de zile",{"entities":[(0,10,"TIME")]}),
("Autoritatea Aeronautică Civilă Română",{"entities":[(0,41,"ORG")]}),
("Regulamentului (UE) nr. 2017 / 373",{"entities":[(0,34,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("Regulamentul (UE) nr. 2018 / 1.139",{"entities":[(0,34,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Rovana Plumb",{"entities":[(0,12,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("14 februarie 2019",{"entities":[(0,17,"TIME")]}),
("LEGE nr. 15 din 15 ianuarie 2020",{"entities":[(0,32,"LAW")]}),
("15 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("Muzeului Național  Brătianu ",{"entities":[(0,30,"ORG")]}),
("Parlamentul",{"entities":[(0,11,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Muzeul Național  Brătianu ",{"entities":[(0,28,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("16 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("Ministerului Culturii",{"entities":[(0,21,"ORG")]}),
("Ștefănești",{"entities":[(0,13,"LOC")]}),
("Argeș",{"entities":[(0,6,"LOC")]}),
("Brătianu",{"entities":[(0,9,"PER")]}),
("Brătianu",{"entities":[(0,9,"PER")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Brătianu",{"entities":[(0,9,"PER")]}),
("Brătianu",{"entities":[(0,9,"PER")]}),
("Ministerului Culturii",{"entities":[(0,21,"ORG")]}),
("Ordonanței de urgență a Guvernului nr. 189 / 2008",{"entities":[(0,52,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Legea nr. 269 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Legii muzeelor și a colecțiilor publice nr. 311 / 2003",{"entities":[(0,56,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 189 / 2008",{"entities":[(0,52,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Comisia Națională a Muzeelor și Colecțiilor",{"entities":[(0,47,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("1 februarie 2020",{"entities":[(0,16,"TIME")]}),
("Parlamentul",{"entities":[(0,11,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("ION-MARCEL CIOLACU",{"entities":[(0,18,"PER")]}),
("TEODOR-VIOREL MELEȘCANU",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("15 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("ORDIN nr. 244 din 11 iunie 2019",{"entities":[(0,31,"LAW")]}),
("11 iunie 2019",{"entities":[(0,13,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("28 iunie 2019",{"entities":[(0,13,"TIME")]}),
("Legea minelor nr. 85 / 2003",{"entities":[(0,27,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 1.419 / 2009",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Licența de concesionare pentru explorare nr. 21.866 / 2019",{"entities":[(0,59,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Borsec",{"entities":[(0,6,"LOC")]}),
("Valea Cupelor",{"entities":[(0,13,"LOC")]}),
("Harghita",{"entities":[(0,8,"LOC")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Societatea Comercială Romaqua Group - S.A.",{"entities":[(0,43,"ORG")]}),
("Borsec",{"entities":[(0,6,"LOC")]}),
("Harghita",{"entities":[(0,8,"LOC")]}),
("Licența de concesionare pentru explorare nr. 21.871 / 2019",{"entities":[(0,59,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Borsec",{"entities":[(0,6,"LOC")]}),
("Valea Vinișoru",{"entities":[(0,15,"LOC")]}),
("Harghita",{"entities":[(0,8,"LOC")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Societatea Comercială Romaqua Group - S.A.",{"entities":[(0,43,"ORG")]}),
("Borsec",{"entities":[(0,6,"LOC")]}),
("Harghita",{"entities":[(0,8,"LOC")]}),
("Licența de concesionare pentru explorare nr. 21.867 / 2019",{"entities":[(0,59,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Tamina",{"entities":[(0,6,"LOC")]}),
("județul Brașov",{"entities":[(0,16,"LOC")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Societatea Comercială PILAR PROCARPATEN - S.R.L.",{"entities":[(0,49,"ORG")]}),
("Brașov",{"entities":[(0,7,"LOC")]}),
("județul Brașov",{"entities":[(0,16,"LOC")]}),
("Licența de concesionare pentru explorare nr. 21.868 / 2019",{"entities":[(0,59,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Poiana Lungă",{"entities":[(0,13,"TIME")]}),
("Gorj",{"entities":[(0,4,"LOC")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Societatea Comercială ENERGOCARB SERV - S.R.L.",{"entities":[(0,47,"ORG")]}),
("Broșteni",{"entities":[(0,9,"LOC")]}),
("Mehedinți",{"entities":[(0,10,"LOC")]}),
("Licența de concesionare pentru explorare nr. 21.869 / 2019",{"entities":[(0,59,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Valea lui Milcu",{"entities":[(0,15,"LOC")]}),
("Mehedinți",{"entities":[(0,10,"LOC")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Societatea Comercială MILARIMAR - S.R.L.",{"entities":[(0,41,"ORG")]}),
("Motru",{"entities":[(0,5,"LOC")]}),
("Gorj",{"entities":[(0,4,"LOC")]}),
("Licența de concesionare pentru explorare nr. 21.972 / 2019",{"entities":[(0,59,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Valea Pârâului",{"entities":[(0,16,"LOC")]}),
("Gorj",{"entities":[(0,4,"LOC")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Societatea Comercială Gekko & Neka Invest - S.R.L.",{"entities":[(0,51,"ORG")]}),
("Târgu Jiu",{"entities":[(0,10,"LOC")]}),
("Gorj",{"entities":[(0,4,"LOC")]}),
("RO",{"entities":[(0,2,"LOC")]}),
("08-08-2019",{"entities":[(0,10,"TIME")]}),
("ORDINUL nr. 285 din 25 iulie 2019",{"entities":[(0,33,"LAW")]}),
("25 iulie 2019",{"entities":[(0,13,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("08 august 2019",{"entities":[(0,14,"TIME")]}),
("Licența de concesionare pentru explorare nr. 21.865 / 2019",{"entities":[(0,59,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Valea Rudarului",{"entities":[(0,15,"LOC")]}),
("Gorj",{"entities":[(0,4,"LOC")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Societatea Comercială Davemicat - S.R.L.",{"entities":[(0,41,"ORG")]}),
("Târgu Jiu",{"entities":[(0,10,"LOC")]}),
("Gorj",{"entities":[(0,4,"LOC")]}),
("RO",{"entities":[(0,2,"LOC")]}),
("Licența de concesionare pentru explorare nr. 21.875 / 2019",{"entities":[(0,59,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Dealul Rusnic",{"entities":[(0,13,"LOC")]}),
("Caraș-Severin",{"entities":[(0,14,"LOC")]}),
("Agenția Națională pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Societatea Comercială Incasso Target - S.R.L.",{"entities":[(0,46,"ORG")]}),
("Arad",{"entities":[(0,4,"LOC")]}),
("județul Arad",{"entities":[(0,13,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Agenției Naționale pentru Resurse Minerale",{"entities":[(0,44,"ORG")]}),
("Gigi Dragomir",{"entities":[(0,13,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("11 iunie 2019",{"entities":[(0,13,"TIME")]}),
("ORDIN nr. 238 din 25 martie 2019",{"entities":[(0,32,"LAW")]}),
("25 martie 2019",{"entities":[(0,14,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Picătura Galicea din județul Vâlcea",{"entities":[(0,92,"ORG")]}),
("județul Vâlcea",{"entities":[(0,16,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("27 martie 2019",{"entities":[(0,14,"TIME")]}),
("Referatul de aprobare nr. 301.871 / 2019",{"entities":[(0,40,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Direcției îmbunătățiri funciare și fond funciar",{"entities":[(0,53,"ORG")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Picătura Galicea din județul Vâlcea",{"entities":[(0,92,"ORG")]}),
("județul Vâlcea",{"entities":[(0,16,"LOC")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("5 zile",{"entities":[(0,6,"TIME")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Petre Daea",{"entities":[(0,10,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("25 martie 2019",{"entities":[(0,14,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Picătura Galicea din județul Vâlcea",{"entities":[(0,92,"ORG")]}),
("județul Vâlcea",{"entities":[(0,16,"LOC")]}),
("Ordinul ministrului finanțelor publice și al ministrului delegat pentru buget nr. 668 / 2014",{"entities":[(0,94,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Agenția Națională de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizația utilizatorilor de apă pentru irigații Picătura Galicea",{"entities":[(0,70,"ORG")]}),
("Ostroveni",{"entities":[(0,9,"LOC")]}),
("Galicea",{"entities":[(0,7,"LOC")]}),
("județul Vâlcea",{"entities":[(0,16,"LOC")]}),
("Registrul național al organizațiilor de îmbunătățiri funciare cu nr. 415 din 23.03.2009",{"entities":[(0,93,"LAW")]}),
("23.03.2009",{"entities":[(0,10,"TIME")]}),
("Galicea",{"entities":[(0,7,"LOC")]}),
("județul Vâlcea",{"entities":[(0,16,"LOC")]}),
("ORDIN nr. 910 din 3 iunie 2019",{"entities":[(0,30,"LAW")]}),
("3 iunie 2019",{"entities":[(0,12,"TIME")]}),
("Ordinului ministrului transporturilor, construcțiilor și turismului nr. 2.261 / 2005",{"entities":[(0,86,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("19 iunie 2019",{"entities":[(0,13,"TIME")]}),
("Ordonanța Guvernului nr. 129 / 2000",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 1.663 / 2004",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Centrului Național de Calificare și Instruire Feroviară",{"entities":[(0,58,"ORG")]}),
("CENAFER",{"entities":[(0,7,"ORG")]}),
("Hotărârea Guvernului nr. 21 / 2015",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("Ordinul ministrului transporturilor, construcțiilor și turismului nr. 2.261 / 2005",{"entities":[(0,84,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("8 februarie 2006",{"entities":[(0,16,"TIME")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("Centrului Național de Calificare și Instruire Feroviară",{"entities":[(0,58,"ORG")]}),
("CENAFER",{"entities":[(0,7,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Dragoș-Virgil Titea",{"entities":[(0,20,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("3 iunie 2019",{"entities":[(0,12,"TIME")]}),
("Ordinul nr. 2.261 / 2005",{"entities":[(0,24,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("HOTĂRÂRE nr. 407 din 12 iunie 2019",{"entities":[(0,36,"LAW")]}),
("Hotărârea Guvernului nr. 904 / 2002",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2002",{"entities":[(0,4,"TIME")]}),
("12 iunie 2019",{"entities":[(0,13,"TIME")]}),
("județului Constanța",{"entities":[(0,21,"LOC")]}),
("județul Constanța",{"entities":[(0,19,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("21 iunie 2019",{"entities":[(0,13,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 213 / 1998",{"entities":[(0,20,"LAW")]}),
("1998",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Hotărârea Guvernului nr. 904 / 2002",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2002",{"entities":[(0,4,"TIME")]}),
("județului Constanța",{"entities":[(0,21,"LOC")]}),
("județul Constanța",{"entities":[(0,19,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("30 august 2002",{"entities":[(0,14,"TIME")]}),
("Hârșova",{"entities":[(0,9,"LOC")]}),
("Techirghiol",{"entities":[(0,11,"LOC")]}),
("Liceul Teoretic «Emil Racoviță»",{"entities":[(0,35,"ORG")]}),
("Techirghiol",{"entities":[(0,11,"LOC")]}),
("strada Nicolae Bălcescu nr. 14",{"entities":[(0,31,"LOC")]}),
("județul Constanța",{"entities":[(0,19,"LOC")]}),
("Strada Fragilor",{"entities":[(0,15,"LOC")]}),
("strada Nicolae Bălcescu",{"entities":[(0,24,"LOC")]}),
("strada Mihai Viteazu",{"entities":[(0,20,"LOC")]}),
("Techirghiol",{"entities":[(0,11,"LOC")]}),
("Hotărârea Consiliului Local Techirghiol nr. 121 / 19.06.2018",{"entities":[(0,62,"LAW")]}),
("Techirghiol",{"entities":[(0,11,"LOC")]}),
("19.06.2018",{"entities":[(0,10,"TIME")]}),
("Hotărârea nr. 15 / 15.01.2019",{"entities":[(0,31,"LAW")]}),
("15.01.2019",{"entities":[(0,10,"TIME")]}),
("Techirghiol",{"entities":[(0,11,"LOC")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Vasile-Daniel Suciu",{"entities":[(0,19,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("12 iunie 2019",{"entities":[(0,13,"TIME")]}),
("Hârșova",{"entities":[(0,9,"LOC")]}),
("Techirghiol",{"entities":[(0,11,"LOC")]}),
("REZOLUȚIE MEPC.301(72) din 13 aprilie 2018",{"entities":[(0,43,"LAW")]}),
("13 aprilie 2018",{"entities":[(0,15,"TIME")]}),
("Protocolului din 1997",{"entities":[(0,21,"LAW")]}),
("1997",{"entities":[(0,4,"TIME")]}),
("1973",{"entities":[(0,4,"TIME")]}),
("Protocolul din 1978",{"entities":[(0,19,"LAW")]}),
("1978",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("11 iunie 2019",{"entities":[(0,13,"TIME")]}),
("ORDINUL nr. 857 din 20 mai 2019",{"entities":[(0,31,"LAW")]}),
("20 mai 2019",{"entities":[(0,11,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("11 iunie 2019",{"entities":[(0,13,"TIME")]}),
("ECAs",{"entities":[(0,4,"ORG")]}),
("EEDI",{"entities":[(0,4,"ORG")]}),
("Organizației Maritime Internaționale",{"entities":[(0,38,"ORG")]}),
("1973",{"entities":[(0,4,"TIME")]}),
("Protocoalele din 1978 și 1997",{"entities":[(0,30,"LAW")]}),
("1978",{"entities":[(0,4,"TIME")]}),
("1997",{"entities":[(0,4,"TIME")]}),
("MARPOL",{"entities":[(0,6,"ORG")]}),
("MARPOL",{"entities":[(0,6,"ORG")]}),
("ECAs",{"entities":[(0,4,"ORG")]}),
("EEDI",{"entities":[(0,4,"ORG")]}),
("MARPOL",{"entities":[(0,6,"ORG")]}),
("MARPOL",{"entities":[(0,6,"ORG")]}),
("MARPOL",{"entities":[(0,6,"ORG")]}),
("1 martie 2019",{"entities":[(0,13,"TIME")]}),
("MARPOL",{"entities":[(0,6,"ORG")]}),
("1 septembrie 2019",{"entities":[(0,17,"TIME")]}),
("MARPOL",{"entities":[(0,6,"ORG")]}),
("EEDI",{"entities":[(0,4,"ORG")]}),
("MARPOL",{"entities":[(0,6,"ORG")]}),
("MARPOL",{"entities":[(0,6,"ORG")]}),
("MARPOL",{"entities":[(0,6,"ORG")]}),
("EEDI",{"entities":[(0,4,"ORG")]}),
("HOTĂRÂRE nr. 960 din 7 decembrie 2018",{"entities":[(0,39,"LAW")]}),
("7 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("municipiul Iași",{"entities":[(0,16,"LOC")]}),
("județul Iași",{"entities":[(0,14,"LOC")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("18 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 213 / 1998",{"entities":[(0,20,"LAW")]}),
("1998",{"entities":[(0,4,"TIME")]}),
("Legea nr. 287 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Codul civil",{"entities":[(0,11,"LAW")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("municipiul Iași",{"entities":[(0,16,"LOC")]}),
("județul Iași",{"entities":[(0,14,"LOC")]}),
("Hotărârii Consiliului Local al Municipiului Iași nr. 96 / 2015",{"entities":[(0,65,"LAW")]}),
("Municipiului Iași",{"entities":[(0,18,"LOC")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Hotărârea nr. 389 / 2016",{"entities":[(0,26,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Ministerul Apărării Naționale",{"entities":[(0,32,"ORG")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Nicolae Nasta",{"entities":[(0,13,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("7 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("municipiul Iași",{"entities":[(0,16,"LOC")]}),
("județul Iași",{"entities":[(0,14,"LOC")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Ordinului ministrului finanțelor publice nr. 1.718 / 2011",{"entities":[(0,58,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("HOTĂRÂRE nr. 33 din 16 ianuarie 2020",{"entities":[(0,38,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("20 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("Regulamentului (UE) nr. 1.307 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("17 decembrie 2013",{"entities":[(0,17,"TIME")]}),
("Regulamentului (CE) nr. 637 / 2008",{"entities":[(0,34,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Regulamentului (CE) nr. 73 / 2009",{"entities":[(0,33,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("16 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ordonanța de urgență a Guvernului nr. 3 / 2015",{"entities":[(0,49,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2015-2020",{"entities":[(0,9,"TIME")]}),
("Legea nr. 36 / 1991",{"entities":[(0,19,"LAW")]}),
("1991",{"entities":[(0,4,"TIME")]}),
("Legea nr. 104 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("anul 2020",{"entities":[(0,9,"TIME")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Banca Centrală Europeană",{"entities":[(0,26,"ORG")]}),
("30 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Jurnalul Oficial al Uniunii Europene",{"entities":[(0,36,"LAW")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("1 octombrie 2019",{"entities":[(0,16,"TIME")]}),
("LUDOVIC ORBAN",{"entities":[(0,13,"PER")]}),
("Florian-Emil Dumitru",{"entities":[(0,20,"PER")]}),
("Sebastian Ioan Burduja",{"entities":[(0,22,"PER")]}),
("Bogdan Lucian Aurescu",{"entities":[(0,21,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("16 ianuarie 2020",{"entities":[(0,16,"TIME")]}),
("HOTĂRÂRE nr. 323 din 23 mai 2019",{"entities":[(0,34,"LAW")]}),
("23 mai 2019",{"entities":[(0,11,"TIME")]}),
("Agenției de Plăți și Intervenție pentru Agricultură",{"entities":[(0,57,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("3 iunie 2019",{"entities":[(0,12,"TIME")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Constituția României",{"entities":[(0,22,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 213 / 1998",{"entities":[(0,20,"LAW")]}),
("1998",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Agenției de Plăți și Intervenție pentru Agricultură",{"entities":[(0,57,"ORG")]}),
("Ministerul Agriculturii și Dezvoltării Rurale",{"entities":[(0,47,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Dumitru Daniel Botănoiu",{"entities":[(0,24,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("23 mai 2019",{"entities":[(0,11,"TIME")]}),
("Agenției de Plăți și Intervenție pentru Agricultură",{"entities":[(0,57,"ORG")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Brașov",{"entities":[(0,7,"LOC")]}),
("Făgăraș",{"entities":[(0,10,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Brașov",{"entities":[(0,7,"LOC")]}),
("Făgăraș",{"entities":[(0,10,"LOC")]}),
("Str. Cetății, Nr.: 40",{"entities":[(0,23,"LOC")]}),
("Târgoviște",{"entities":[(0,12,"LOC")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Dâmbovița",{"entities":[(0,11,"LOC")]}),
("Târgoviște",{"entities":[(0,12,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Dâmbovița",{"entities":[(0,11,"LOC")]}),
("Târgoviște",{"entities":[(0,12,"LOC")]}),
("Bd. Ion C. Brătianu",{"entities":[(0,20,"LOC")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Dâmbovița",{"entities":[(0,11,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Dâmbovița",{"entities":[(0,11,"LOC")]}),
("Satul Greci",{"entities":[(0,11,"LOC")]}),
("Fetești",{"entities":[(0,8,"LOC")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Ialomița",{"entities":[(0,9,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ialomița",{"entities":[(0,9,"LOC")]}),
("Fetești",{"entities":[(0,8,"LOC")]}),
("Str. Promenadei",{"entities":[(0,15,"LOC")]}),
("Slobozia",{"entities":[(0,8,"LOC")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Ialomița",{"entities":[(0,9,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ialomița",{"entities":[(0,9,"LOC")]}),
("Slobozia",{"entities":[(0,8,"LOC")]}),
("Str. Lacului,",{"entities":[(0,13,"LOC")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Ialomița",{"entities":[(0,9,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ialomița",{"entities":[(0,9,"LOC")]}),
("Fierbinți-Târg",{"entities":[(0,16,"LOC")]}),
("Fierbinți-Târg",{"entities":[(0,16,"LOC")]}),
("Str. Silozului",{"entities":[(0,14,"LOC")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Ialomița",{"entities":[(0,9,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ialomița",{"entities":[(0,9,"LOC")]}),
("Căzănești",{"entities":[(0,12,"LOC")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Ialomița",{"entities":[(0,9,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Ialomița",{"entities":[(0,9,"LOC")]}),
("Str. Gării",{"entities":[(0,11,"LOC")]}),
("Reghin",{"entities":[(0,6,"LOC")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Mureș",{"entities":[(0,6,"LOC")]}),
("Reghin",{"entities":[(0,6,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Mureș",{"entities":[(0,6,"LOC")]}),
("Reghin",{"entities":[(0,6,"LOC")]}),
("Str. Gării",{"entities":[(0,11,"LOC")]}),
("Baia",{"entities":[(0,4,"LOC")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Tulcea",{"entities":[(0,6,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Tulcea",{"entities":[(0,6,"LOC")]}),
("HOTĂRÂRE nr. 193 din 3 aprilie 2019",{"entities":[(0,37,"LAW")]}),
("3 aprilie 2019",{"entities":[(0,14,"TIME")]}),
("Institutului Național de Sănătate Publică",{"entities":[(0,45,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Ministerului Muncii și Justiției Sociale",{"entities":[(0,42,"ORG")]}),
("Casa Națională de Pensii Publice",{"entities":[(0,34,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("10 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("Legea nr. 287 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Codul civil",{"entities":[(0,11,"LAW")]}),
("Legea nr. 213 / 1998",{"entities":[(0,20,"LAW")]}),
("1998",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Institutului Național de Sănătate Publică",{"entities":[(0,45,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Institutului Național de Sănătate Publică",{"entities":[(0,45,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Ministerului Muncii și Justiției Sociale",{"entities":[(0,42,"ORG")]}),
("Casa Națională de Pensii Publice",{"entities":[(0,34,"ORG")]}),
("Institutului Național de Sănătate Publică",{"entities":[(0,45,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("60 de zile",{"entities":[(0,10,"TIME")]}),
("Casa Națională de Pensii Publice",{"entities":[(0,34,"ORG")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("Ministerul Muncii și Justiției Sociale",{"entities":[(0,40,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("iberius-Marius Brădățan",{"entities":[(0,26,"PER")]}),
("Adrian Marius Rîndunică",{"entities":[(0,25,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("3 aprilie 2019",{"entities":[(0,14,"TIME")]}),
("Institutului Național de Sănătate Publică",{"entities":[(0,45,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Institutului Național de Sănătate Publică",{"entities":[(0,45,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Ministerului Muncii și Justiției Sociale",{"entities":[(0,42,"ORG")]}),
("Casa Națională de Pensii Publice",{"entities":[(0,34,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("NORMĂ nr. 3 din 18 februarie 2019",{"entities":[(0,34,"LAW")]}),
("18 februarie 2019",{"entities":[(0,17,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("28 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Legea nr. 411 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 50 / 2005",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("Comisiei de Supraveghere a Sistemului de Pensii Private",{"entities":[(0,55,"ORG")]}),
("Legea nr. 313 / 2005",{"entities":[(0,20,"LAW")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 93 / 2012",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Autorității de Supraveghere Financiară",{"entities":[(0,41,"ORG")]}),
("Legea nr. 113 / 2013",{"entities":[(0,20,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Autorității de Supraveghere Financiară",{"entities":[(0,41,"ORG")]}),
("6.02.2019",{"entities":[(0,9,"TIME")]}),
("Autoritatea de Supraveghere Financiară",{"entities":[(0,39,"ORG")]}),
("Legea nr. 411 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Lege",{"entities":[(0,4,"LAW")]}),
("Lege",{"entities":[(0,4,"LAW")]}),
("Casei Naționale de Pensii Publice",{"entities":[(0,34,"ORG")]}),
("5 zile",{"entities":[(0,6,"TIME")]}),
("data de 25 a lunii",{"entities":[(0,18,"TIME")]}),
("Lege",{"entities":[(0,4,"LAW")]}),
("Lege",{"entities":[(0,4,"LAW")]}),
("Autoritatea de Supraveghere Financiară",{"entities":[(0,39,"ORG")]}),
("Comisia Națională de Strategie și Prognoză",{"entities":[(0,46,"ORG")]}),
("ianuarie 2019",{"entities":[(0,13,"TIME")]}),
("Lege",{"entities":[(0,4,"LAW")]}),
("Ordonanței de urgență a Guvernului nr. 114 / 2018",{"entities":[(0,52,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Autorității de Supraveghere Financiară",{"entities":[(0,41,"ORG")]}),
("Leonardo Badea",{"entities":[(0,14,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("18 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Lege",{"entities":[(0,4,"LAW")]}),
("ORDIN nr. 1.608 din 27 decembrie 2018",{"entities":[(0,37,"LAW")]}),
("27 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Normelor tehnice de realizare a programelor naționale de sănătate curative pentru anii 2017 și 2018",{"entities":[(0,103,"LAW")]}),
("anii 2017 și 2018",{"entities":[(0,18,"TIME")]}),
("Ordinul președintelui Casei Naționale de Asigurări de Sănătate nr. 245 / 2017",{"entities":[(0,82,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("28 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Referatul de aprobare nr. D.G. 5.586 / 27.12.2018",{"entities":[(0,49,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 155 / 2017",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("anii 2017 și 2018",{"entities":[(0,18,"TIME")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Statutul Casei Naționale de Asigurări de Sănătate",{"entities":[(0,53,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Hotărârea Guvernului nr. 972 / 2006",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Normele tehnice de realizare a programelor naționale de sănătate curative pentru anii 2017 și 2018",{"entities":[(0,102,"LAW")]}),
("anii 2017 și 2018",{"entities":[(0,18,"TIME")]}),
("Ordinul președintelui Casei Naționale de Asigurări de Sănătate nr. 245 / 2017",{"entities":[(0,82,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("31 martie 2017",{"entities":[(0,14,"TIME")]}),
("anul 2018",{"entities":[(0,9,"TIME")]}),
("ianuarie 2019",{"entities":[(0,13,"TIME")]}),
("ianuarie 2019",{"entities":[(0,13,"TIME")]}),
("ianuarie 2019",{"entities":[(0,13,"TIME")]}),
("Casa Națională de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("casele de asigurări de sănătate",{"entities":[(0,34,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Liliana-Maria Mihai",{"entities":[(0,19,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("27 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("HOTĂRÂRE nr. 795 din 4 noiembrie 2019",{"entities":[(0,39,"LAW")]}),
("4 noiembrie 2019",{"entities":[(0,16,"TIME")]}),
("Hotărârea Guvernului nr. 1.357 / 2001",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2001",{"entities":[(0,4,"TIME")]}),
("județului Suceava",{"entities":[(0,18,"LOC")]}),
("județul Suceava",{"entities":[(0,16,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("6 noiembrie 2019",{"entities":[(0,16,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("Ordonanța de urgență a Guvernului nr. 57 / 2019",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Hotărârea Guvernului nr. 1.357 / 2001",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2001",{"entities":[(0,4,"TIME")]}),
("județului Suceava",{"entities":[(0,18,"LOC")]}),
("județul Suceava",{"entities":[(0,16,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("30 august 2002",{"entities":[(0,14,"TIME")]}),
("localitatea Mestecăniș",{"entities":[(0,24,"LOC")]}),
("Strada Fermierilor nr. 14",{"entities":[(0,25,"LOC")]}),
("Strada Fermierilo",{"entities":[(0,17,"LOC")]}),
("proprietate particulară și comuna Iacobeni",{"entities":[(0,44,"LOC")]}),
("comuna Iacobeni",{"entities":[(0,15,"LOC")]}),
("Hotărârea Consiliului Local al Comunei Iacobeni nr. 21 / 08.04.2019",{"entities":[(0,69,"LAW")]}),
("Comunei Iacobeni",{"entities":[(0,16,"LOC")]}),
("08.04.2019",{"entities":[(0,10,"TIME")]}),
("cartea funciară nr. 31614 Iacobeni",{"entities":[(0,35,"LAW")]}),
("Iacobeni",{"entities":[(0,8,"LOC")]}),
("localitatea Mestecăniș",{"entities":[(0,24,"LOC")]}),
("Strada Fermierilor nr. 14",{"entities":[(0,25,"LOC")]}),
("Strada Fermierilo",{"entities":[(0,17,"LOC")]}),
("proprietate particulară și comuna Iacobeni",{"entities":[(0,44,"LOC")]}),
("comuna Iacobeni",{"entities":[(0,15,"LOC")]}),
("1995",{"entities":[(0,4,"TIME")]}),
("Hotărârea Consiliului Local al Comunei Iacobeni nr. 21 / 08.04.2019",{"entities":[(0,69,"LAW")]}),
("Consiliului Local al Comunei Iacobeni",{"entities":[(0,37,"ORG")]}),
("Comunei Iacobeni",{"entities":[(0,16,"LOC")]}),
("21 / 08.04.2019",{"entities":[(0,15,"TIME")]}),
("cartea funciară nr. 31614 Iacobeni",{"entities":[(0,35,"LAW")]}),
("Iacobeni",{"entities":[(0,8,"LOC")]}),
("Consiliului Local al Comunei Iacobeni",{"entities":[(0,37,"ORG")]}),
("Vicovu de Sus",{"entities":[(0,13,"LOC")]}),
("comunei Coșna",{"entities":[(0,14,"LOC")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Vasile-Daniel Suciu",{"entities":[(0,19,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("4 noiembrie 2019",{"entities":[(0,16,"TIME")]}),
("comunei Coșna",{"entities":[(0,14,"LOC")]}),
("comunei Coșna",{"entities":[(0,14,"LOC")]}),
("Hotărârii Consiliului Local nr. 31 / 2019",{"entities":[(0,43,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("RAPORT nr. 17.432 din 17 decembrie 2018",{"entities":[(0,39,"LAW")]}),
("17 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Autoritatea Electorală Permanentă",{"entities":[(0,35,"ORG")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("5 iunie 2019",{"entities":[(0,12,"TIME")]}),
("Legea nr. 334 / 2006",{"entities":[(0,20,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("anul 2018",{"entities":[(0,9,"TIME")]}),
("Autorității Electorale Permanente",{"entities":[(0,35,"ORG")]}),
("16.04.2018",{"entities":[(0,10,"TIME")]}),
("27.04.2018",{"entities":[(0,10,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("1.01.2015",{"entities":[(0,9,"TIME")]}),
("31.12.2017",{"entities":[(0,10,"TIME")]}),
("1.01.2015",{"entities":[(0,9,"TIME")]}),
("31.12.2015",{"entities":[(0,10,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("31.12.2015",{"entities":[(0,10,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("31.12.2015",{"entities":[(0,10,"TIME")]}),
("decembrie 2015",{"entities":[(0,14,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("anul 2015",{"entities":[(0,9,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("31.12.2015",{"entities":[(0,10,"TIME")]}),
("Agenția Națională de Administrare Fiscală",{"entities":[(0,45,"ORG")]}),
("Direcția Generală Regională a Finanțelor Publice București Sector 1",{"entities":[(0,72,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Sector 1",{"entities":[(0,8,"LOC")]}),
("1.01.2016",{"entities":[(0,9,"TIME")]}),
("31.12.2016",{"entities":[(0,10,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("31.12.2016",{"entities":[(0,10,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("31.12.2016",{"entities":[(0,10,"TIME")]}),
("decembrie 2015",{"entities":[(0,14,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("anul 2016",{"entities":[(0,9,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("31.12.2016",{"entities":[(0,10,"TIME")]}),
("Agenția Națională de Administrare Fiscală",{"entities":[(0,45,"ORG")]}),
("Direcția Generală Regională a Finanțelor Publice București Sector 1",{"entities":[(0,72,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Sector 1",{"entities":[(0,8,"LOC")]}),
("1.01.2017",{"entities":[(0,9,"TIME")]}),
("31.12.2017",{"entities":[(0,10,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("31.12.2017",{"entities":[(0,10,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("31.12.2017",{"entities":[(0,10,"TIME")]}),
("decembrie 2015",{"entities":[(0,14,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("anul 2017",{"entities":[(0,9,"TIME")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("31.12.2017",{"entities":[(0,10,"TIME")]}),
("Agenția Națională de Administrare Fiscală",{"entities":[(0,45,"ORG")]}),
("Direcția Generală Regională a Finanțelor Publice București Sector 1",{"entities":[(0,72,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Sector 1",{"entities":[(0,8,"LOC")]}),
("Partidul România Mare",{"entities":[(0,22,"ORG")]}),
("Legea nr. 334 / 2006",{"entities":[(0,20,"LAW")]}),
("Autorității Electorale Permanente",{"entities":[(0,35,"ORG")]}),
("2015-2017",{"entities":[(0,9,"TIME")]}),
("2015-2017",{"entities":[(0,9,"TIME")]}),
("anul 2018",{"entities":[(0,9,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legii nr. 334 / 2006",{"entities":[(0,20,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("București",{"entities":[(0,10,"LOC")]}),
("17 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("RAPORT din 15 iulie 2019",{"entities":[(0,24,"LAW")]}),
("15 iulie 2019",{"entities":[(0,13,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Parlamentul European",{"entities":[(0,20,"ORG")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("Autoritatea Electorală Permanentă",{"entities":[(0,35,"ORG")]}),
("Legea nr. 334 / 2006",{"entities":[(0,20,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Partidul Alianța Liberalilor și Democraților",{"entities":[(0,47,"ORG")]}),
("ALDE",{"entities":[(0,4,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("15 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Partidul Alianța Liberalilor și Democraților",{"entities":[(0,47,"ORG")]}),
("ALDE",{"entities":[(0,4,"ORG")]}),
("26 mai 2019",{"entities":[(0,11,"TIME")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Badea Andrei Alexandru",{"entities":[(0,22,"PER")]}),
("Barbu Daniel Constantin",{"entities":[(0,23,"PER")]}),
("Barbu Daniel Constantin",{"entities":[(0,23,"PER")]}),
("Bujac Razvan Alexandru",{"entities":[(0,22,"PER")]}),
("Corches Dorin Octavian",{"entities":[(0,22,"PER")]}),
("Daraban Gabriel",{"entities":[(0,15,"PER")]}),
("Deaconu Alexandru Stefan",{"entities":[(0,24,"PER")]}),
("Eduard Luca",{"entities":[(0,11,"PER")]}),
("Gerea Andrei Dominic",{"entities":[(0,20,"PER")]}),
("Gherman Dan Nicolae",{"entities":[(0,19,"PER")]}),
("Gurghian Alexandru",{"entities":[(0,18,"PER")]}),
("Hristea Robert Iulian",{"entities":[(0,21,"PER")]}),
("Husanu Mihaela",{"entities":[(0,14,"PER")]}),
("Husanu Mihaela",{"entities":[(0,14,"PER")]}),
("Ionescu Tudor Tim",{"entities":[(0,17,"PER")]}),
("Mina-Draghici Oana Alexandra",{"entities":[(0,28,"PER")]}),
("Muscalu Ionel",{"entities":[(0,13,"PER")]}),
("Nazaruk Christopher Raphael",{"entities":[(0,27,"PER")]}),
("Norica Nicolai",{"entities":[(0,14,"PER")]}),
("Ovidiu Ioan Silaghi",{"entities":[(0,19,"PER")]}),
("Ovidiu-Marcel Sirbu",{"entities":[(0,19,"PER")]}),
("Pistru Popa Eusebiu-Manea",{"entities":[(0,25,"PER")]}),
("Punga Nicolae",{"entities":[(0,13,"PER")]}),
("Renate Weber",{"entities":[(0,12,"PER")]}),
("Renate Weber",{"entities":[(0,12,"PER")]}),
("Rosca Alexandra Raluca",{"entities":[(0,22,"PER")]}),
("Rosu-Mares Claudiu-Sorin",{"entities":[(0,24,"PER")]}),
("Ruscea Lia Ruxandra",{"entities":[(0,19,"PER")]}),
("Stoica Emilian Marian",{"entities":[(0,21,"PER")]}),
("Tiriteu Stefan-Ioan",{"entities":[(0,19,"PER")]}),
("Toma Horia Victor",{"entities":[(0,17,"PER")]}),
("Tudorache Iulian Robert",{"entities":[(0,23,"PER")]}),
("Umbrarescu Stefan-Sorin",{"entities":[(0,23,"PER")]}),
("Voicu Constantin",{"entities":[(0,16,"PER")]}),
("Vosganian Varujan",{"entities":[(0,17,"PER")]}),
("Vosganian Varujan",{"entities":[(0,17,"PER")]}),
("11.06.2019",{"entities":[(0,10,"TIME")]}),
("Burcescu Marian Catalin",{"entities":[(0,23,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("ORDIN nr. 281 din 18 aprilie 2019",{"entities":[(0,33,"LAW")]}),
("18 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Ordinul ministrului agriculturii și dezvoltării rurale nr. 266 / 2017",{"entities":[(0,71,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Referatul de aprobare al Oficiului Național al Viei și Produselor Vitivinicole (O.N.V.P.V.) nr. 838 din 9.04.2019",{"entities":[(0,115,"LAW")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("23 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("9.04.2019",{"entities":[(0,9,"TIME")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("Ordinul ministrului agriculturii și dezvoltării rurale nr. 266 / 2017",{"entities":[(0,71,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("3 august 2017",{"entities":[(0,13,"TIME")]}),
("1 iunie",{"entities":[(0,7,"TIME")]}),
("1 octombrie",{"entities":[(0,11,"TIME")]}),
("1 octombrie",{"entities":[(0,11,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Petre Daea",{"entities":[(0,10,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("18 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("ORDIN nr. 1.362 din 28 decembrie 2018",{"entities":[(0,37,"LAW")]}),
("28 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("15 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Referatul de aprobare nr. 93.441 / DGDSCSP din 6 septembrie 2018",{"entities":[(0,64,"LAW")]}),
("6 septembrie 2018",{"entities":[(0,17,"TIME")]}),
("Legea nr. 249 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 19 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Mediului",{"entities":[(0,21,"ORG")]}),
("Legea nr. 249 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Comisia de supraveghere a răspunderii extinse a producătorilor",{"entities":[(0,64,"ORG")]}),
("Legea nr. 211 / 2011",{"entities":[(0,20,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Legea nr. 249 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ministerului Mediului",{"entities":[(0,21,"ORG")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("Comisia",{"entities":[(0,7,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 74 / 2018",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Legii nr. 211 / 2011",{"entities":[(0,20,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Legii nr. 249 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 196 / 2005",{"entities":[(0,52,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("Legea nr. 249 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 196 / 2005",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("Legea nr. 105 / 2006",{"entities":[(0,20,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 74 / 2018",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 74 / 2018",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("90 de zile",{"entities":[(0,10,"TIME")]}),
("Administrația Fondului pentru Mediu",{"entities":[(0,36,"ORG")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("15 septembrie",{"entities":[(0,13,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("ministrul mediului",{"entities":[(0,18,"ORG")]}),
("Laurențiu Adrian Neculaescu,",{"entities":[(0,29,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("28 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("ORDIN nr. 568 din 5 decembrie 2019",{"entities":[(0,34,"LAW")]}),
("5 decembrie 2019",{"entities":[(0,16,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("13 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("Referatul de aprobare nr. 17.209 din 26.11.2019",{"entities":[(0,47,"LAW")]}),
("26.11.2019",{"entities":[(0,10,"TIME")]}),
("Autoritatea Națională Fitosanitară",{"entities":[(0,37,"ORG")]}),
("Legea nr. 139 / 2014",{"entities":[(0,20,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 43 / 2015",{"entities":[(0,36,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Autorității Naționale Fitosanitare",{"entities":[(0,37,"ORG")]}),
("Hotărârea nr. 30 / 2017",{"entities":[(0,25,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("Autorității Naționale Fitosanitare",{"entities":[(0,37,"ORG")]}),
("Autorității Naționale Fitosanitare",{"entities":[(0,37,"ORG")]}),
("Autoritatea Națională Fitosanitară",{"entities":[(0,37,"ORG")]}),
("Ordinul ministrului agriculturii și dezvoltării rurale nr. 837 / 2016",{"entities":[(0,71,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("6 iulie 2016",{"entities":[(0,12,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Nechita-Adrian Oros",{"entities":[(0,19,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("5 decembrie 2019",{"entities":[(0,16,"TIME")]}),
("HOTĂRÂRE nr. 2 / H din 26 septembrie 2019",{"entities":[(0,43,"LAW")]}),
("26 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("27 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Legea nr. 370 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Legea nr. 370 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Legea nr. 370 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Camerele Parlamentului",{"entities":[(0,22,"ORG")]}),
("Parlamentul",{"entities":[(0,11,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 370 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Curții Constituționale",{"entities":[(0,24,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("biroul electoral pentru secțiile de votare din străinătate",{"entities":[(0,61,"ORG")]}),
("biroului electoral pentru secțiile de votare din străinătate",{"entities":[(0,63,"ORG")]}),
("birourilor electorale ale secțiilor de votare din țară și străinătate",{"entities":[(0,75,"ORG")]}),
("birourile electorale județene",{"entities":[(0,30,"ORG")]}),
("birourile electorale ale sectoarelor municipiului București",{"entities":[(0,60,"ORG")]}),
("birourile electorale ale secțiilor de votare",{"entities":[(0,45,"ORG")]}),
("Biroul Electoral Central",{"entities":[(0,24,"ORG")]}),
("Legea nr. 370 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Camerele Parlamentului",{"entities":[(0,22,"ORG")]}),
("Parlamentul",{"entities":[(0,11,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Biroului Electoral Central",{"entities":[(0,26,"ORG")]}),
("Adina-Georgeta Nicolae",{"entities":[(0,22,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("26 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("ORDIN nr. 4.887 / C din 22 noiembrie 2019",{"entities":[(0,41,"LAW")]}),
("22 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("Ministerului Justiției",{"entities":[(0,23,"ORG")]}),
("Ordinul ministrului justiției nr. 927 / C/2006",{"entities":[(0,47,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("2 decembrie 2019",{"entities":[(0,16,"TIME")]}),
("Decizia nr. 5 din 22.10.2018",{"entities":[(0,28,"LAW")]}),
("22.10.2018",{"entities":[(0,10,"TIME")]}),
("Curții de Conturi",{"entities":[(0,18,"ORG")]}),
("Nota internă nr. 16 / 48.065 din 15.11.2018",{"entities":[(0,44,"LAW")]}),
("15.11.2018",{"entities":[(0,10,"TIME")]}),
("Legea locuinței nr. 114 / 1996",{"entities":[(0,31,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 652 / 2009",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Ministerului Justiției",{"entities":[(0,23,"ORG")]}),
("Ministerului Justiției",{"entities":[(0,23,"ORG")]}),
("Ordinul ministrului justiției nr. 927 / C/2006",{"entities":[(0,47,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("17 aprilie 2006",{"entities":[(0,15,"TIME")]}),
("Legea locuinței nr. 114 / 1996",{"entities":[(0,31,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("5 zile",{"entities":[(0,6,"TIME")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Direcției financiar-contabile",{"entities":[(0,30,"ORG")]}),
("Ministerul Justiției",{"entities":[(0,21,"ORG")]}),
("Legea locuinței nr. 114 / 1996",{"entities":[(0,31,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Marian Cătălin Predoiu",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("22 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("HOTĂRÂRE nr. 549 din 31 iulie 2019",{"entities":[(0,36,"LAW")]}),
("31 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("Galați",{"entities":[(0,7,"LOC")]}),
("Galați",{"entities":[(0,7,"LOC")]}),
("Tulcea",{"entities":[(0,6,"LOC")]}),
("Brăila",{"entities":[(0,7,"LOC")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("6 august 2019",{"entities":[(0,13,"TIME")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("Ordonanța de urgență a Guvernului nr. 57 / 2019",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Portul Docuri Galați",{"entities":[(0,21,"LOC")]}),
("Portul Bazinul Nou Galați",{"entities":[(0,26,"LOC")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("Companiei Naționale  Administrația Porturilor Dunării Maritime  - S.A. Galați",{"entities":[(0,81,"ORG")]}),
("Galați",{"entities":[(0,7,"LOC")]}),
("Companiei Naționale  Administrația Porturilor Dunării Maritime  - S.A. Galaț",{"entities":[(0,80,"ORG")]}),
("Tulcea",{"entities":[(0,6,"LOC")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("Companiei Naționale  Administrația Porturilor Dunării Maritime  - S.A. Galați",{"entities":[(0,81,"ORG")]}),
("Galați",{"entities":[(0,7,"LOC")]}),
("Brăila",{"entities":[(0,7,"LOC")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("Companiei Naționale  Administrația Porturilor Dunării Maritime  - S.A. Galați",{"entities":[(0,81,"ORG")]}),
("Galați",{"entities":[(0,7,"LOC")]}),
("Ministerul Transporturilor",{"entities":[(0,26,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Alexandru-Răzvan Cuc",{"entities":[(0,21,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("31 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Companiei Naționale  Administrația Porturilor Dunării Maritime  - S.A. Galați",{"entities":[(0,81,"ORG")]}),
("Galați",{"entities":[(0,7,"LOC")]}),
("Ministerul Transporturilor",{"entities":[(0,26,"ORG")]}),
("Compania Națională  Administrația Porturilor Dunării Maritime  - S.A. Galați",{"entities":[(0,81,"ORG")]}),
("Galați",{"entities":[(0,7,"LOC")]}),
("Companiei Naționale  Administrația Porturilor Dunării Maritime  - S.A. Galați",{"entities":[(0,81,"ORG")]}),
("Galați",{"entities":[(0,7,"LOC")]}),
("Ministerul Transporturilor",{"entities":[(0,26,"ORG")]}),
("Compania Națională  Administrația Porturilor Dunării Maritime  - S.A. Galați",{"entities":[(0,81,"ORG")]}),
("Galați",{"entities":[(0,7,"LOC")]}),
("Companiei Naționale  Administrația Porturilor Dunării Maritime  - S.A. Galați",{"entities":[(0,81,"ORG")]}),
("Galați",{"entities":[(0,7,"LOC")]}),
("Ministerul Transporturilor",{"entities":[(0,26,"ORG")]}),
("Compania Națională  Administrația Porturilor Dunării Maritime  - S.A. Galați",{"entities":[(0,81,"ORG")]}),
("Galați",{"entities":[(0,7,"LOC")]}),
("LEGE nr. 211 din 11 noiembrie 2019",{"entities":[(0,34,"LAW")]}),
("11 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("Decretul-lege nr. 118 / 1990",{"entities":[(0,28,"LAW")]}),
("1990",{"entities":[(0,4,"TIME")]}),
("6 martie 1945",{"entities":[(0,13,"TIME")]}),
("Ordonanței Guvernului nr. 105 / 1999",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("1999",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("6 septembrie 1940",{"entities":[(0,17,"TIME")]}),
("6 martie 1945",{"entities":[(0,13,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"LAW")]}),
("12 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("Parlamentul",{"entities":[(0,11,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("6 martie 1945",{"entities":[(0,13,"TIME")]}),
("Decretul-lege nr. 118 / 1990",{"entities":[(0,28,"LAW")]}),
("1990",{"entities":[(0,4,"TIME")]}),
("23 septembrie 2009",{"entities":[(0,18,"TIME")]}),
("Agențiile județene de plată și inspecție socială",{"entities":[(0,54,"ORG")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Ordonanța Guvernului nr. 105 / 1999",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("1999",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("6 septembrie 1940",{"entities":[(0,17,"TIME")]}),
("6 martie 1945",{"entities":[(0,13,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("31 august 1999",{"entities":[(0,14,"TIME")]}),
("Legea nr. 189 / 2000",{"entities":[(0,20,"LAW")]}),
("Legii contenciosului administrativ nr. 554 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("1 ianuarie 2020",{"entities":[(0,15,"TIME")]}),
("Ordonanța Guvernului nr. 105 / 1999",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("1999",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("6 septembrie 1940",{"entities":[(0,17,"TIME")]}),
("6 martie 1945",{"entities":[(0,13,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("31 august 1999",{"entities":[(0,14,"TIME")]}),
("Legea nr. 189 / 2000",{"entities":[(0,20,"LAW")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Parlamentul",{"entities":[(0,11,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("CAMEREI DEPUTAȚILOR",{"entities":[(0,20,"ORG")]}),
("ION-MARCEL CIOLACU",{"entities":[(0,18,"PER")]}),
("SENATULUI",{"entities":[(0,9,"ORG")]}),
("TEODOR-VIOREL MELEȘCANU",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("11 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("ORDIN nr. 1.106 din 29 noiembrie 2019",{"entities":[(0,37,"LAW")]}),
("Ordinul președintelui Casei Naționale de Asigurări de Sănătate nr. 245 / 2017",{"entities":[(0,82,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("29 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("Referatul de aprobare nr. DG 1.657 din 29.11.2019",{"entities":[(0,49,"LAW")]}),
("29.11.2019",{"entities":[(0,10,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 155 / 2017",{"entities":[(0,37,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 440 / 2019",{"entities":[(0,37,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Hotărârii Guvernului nr. 155 / 2017",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Statutul Casei Naționale de Asigurări de Sănătate",{"entities":[(0,53,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Hotărârea Guvernului nr. 972 / 2006",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Normelor tehnice de realizare a programelor naționale de sănătate curative pentru anii 2017 și 2018",{"entities":[(0,103,"LAW")]}),
("Normele tehnice de realizare a programelor naționale de sănătate curative pentru anii 2017 și 2018",{"entities":[(0,102,"LAW")]}),
("Ordinul președintelui Casei Naționale de Asigurări de Sănătate nr. 245 / 2017",{"entities":[(0,82,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("31 martie 2017",{"entities":[(0,14,"TIME")]}),
("anii 2017 și 2018",{"entities":[(0,18,"TIME")]}),
("anii 2017 și 2018",{"entities":[(0,18,"TIME")]}),
("anii 2017 și 2018",{"entities":[(0,18,"TIME")]}),
("an 2019",{"entities":[(0,7,"TIME")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("an 2019",{"entities":[(0,7,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Adela Cojan",{"entities":[(0,11,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("29 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("anul 2019",{"entities":[(0,9,"TIME")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("ORDIN nr. 512 din 14 februarie 2019",{"entities":[(0,35,"LAW")]}),
("14 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Ordinul ministrului transporturilor și infrastructurii nr. 1.305 / 2012",{"entities":[(0,72,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Regia Autonomă  Autoritatea Aeronautică Civilă Română ",{"entities":[(0,59,"ORG")]}),
("Ministerul Transporturilor și Infrastructurii",{"entities":[(0,46,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("22 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Referatul Direcției transport aerian nr. 49.137 din 15.01.2019",{"entities":[(0,63,"LAW")]}),
("15.01.2019",{"entities":[(0,10,"TIME")]}),
("Direcției transport aerian",{"entities":[(0,27,"ORG")]}),
("Hotărârea Consiliului de administrație al Autorității Aeronautice Civile Române nr. 19 din 5.12.2018",{"entities":[(0,106,"LAW")]}),
("Consiliului de administrație al Autorității Aeronautice Civile Române",{"entities":[(0,73,"ORG")]}),
("5.12.2018",{"entities":[(0,9,"TIME")]}),
("Ordonanța Guvernului nr. 29 / 1997",{"entities":[(0,35,"LAW")]}),
("1997",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Codul aerian civil",{"entities":[(0,18,"LAW")]}),
("Hotărârea Guvernului nr. 21 / 2015",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ministerului Transporturilor",{"entities":[(0,28,"ORG")]}),
("ordinul ministrului transporturilor și infrastructurii nr. 1.305 / 2012",{"entities":[(0,72,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Regia Autonomă  Autoritatea Aeronautică Civilă Română ",{"entities":[(0,59,"ORG")]}),
("Ministerul Transporturilor și Infrastructurii",{"entities":[(0,46,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("27 august 2012",{"entities":[(0,14,"TIME")]}),
("AACR",{"entities":[(0,4,"ORG")]}),
("AACR",{"entities":[(0,4,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Rovana Plumb",{"entities":[(0,12,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("14 februarie 2019",{"entities":[(0,17,"TIME")]}),
("ORDIN nr. 1.632 din 26 noiembrie 2018",{"entities":[(0,37,"LAW")]}),
("26 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("județul Gorj",{"entities":[(0,13,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("18 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Legea cadastrului și a publicității imobiliare nr. 7 / 1996",{"entities":[(0,62,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Legea cadastrului și a publicității imobiliare nr. 7 / 1996",{"entities":[(0,62,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Agenției Naționale de Cadastru și Publicitate Imobiliară",{"entities":[(0,60,"ORG")]}),
("județul Gorj",{"entities":[(0,13,"LOC")]}),
("Arcani",{"entities":[(0,6,"LOC")]}),
("Baia de Fier",{"entities":[(0,12,"LOC")]}),
("Bălești",{"entities":[(0,9,"LOC")]}),
("Bolboși",{"entities":[(0,8,"LOC")]}),
("Brănești",{"entities":[(0,10,"LOC")]}),
("Bumbești-Pițic",{"entities":[(0,16,"LOC")]}),
("Căpreni",{"entities":[(0,8,"LOC")]}),
("Glogova",{"entities":[(0,7,"LOC")]}),
("Godinești",{"entities":[(0,10,"LOC")]}),
("Lelești",{"entities":[(0,8,"LOC")]}),
("Novaci",{"entities":[(0,6,"LOC")]}),
("Polovragi",{"entities":[(0,9,"LOC")]}),
("Roșia de Amaradia",{"entities":[(0,18,"LOC")]}),
("Săulești",{"entities":[(0,10,"LOC")]}),
("Târgu Cărbunești",{"entities":[(0,19,"LOC")]}),
("Tismana",{"entities":[(0,7,"LOC")]}),
("Țicleni",{"entities":[(0,8,"LOC")]}),
("Turcinești",{"entities":[(0,11,"LOC")]}),
("Urdari",{"entities":[(0,6,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Agenției Naționale de Cadastru și Publicitate Imobiliară",{"entities":[(0,60,"ORG")]}),
("Radu-Codruț Ștefănescu",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("26 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("HOTĂRÂRE nr. 219 din 10 aprilie 2019",{"entities":[(0,38,"LAW")]}),
("Hotărârii Guvernului nr. 296 / 2016",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("15 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("Ordonanța Guvernului nr. 11 / 2009",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Legea nr. 31 / 2010",{"entities":[(0,19,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Hotărârea Guvernului nr. 296 / 2016",{"entities":[(0,37,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("26 aprilie 2016",{"entities":[(0,15,"TIME")]}),
("Ministerul Sănătății",{"entities":[(0,24,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("2020",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Sorina Pintea",{"entities":[(0,13,"PER")]}),
("Rovana Plumb",{"entities":[(0,12,"PER")]}),
("Daniela Pescaru",{"entities":[(0,15,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("10 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Hotărârea Guvernului nr. 296 / 2016",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("COMUNICAT din 18 decembrie 2018",{"entities":[(0,31,"LAW")]}),
("18 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Decizia nr. 52 din 18 iunie 2018",{"entities":[(0,32,"LAW")]}),
("18 iunie 2018",{"entities":[(0,13,"TIME")]}),
("Înalta Curte de Casație și Justiție",{"entities":[(0,39,"ORG")]}),
("18 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Curții Constituționale",{"entities":[(0,24,"ORG")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 47 / 1992",{"entities":[(0,19,"LAW")]}),
("1992",{"entities":[(0,4,"TIME")]}),
("Curții Constituționale",{"entities":[(0,24,"ORG")]}),
("Codul de procedură civilă",{"entities":[(0,27,"LAW")]}),
("Decizia nr. 52 din 18 iunie 2018",{"entities":[(0,32,"LAW")]}),
("18 iunie 2018",{"entities":[(0,13,"TIME")]}),
("Înalta Curte de Casație și Justiție",{"entities":[(0,39,"ORG")]}),
("Legea nr. 2 / 2013",{"entities":[(0,18,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Legii nr. 134 / 2010",{"entities":[(0,20,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Codul de procedură civilă",{"entities":[(0,27,"LAW")]}),
("Codul de procedură civilă",{"entities":[(0,27,"LAW")]}),
("Codul de procedură civilă",{"entities":[(0,27,"LAW")]}),
("Legea nr. 2 / 2013",{"entities":[(0,18,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("31 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Legea nr. 134 / 2010",{"entities":[(0,20,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Codul de procedură civilă",{"entities":[(0,27,"LAW")]}),
("Codul de procedură civilă",{"entities":[(0,27,"LAW")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Codul de procedură civilă",{"entities":[(0,27,"LAW")]}),
("Decizia nr. 52 din 18 iunie 2018",{"entities":[(0,32,"LAW")]}),
("18 iunie 2018",{"entities":[(0,13,"TIME")]}),
("Înalta Curte de Casație și Justiție",{"entities":[(0,39,"ORG")]}),
("Legea nr. 2 / 2013",{"entities":[(0,18,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Legii nr. 134 / 2010",{"entities":[(0,20,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Codul de procedură civilă",{"entities":[(0,27,"LAW")]}),
("Codul de procedură civilă",{"entities":[(0,27,"LAW")]}),
("Curtea",{"entities":[(0,6,"ORG")]}),
("Codul de procedură civilă",{"entities":[(0,27,"ORG")]}),
("Decizia nr. 52 din 18 iunie 2018",{"entities":[(0,32,"LAW")]}),
("18 iunie 2018",{"entities":[(0,13,"TIME")]}),
("Înalta Curte de Casație și Justiție",{"entities":[(0,39,"ORG")]}),
("Decizia nr. 369 din 30 mai 2017",{"entities":[(0,31,"LAW")]}),
("30 mai 2017",{"entities":[(0,11,"TIME")]}),
("Constituție",{"entities":[(0,12,"LAW")]}),
("Curții Constițutionale",{"entities":[(0,24,"ORG")]}),
("Curtea",{"entities":[(0,6,"ORG")]}),
("Curții Constituționale",{"entities":[(0,24,"ORG")]}),
("Camere ale Parlamentului",{"entities":[(0,24,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Curtea Constituțională",{"entities":[(0,24,"ORG")]}),
("Curții de Apel Alba Iulia",{"entities":[(0,26,"ORG")]}),
("Alba Iulia",{"entities":[(0,10,"LOC")]}),
("Curții de Apel Brașov",{"entities":[(0,23,"ORG")]}),
("Brașov",{"entities":[(0,7,"LOC")]}),
("Curții de Apel Craiova",{"entities":[(0,23,"ORG")]}),
("Craiova",{"entities":[(0,7,"LOC")]}),
("Timișoara",{"entities":[(0,10,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Oradea",{"entities":[(0,6,"LOC")]}),
("Curții de Apel Timișoara",{"entities":[(0,26,"ORG")]}),
("Curții de Apel București",{"entities":[(0,26,"ORG")]}),
("Curții de Apel Oradea",{"entities":[(0,22,"ORG")]}),
("REGULI din 2 decembrie 2019",{"entities":[(0,27,"LAW")]}),
("2 decembrie 2019",{"entities":[(0,16,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("2014-2021",{"entities":[(0,9,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("4 decembrie 2019",{"entities":[(0,16,"TIME")]}),
("ORDINUL nr. 144 din 2 decembrie 2019",{"entities":[(0,36,"LAW")]}),
("2 decembrie 2019",{"entities":[(0,16,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("4 decembrie 2019",{"entities":[(0,16,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Poliția de Frontieră Română",{"entities":[(0,31,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("12 ore",{"entities":[(0,6,"TIME")]}),
("24 de ore",{"entities":[(0,9,"TIME")]}),
("12 ore",{"entities":[(0,6,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("România",{"entities":[(0,8,"LOC")]}),
("noapte",{"entities":[(0,6,"TIME")]}),
("zi",{"entities":[(0,2,"TIME")]}),
("zi",{"entities":[(0,2,"TIME")]}),
("ORDIN nr. 3.184 din 18 februarie 2019",{"entities":[(0,37,"LAW")]}),
("18 februarie 2019",{"entities":[(0,17,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("25 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Legea educației naționale nr. 1 / 2011",{"entities":[(0,40,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului educației naționale nr. 4.830 / 2018",{"entities":[(0,58,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului educației, cercetării, tineretului și sportului nr. 4.799 / 2010,",{"entities":[(0,88,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 26 / 2017",{"entities":[(0,36,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Ministerului Educației Naționale",{"entities":[(0,34,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("iunie",{"entities":[(0,5,"TIME")]}),
("iulie",{"entities":[(0,5,"TIME")]}),
("Direcției generale învățământ secundar superior și educație permanentă",{"entities":[(0,79,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("iunie",{"entities":[(0,5,"TIME")]}),
("iulie",{"entities":[(0,5,"TIME")]}),
("Federația Sportului Școlar și Universitar",{"entities":[(0,44,"ORG")]}),
("Comisiei Naționale de Bacalaureat",{"entities":[(0,34,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Comisia județeană de bacalaureat a Inspectoratului Școlar Județean Prahova",{"entities":[(0,78,"ORG")]}),
("Comisia județeană de bacalaureat a Inspectoratului Școlar Județean Prahova",{"entities":[(0,78,"ORG")]}),
("Prahova",{"entities":[(0,7,"LOC")]}),
("Prahova",{"entities":[(0,7,"LOC")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului educației, cercetării, tineretului și sportului nr. 4.799 / 2010",{"entities":[(0,87,"LAW")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Ordinului ministrului educației naționale nr. 4.830 / 2018",{"entities":[(0,60,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Direcția generală învățământ secundar superior și educație permanentă",{"entities":[(0,79,"ORG")]}),
("Direcția minorități",{"entities":[(0,22,"ORG")]}),
("Direcția generală economică",{"entities":[(0,30,"ORG")]}),
("Centrul Național de Evaluare și Examinare",{"entities":[(0,43,"ORG")]}),
("Inspectoratul Școlar Județean Prahova",{"entities":[(0,39,"ORG")]}),
("Prahova",{"entities":[(0,7,"LOC")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ecaterina Andronescu",{"entities":[(0,20,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("18 februarie 2019",{"entities":[(0,17,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("16 mai",{"entities":[(0,6,"TIME")]}),
("5 iunie 2019",{"entities":[(0,12,"TIME")]}),
("16-17 mai 2019",{"entities":[(0,14,"TIME")]}),
("20-21 mai 2019",{"entities":[(0,14,"TIME")]}),
("22 mai 2019",{"entities":[(0,11,"TIME")]}),
("23-24 mai 2019",{"entities":[(0,14,"TIME")]}),
("27 mai 2019",{"entities":[(0,11,"TIME")]}),
("28 mai 2019",{"entities":[(0,11,"TIME")]}),
("29 mai 2019",{"entities":[(0,11,"TIME")]}),
("30 mai 2019",{"entities":[(0,11,"TIME")]}),
("31 mai 2019",{"entities":[(0,11,"TIME")]}),
("ora 12",{"entities":[(0,6,"TIME")]}),
("orele 12-14",{"entities":[(0,11,"TIME")]}),
("31 mai",{"entities":[(0,6,"TIME")]}),
("5 iunie 2019",{"entities":[(0,12,"TIME")]}),
("HOTĂRÂRE nr. 710 din 19 septembrie 2019",{"entities":[(0,41,"LAW")]}),
("19 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("24 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 57 / 2019",{"entities":[(0,50,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Camera Deputaților",{"entities":[(0,19,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("Silvia-Claudia Mihalcea",{"entities":[(0,23,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("19 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Ordinului ministrului finanțelor publice nr. 1.718 / 2011",{"entities":[(0,58,"LAW")]}),
("Str. Izvor nr. 2-4",{"entities":[(0,18,"LOC")]}),
("6.11.2012",{"entities":[(0,9,"TIME")]}),
("sectorul 5",{"entities":[(0,10,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Ordinul ministrului finanțelor publice nr. 1.718 / 2011",{"entities":[(0,56,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("Ordinului ministrului finanțelor publice nr. 1.718 / 2011",{"entities":[(0,58,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Str. Izvor nr. 2-4",{"entities":[(0,18,"LOC")]}),
("sectorul 5",{"entities":[(0,10,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Ordinul ministrului finanțelor publice nr. 1.718 / 2011",{"entities":[(0,56,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Camerei Deputaților",{"entities":[(0,20,"ORG")]}),
("Ordinului ministrului finanțelor publice nr. 1.718 / 2011",{"entities":[(0,58,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Str. Izvor nr. 2-4",{"entities":[(0,18,"LOC")]}),
("sectorul 5",{"entities":[(0,10,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Ordinul ministrului finanțelor publice nr. 1.718 / 2011",{"entities":[(0,56,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("HOTĂRÂRE nr. 55 din 22 octombrie 2019",{"entities":[(0,39,"LAW")]}),
("22 octombrie 2019",{"entities":[(0,17,"TIME")]}),
("Parlamentul European",{"entities":[(0,20,"ORG")]}),
("Consiliul European",{"entities":[(0,18,"ORG")]}),
("Consiliu",{"entities":[(0,8,"ORG")]}),
("Uniunii",{"entities":[(0,7,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("28 octombrie 2019",{"entities":[(0,17,"TIME")]}),
("parlamentelor naționale",{"entities":[(0,24,"ORG")]}),
("Uniunea Europeană",{"entities":[(0,18,"ORG")]}),
("Tratatului de la Lisabona",{"entities":[(0,25,"LAW")]}),
("Lisabona",{"entities":[(0,8,"LOC")]}),
("Tratatului privind Uniunea Europeană",{"entities":[(0,37,"LAW")]}),
("Uniunea Europeană",{"entities":[(0,18,"ORG")]}),
("Tratatului de instituire a Comunității Europene",{"entities":[(0,49,"LAW")]}),
("Lisabona",{"entities":[(0,8,"LOC")]}),
("13 decembrie 2007",{"entities":[(0,17,"TIME")]}),
("Legea nr. 13 / 2008",{"entities":[(0,19,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("10.10.2019",{"entities":[(0,10,"TIME")]}),
("Comisiei pentru afaceri europene",{"entities":[(0,32,"ORG")]}),
("Senatul",{"entities":[(0,7,"ORG")]}),
("Senatul",{"entities":[(0,7,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("Uniunii",{"entities":[(0,7,"ORG")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("Comisia",{"entities":[(0,7,"ORG")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("Comisie",{"entities":[(0,7,"ORG")]}),
("parlamentelor naționale",{"entities":[(0,24,"ORG")]}),
("Uniunii",{"entities":[(0,7,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Senat",{"entities":[(0,5,"ORG")]}),
("22 octombrie 2019",{"entities":[(0,17,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("SENATULUI",{"entities":[(0,9,"ORG")]}),
("TEODOR-VIOREL MELEȘCANU",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("22 octombrie 2019",{"entities":[(0,17,"TIME")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("ORDIN nr. 112 din 3 septembrie 2019",{"entities":[(0,35,"LAW")]}),
("3 septembrie 2019",{"entities":[(0,17,"TIME")]}),
("1 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("31 decembrie 2021",{"entities":[(0,17,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("10 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 114 / 2018",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 30 / 2007",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Legea nr. 15 / 2008",{"entities":[(0,19,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("1 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("31 decembrie 2021",{"entities":[(0,17,"TIME")]}),
("1 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("31 decembrie 2021",{"entities":[(0,17,"TIME")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 114 / 2018",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 114 / 2018",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Institutul Național de Statistică",{"entities":[(0,35,"ORG")]}),
("Institutul Național de Statistică",{"entities":[(0,35,"ORG")]}),
("Institutul Național de Statistică",{"entities":[(0,35,"ORG")]}),
("Ordonanței de urgență a Guvernului nr. 114 / 2018",{"entities":[(0,52,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Legii nr. 227 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Legii nr. 227 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 1 / 2016",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Mihai-Viorel Fifor",{"entities":[(0,18,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("3 septembrie 2019",{"entities":[(0,17,"TIME")]}),
("AMENDAMENT din 19 martie 2019",{"entities":[(0,29,"LAW")]}),
("19 martie 2019",{"entities":[(0,14,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Banca de Dezvoltare a Consiliului Europei",{"entities":[(0,41,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("15 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("Paris",{"entities":[(0,5,"LOC")]}),
("3 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Banca de Dezvoltare a Consiliului Europei",{"entities":[(0,41,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("11 iulie 2003",{"entities":[(0,13,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("26 martie 2019",{"entities":[(0,14,"TIME")]}),
("Hotărârea Guvernului nr. 148 din 19 martie 2019",{"entities":[(0,49,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("19 martie 2019",{"entities":[(0,14,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("26 martie 2019",{"entities":[(0,14,"TIME")]}),
("ROMÂNIA",{"entities":[(0,8,"LOC")]}),
("MINISTERUL FINANȚELOR PUBLICE",{"entities":[(0,30,"ORG")]}),
("15 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("Banca de Dezvoltare a Consiliului Europei",{"entities":[(0,41,"ORG")]}),
("Direcția generală pentru împrumuturi și dezvoltare socială",{"entities":[(0,63,"ORG")]}),
("2002",{"entities":[(0,4,"TIME")]}),
("Poirel",{"entities":[(0,6,"PER")]}),
("Unității de management al proiectelor pentru modernizarea rețelei școlare și universitare",{"entities":[(0,94,"ORG")]}),
("UMPMRȘU",{"entities":[(0,8,"ORG")]}),
("Ministerului Educației Naționale",{"entities":[(0,34,"ORG")]}),
("MEN",{"entities":[(0,3,"ORG")]}),
("26 octombrie",{"entities":[(0,12,"TIME")]}),
("Școala cu clasele I-VIII Bicaz-Chei",{"entities":[(0,36,"ORG")]}),
("județul Neamț",{"entities":[(0,15,"LOC")]}),
("Școala cu clasele I-VIII Dragomirești",{"entities":[(0,39,"ORG")]}),
("județul Neamț",{"entities":[(0,15,"LOC")]}),
("MEN",{"entities":[(0,3,"ORG")]}),
("UMPMRȘU",{"entities":[(0,8,"ORG")]}),
("MEN",{"entities":[(0,3,"ORG")]}),
("UMPMRȘU",{"entities":[(0,8,"ORG")]}),
("31 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("MEN",{"entities":[(0,3,"ORG")]}),
("decembrie 2018",{"entities":[(0,14,"TIME")]}),
("august 2019",{"entities":[(0,11,"TIME")]}),
("MEN",{"entities":[(0,3,"ORG")]}),
("octombrie 2003",{"entities":[(0,14,"TIME")]}),
("august 2019",{"entities":[(0,11,"TIME")]}),
("Attila György",{"entities":[(0,14,"PER")]}),
("BDCE",{"entities":[(0,4,"ORG")]}),
("Banca de Dezvoltare a Consiliului Europei",{"entities":[(0,41,"ORG")]}),
("Direcția generală pentru împrumuturi și dezvoltare socială",{"entities":[(0,63,"ORG")]}),
("Attila György",{"entities":[(0,14,"PER")]}),
("Thierry Poirel",{"entities":[(0,14,"PER")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Bulevardul Libertății nr. 16",{"entities":[(0,30,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("030167",{"entities":[(0,6,"LOC")]}),
("ROMÂNIA",{"entities":[(0,8,"LOC")]}),
("Paris",{"entities":[(0,5,"LOC")]}),
("3 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("2002",{"entities":[(0,4,"TIME")]}),
("11 iulie 2003",{"entities":[(0,13,"TIME")]}),
("György",{"entities":[(0,7,"PER")]}),
("15 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("2002",{"entities":[(0,4,"TIME")]}),
("Ministerului Educației Naționale",{"entities":[(0,34,"ORG")]}),
("BDCE",{"entities":[(0,4,"ORG")]}),
("31 august 2019",{"entities":[(0,14,"TIME")]}),
("Melanie Wieschollek-Lacroix",{"entities":[(0,27,"PER")]}),
("Departamentul de asistență operațiuni",{"entities":[(0,40,"ORG")]}),
("Thierry Poirel",{"entities":[(0,14,"PER")]}),
("Împrumuturi și dezvoltare socială",{"entities":[(0,36,"ORG")]}),
("Boni Cucu",{"entities":[(0,9,"PER")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("COMUNICAT din 27 iunie 2019",{"entities":[(0,27,"LAW")]}),
("27 iunie 2019",{"entities":[(0,13,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 83 / 2014",{"entities":[(0,50,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Înalta Curte de Casație și Justiție",{"entities":[(0,39,"ORG")]}),
("Decizia nr. 23 / 2016",{"entities":[(0,21,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 57 / 2015",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 20 / 2016",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("27.06.2019",{"entities":[(0,10,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 83 / 2014",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Legea nr. 71 / 2015",{"entities":[(0,19,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Înalta Curte de Casație și Justiție",{"entities":[(0,39,"ORG")]}),
("Decizia nr. 23 / 2016",{"entities":[(0,21,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 57 / 2015",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 20 / 2016",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("1 ianuarie 2010",{"entities":[(0,15,"TIME")]}),
("deciziei nr. 51 din 11 noiembrie 2019",{"entities":[(0,37,"LAW")]}),
("11 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("Curtea de Apel Bacău",{"entities":[(0,21,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 83 / 2014",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Legea nr. 71 / 2015",{"entities":[(0,19,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 57 / 2015",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 83 / 2014",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Legea nr. 71 / 2015",{"entities":[(0,19,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Înalta Curte de Casație și Justiție",{"entities":[(0,39,"ORG")]}),
("Decizia nr. 23 din 26 septembrie 2016",{"entities":[(0,37,"LAW")]}),
("26 septembrie 2016",{"entities":[(0,18,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("9 noiembrie 2016",{"entities":[(0,16,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 57 / 2015",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 20 / 2016",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"LOC")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 57 / 2015",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Legea nr. 250 / 2016",{"entities":[(0,20,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("1 ianuarie 2010",{"entities":[(0,15,"TIME")]}),
("HOTĂRÂRE nr. 159 din 19 martie 2019",{"entities":[(0,37,"LAW")]}),
("19 martie 2019",{"entities":[(0,14,"TIME")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("20 martie 2019",{"entities":[(0,14,"TIME")]}),
("Regulamentului (UE) nr. 1.307 / 2013",{"entities":[(0,36,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("17 decembrie 2013",{"entities":[(0,17,"TIME")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Regulamentului (CE) nr. 637 / 2008 al Consiliului",{"entities":[(0,49,"LAW")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Regulamentului (CE) nr. 73 / 2009 al Consiliului",{"entities":[(0,48,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ordonanța de urgență a Guvernului nr. 3 / 2015",{"entities":[(0,49,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2015-2020",{"entities":[(0,9,"TIME")]}),
("Legea nr. 36 / 1991",{"entities":[(0,19,"LAW")]}),
("1991",{"entities":[(0,4,"TIME")]}),
("Legea nr. 104 / 2015",{"entities":[(0,20,"LAW")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Agenția de Plăți și Intervenție pentru Agricultură",{"entities":[(0,56,"ORG")]}),
("Banca Centrală Europeană",{"entities":[(0,26,"ORG")]}),
("28 septembrie 2018",{"entities":[(0,18,"TIME")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("1 octombrie 2018",{"entities":[(0,16,"TIME")]}),
("Jurnalul Oficial al Uniunii Europene, seria C, nr. 351 din 1 octombrie 2018",{"entities":[(0,75,"LAW")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Dumitru Daniel Botănoiu",{"entities":[(0,24,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("Teodor-Viorel Meleșcanu",{"entities":[(0,24,"PER")]}),
("Alexandru-Victor Micula",{"entities":[(0,23,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("19 martie 2019",{"entities":[(0,14,"TIME")]}),
("ORDIN nr. 5.087 din 30 august 2019",{"entities":[(0,34,"LAW")]}),
("30 august 2019",{"entities":[(0,14,"TIME")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("18 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Legea educației naționale nr. 1 / 2011",{"entities":[(0,40,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 26 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Educației Naționale",{"entities":[(0,34,"ORG")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("Metodologia de organizare și desfășurare a admiterii în învățământul profesional de stat",{"entities":[(0,97,"LAW")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("Ordinul ministrului educației naționale și cercetării științifice nr. 5.068 / 2016",{"entities":[(0,88,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("București",{"entities":[(0,10,"ORG")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("Ordinul ministrului educației naționale nr. 3.556 / 2017",{"entities":[(0,58,"LAW")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("București",{"entities":[(0,10,"LOC")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("Direcția generală învățământ secundar superior și educație permanentă",{"entities":[(0,79,"ORG")]}),
("Direcția minorități",{"entities":[(0,22,"ORG")]}),
("Centrul Național de Dezvoltare a Învățământului Profesional și Tehnic",{"entities":[(0,76,"ORG")]}),
("București",{"entities":[(0,10,"ORG")]}),
("inspectoratele școlare județene",{"entities":[(0,33,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Valer-Daniel Breaz",{"entities":[(0,18,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("30 august 2019",{"entities":[(0,14,"TIME")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("HOTĂRÂRE nr. 785 din 4 noiembrie 2019",{"entities":[(0,39,"LAW")]}),
("4 noiembrie 2019",{"entities":[(0,16,"TIME")]}),
("Hotărârii Guvernului nr. 362 / 2019",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("5 noiembrie 2019",{"entities":[(0,16,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Hotărârea Guvernului nr. 362 / 2019",{"entities":[(0,37,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("5 iunie 2019",{"entities":[(0,12,"TIME")]}),
("Hotărârea Guvernului nr. 1.016 / 2011",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Ordonanța Guvernului nr. 22 / 2007",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("CPE",{"entities":[(0,3,"ORG")]}),
("CNSP",{"entities":[(0,4,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 114 / 2018",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("CPE",{"entities":[(0,3,"ORG")]}),
("CPE",{"entities":[(0,3,"ORG")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("CPE",{"entities":[(0,3,"ORG")]}),
("24 de luni",{"entities":[(0,10,"TIME")]}),
("CNSP",{"entities":[(0,4,"ORG")]}),
("27 de luni",{"entities":[(0,10,"TIME")]}),
("Hotărârea Guvernului nr. 362 / 2019",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Toni Greblă",{"entities":[(0,12,"PER")]}),
("Comisiei Naționale de Strategie și Prognoză",{"entities":[(0,46,"ORG")]}),
("Ion Ghizdeanu",{"entities":[(0,13,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("Bogdan Gheorghe Trif",{"entities":[(0,20,"PER")]}),
("Tiberius-Marius Brădățan",{"entities":[(0,27,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("4 noiembrie 2019",{"entities":[(0,16,"TIME")]}),
("3 ani",{"entities":[(0,5,"TIME")]}),
("ORDIN nr. 392 din 17 iulie 2019",{"entities":[(0,31,"LAW")]}),
("17 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Liești din județul Galați",{"entities":[(0,82,"ORG")]}),
("județul Galați",{"entities":[(0,16,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("18 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Referatul de aprobare nr. 303.287 / 2019",{"entities":[(0,40,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Direcției îmbunătățiri funciare și fond funciar",{"entities":[(0,53,"ORG")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Liești din județul Galați",{"entities":[(0,82,"ORG")]}),
("județul Galați",{"entities":[(0,16,"LOC")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Patrimoniul Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,61,"ORG")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Petre Daea",{"entities":[(0,10,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("17 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Liești din județul Galați",{"entities":[(0,82,"ORG")]}),
("județul Galați",{"entities":[(0,16,"LOC")]}),
("Ordinul ministrului finanțelor publice și al ministrului delegat pentru buget nr. 668 / 2014",{"entities":[(0,94,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Agenția Națională de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizația utilizatorilor de apă pentru irigații Liești",{"entities":[(0,60,"ORG")]}),
("municipiul Galați",{"entities":[(0,18,"LOC")]}),
("Str. Frunzei nr. 105",{"entities":[(0,20,"LOC")]}),
("cartier Siderurgiștilor Vest",{"entities":[(0,29,"LOC")]}),
("bl. 4C, sc. 3, ap. 57",{"entities":[(0,21,"LOC")]}),
("județul Galați",{"entities":[(0,16,"LOC")]}),
("Registrul național al organizațiilor de îmbunătățiri funciare cu nr. 644 / 11.06.2019",{"entities":[(0,91,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Slobozia Conachi",{"entities":[(0,16,"LOC")]}),
("județul Galați",{"entities":[(0,16,"LOC")]}),
("Slobozia Conachi",{"entities":[(0,16,"LOC")]}),
("județul Galați",{"entities":[(0,16,"LOC")]}),
("Slobozia Conachi",{"entities":[(0,16,"LOC")]}),
("județul Galați",{"entities":[(0,16,"LOC")]}),
("Slobozia Conachi",{"entities":[(0,16,"LOC")]}),
("județul Galați",{"entities":[(0,16,"LOC")]}),
("5 zile",{"entities":[(0,6,"TIME")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("ORDIN nr. 195 din 14 decembrie 2018",{"entities":[(0,35,"LAW")]}),
("14 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Societatea E-Distribuție Dobrogea - S.A.",{"entities":[(0,41,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("20 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Legea energiei electrice și a gazelor naturale nr. 123 / 2012",{"entities":[(0,62,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Metodologiei de stabilire a tarifelor pentru serviciul de distribuție a energiei electrice",{"entities":[(0,91,"LAW")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 169 / 2018",{"entities":[(0,100,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 33 / 2014",{"entities":[(0,99,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 33 / 2007",{"entities":[(0,50,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Legea nr. 160 / 2012",{"entities":[(0,20,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Societatea EDistribuție Dobrogea - S.A.",{"entities":[(0,40,"ORG")]}),
("Societatea EDistribuție Dobrogea - S.A.",{"entities":[(0,40,"ORG")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 33 / 2014",{"entities":[(0,99,"LAW")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autoritatea Națională de Reglementare în Domeniul Energiei",{"entities":[(0,61,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Societatea E-Distribuție Dobrogea - S.A.",{"entities":[(0,41,"ORG")]}),
("Societatea E-Distribuție Dobrogea - S.A.",{"entities":[(0,41,"ORG")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Ordinul președintelui Autorității Naționale de Reglementare în Domeniul Energiei nr. 111 / 2017",{"entities":[(0,100,"LAW")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Societatea E-Distribuție Dobrogea - S.A.",{"entities":[(0,41,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("15 decembrie 2017",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("1 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("Autorității Naționale de Reglementare în Domeniul Energiei",{"entities":[(0,62,"ORG")]}),
("Dumitru Chiriță",{"entities":[(0,17,"PER")]}),
("Societatea E-Distribuție Dobrogea - S.A.",{"entities":[(0,41,"ORG")]}),
("1 iulie 2019",{"entities":[(0,12,"TIME")]}),
("01-07-2019",{"entities":[(0,10,"TIME")]}),
("ORDINUL nr. 76 din 24 iunie 2019",{"entities":[(0,32,"LAW")]}),
("24 iunie 2019",{"entities":[(0,13,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("25 iunie 2019",{"entities":[(0,13,"TIME")]}),
("ORDIN nr. 941 / 4.362 / 2019",{"entities":[(0,28,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("26 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Referatul de aprobare nr. S.P. 7.914 din 21 iunie 2019",{"entities":[(0,54,"LAW")]}),
("21 iunie 2019",{"entities":[(0,13,"TIME")]}),
("Centrului de resurse umane în sănătate publică",{"entities":[(0,50,"ORG")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Avizul de principiu nr. 1.873 din 5 martie 2019",{"entities":[(0,47,"LAW")]}),
("5 martie 2019",{"entities":[(0,13,"TIME")]}),
("Colegiului Medicilor din România",{"entities":[(0,33,"ORG")]}),
("Avizul de principiu nr. 915 din 24 aprilie 2019",{"entities":[(0,47,"LAW")]}),
("24 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Colegiului Medicilor Stomatologi din România",{"entities":[(0,45,"ORG")]}),
("Avizul de principiu nr. 1.098 din 30 mai 2019",{"entities":[(0,45,"LAW")]}),
("30 mai 2019",{"entities":[(0,11,"TIME")]}),
("Colegiului Medicilor Stomatologi din România",{"entities":[(0,45,"ORG")]}),
("Ordonanța Guvernului nr. 18 / 2009",{"entities":[(0,35,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Legea nr. 103 / 2012",{"entities":[(0,20,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 144 / 2010",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Hotărârea Guvernului nr. 26 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Educației Naționale",{"entities":[(0,34,"ORG")]}),
("Ordinul",{"entities":[(0,7,"LAW")]}),
("nr. 1.141 / 1.386 / 2007",{"entities":[(0,24,"LAW")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("1 octombrie 2007",{"entities":[(0,16,"TIME")]}),
("noiembrie 2019",{"entities":[(0,14,"TIME")]}),
("noiembrie 2019",{"entities":[(0,14,"TIME")]}),
("noiembrie 2019",{"entities":[(0,14,"TIME")]}),
("Centrul pentru relații cu publicul al Regiei Autonome  Monitorul Oficial ",{"entities":[(0,74,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("șos. Panduri nr. 1",{"entities":[(0,19,"LOC")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Ministerului Educației Naționale",{"entities":[(0,34,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Sorina Pintea",{"entities":[(0,13,"PER")]}),
("Ecaterina Andronescu",{"entities":[(0,20,"PER")]}),
("Ordinul",{"entities":[(0,7,"LAW")]}),
("nr. 1.141 / 1.386 / 2007",{"entities":[(0,24,"LAW")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Ordinul ministrului sănătății publice și al ministrului educației, cercetării și tineretului nr. 1.141 / 1.386 / 2007",{"entities":[(0,125,"LAW")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Nomenclatorul specialităților medicale, medico-dentare și farmaceutice pentru rețeaua de asistență medicală",{"entities":[(0,114,"LAW")]}),
("Nomenclatorul specialităților medicale, medico-dentare și farmaceutice pentru rețeaua de asistență medicală",{"entities":[(0,114,"LAW")]}),
("Nomenclatorulspecialităților medicale, medico-dentare și farmaceutice pentru rețeaua de asistență",{"entities":[(0,103,"LAW")]}),
("ORDIN nr. 981 din 20 septembrie 2019",{"entities":[(0,36,"LAW")]}),
("20 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("Secretariatului General al Guvernului",{"entities":[(0,37,"ORG")]}),
("Secretariatului General al Guvernului",{"entities":[(0,37,"ORG")]}),
("1 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("31 decembrie 2021",{"entities":[(0,17,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("2 octombrie 2019",{"entities":[(0,16,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 114 / 2018",{"entities":[(0,51,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Adresa nr. 16 C / 2.335 din 13.09.2019",{"entities":[(0,38,"LAW")]}),
("13.09.2019",{"entities":[(0,10,"TIME")]}),
("Direcției economice și achiziții publice",{"entities":[(0,43,"ORG")]}),
("Hotărârea Guvernului nr. 21 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Secretariatului General al Guvernului",{"entities":[(0,37,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Secretariatului General al Guvernului",{"entities":[(0,37,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Secretariatului General al Guvernului",{"entities":[(0,37,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("31 decembrie 2021",{"entities":[(0,17,"TIME")]}),
("1 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("1 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("31 decembrie 2021",{"entities":[(0,17,"TIME")]}),
("Secretariatului General al Guvernului",{"entities":[(0,37,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Secretariatului General al Guvernului",{"entities":[(0,37,"ORG")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Ordonanța de urgență a Guvernului nr. 114 / 2018",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 114 / 2018",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ordonanța de urgență a Guvernului nr. 114 / 2018",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("I.N.S.",{"entities":[(0,6,"ORG")]}),
("1 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("31 decembrie 2021",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("Toni Greblă",{"entities":[(0,12,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("20 septembrie 2019",{"entities":[(0,18,"TIME")]}),
("16 iulie 2019",{"entities":[(0,13,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("31 iulie 2019",{"entities":[(0,13,"TIME")]}),
("ORDINUL nr. 1.043 din 16 iulie 2019",{"entities":[(0,35,"LAW")]}),
("16 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("31 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Regulamentul (UE) nr. 598 / 2014",{"entities":[(0,32,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Regulamentului (UE) nr. 598 / 2014",{"entities":[(0,34,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autoritatea Aeronautică Civilă Română",{"entities":[(0,41,"ORG")]}),
("AACR",{"entities":[(0,4,"ORG")]}),
("guvern",{"entities":[(0,6,"ORG")]}),
("AACR",{"entities":[(0,4,"ORG")]}),
("Chicago",{"entities":[(0,7,"LOC")]}),
("AACR",{"entities":[(0,4,"ORG")]}),
("AACR",{"entities":[(0,4,"ORG")]}),
("AACR",{"entities":[(0,4,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("24 de ore",{"entities":[(0,9,"TIME")]}),
("3 zile",{"entities":[(0,6,"TIME")]}),
("3 zile",{"entities":[(0,6,"TIME")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("HOTĂRÂRE nr. 1.042 din 28 decembrie 2018",{"entities":[(0,42,"LAW")]}),
("28 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Inspectoratul pentru Situații de Urgență  Mihail Grigore Sturza  al Județului Iași",{"entities":[(0,87,"ORG")]}),
("Județului Iași",{"entities":[(0,16,"LOC")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("7 ianuarie 2019",{"entities":[(0,15,"TIME")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Ordonanța Guvernului nr. 112 / 2000",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("Legea nr. 246 / 2001",{"entities":[(0,20,"LAW")]}),
("2001",{"entities":[(0,4,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 213 / 1998",{"entities":[(0,20,"LAW")]}),
("1998",{"entities":[(0,4,"TIME")]}),
("Guvernul României",{"entities":[(0,18,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Inspectoratul pentru Situații de Urgență  Mihail Grigore Sturza  al Județului Iași",{"entities":[(0,87,"ORG")]}),
("Județului Iași",{"entities":[(0,16,"LOC")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Inspectoratul pentru Situații de Urgență  Mihail Grigore Sturza  al Județului Iași",{"entities":[(0,87,"ORG")]}),
("Județului Iași",{"entities":[(0,16,"LOC")]}),
("Ministerul Afacerilor Interne",{"entities":[(0,29,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Carmen Daniela Dan",{"entities":[(0,18,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("28 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Inspectoratul pentru Situații de Urgență  Mihail Grigore Sturza  al județului Iași",{"entities":[(0,87,"ORG")]}),
("județului Iași",{"entities":[(0,16,"LOC")]}),
("Județul Iași",{"entities":[(0,14,"LOC")]}),
("Ministerul Afacerilor Interne",{"entities":[(0,29,"ORG")]}),
("Inspectoratul pentru Situații de Urgență  Mihail Grigore Sturza  al Județului Iași",{"entities":[(0,87,"ORG")]}),
("Județului Iași",{"entities":[(0,16,"LOC")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Inspectoratul pentru Situații de Urgență  Mihail Grigore Sturza al Județului Iași",{"entities":[(0,86,"ORG")]}),
("Județului Iași",{"entities":[(0,16,"LOC")]}),
("Județul Iași",{"entities":[(0,14,"LOC")]}),
("Ministerul Afacerilor Interne",{"entities":[(0,29,"ORG")]}),
("nspectoratul pentru Situații de Urgență  Mihail Grigore Sturza  al Județului Iași",{"entities":[(0,86,"ORG")]}),
("Județului Iași",{"entities":[(0,16,"LOC")]}),
("CIRCULARĂ nr. 26 din 10 decembrie 2019",{"entities":[(0,39,"LAW")]}),
("10 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("Decembrie 1989",{"entities":[(0,14,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("16 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("Legii nr. 312 / 2004",{"entities":[(0,20,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Băncii Naționale a României",{"entities":[(0,30,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("16 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("Banca Națională a României",{"entities":[(0,29,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Decembrie 1989",{"entities":[(0,14,"TIME")]}),
("ROMANIA",{"entities":[(0,7,"LOC")]}),
("ROMANIA",{"entities":[(0,7,"LOC")]}),
("Decembrie 1989",{"entities":[(0,14,"TIME")]}),
("ROMANIA",{"entities":[(0,7,"LOC")]}),
("României",{"entities":[(0,9,"LOC")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Decembrie 1989",{"entities":[(0,14,"TIME")]}),
("ROMANIA",{"entities":[(0,7,"LOC")]}),
("României",{"entities":[(0,9,"LOC")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Decembrie 1989",{"entities":[(0,14,"TIME")]}),
("ROMANIA",{"entities":[(0,7,"LOC")]}),
("României",{"entities":[(0,9,"LOC")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Decembrie 1989",{"entities":[(0,14,"TIME")]}),
("DECEMBRIE",{"entities":[(0,9,"TIME")]}),
("1989",{"entities":[(0,4,"TIME")]}),
("Băncii Naționale a României",{"entities":[(0,30,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Decembrie 1989",{"entities":[(0,14,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Decembrie 1989",{"entities":[(0,14,"TIME")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Cluj",{"entities":[(0,4,"LOC")]}),
("Constanța",{"entities":[(0,10,"LOC")]}),
("Dolj",{"entities":[(0,4,"LOC")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Timiș",{"entities":[(0,6,"LOC")]}),
("Băncii Naționale a României",{"entities":[(0,30,"ORG")]}),
("Decembrie 1989",{"entities":[(0,14,"TIME")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Cluj",{"entities":[(0,4,"LOC")]}),
("Constanța",{"entities":[(0,10,"LOC")]}),
("Dolj",{"entities":[(0,4,"LOC")]}),
("Iași",{"entities":[(0,5,"LOC")]}),
("Timiș",{"entities":[(0,6,"LOC")]}),
("Băncii Naționale a României",{"entities":[(0,30,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Băncii Naționale a României",{"entities":[(0,30,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Mugur Constantin Isărescu",{"entities":[(0,26,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("10 decembrie 2019",{"entities":[(0,17,"TIME")]}),
("30 de ani",{"entities":[(0,9,"TIME")]}),
("30 de ani",{"entities":[(0,9,"TIME")]}),
("30 de ani",{"entities":[(0,9,"TIME")]}),
("HOTĂRÂRE nr. 392 din 12 iunie 2019",{"entities":[(0,36,"LAW")]}),
("12 iunie 2019",{"entities":[(0,13,"TIME")]}),
("ASE București",{"entities":[(0,14,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("ASE București",{"entities":[(0,14,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Piața Romană nr. 7",{"entities":[(0,20,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("14 iunie 2019",{"entities":[(0,13,"TIME")]}),
("Legea educației naționale nr. 1 / 2011",{"entities":[(0,40,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("Legea nr. 500 / 2002",{"entities":[(0,20,"LAW")]}),
("Guvernul României",{"entities":[(0,18,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("2002",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 506 / 2013",{"entities":[(0,37,"LAW")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Academia de Studii Economice din București",{"entities":[(0,43,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Piața Romană nr. 7",{"entities":[(0,20,"LOC")]}),
("sectorul 1",{"entities":[(0,10,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("ASE București",{"entities":[(0,14,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("ASE București",{"entities":[(0,14,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Piața Romană nr. 7",{"entities":[(0,20,"LOC")]}),
("ASE București",{"entities":[(0,14,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("ASE București",{"entities":[(0,14,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Piața Romană nr. 7",{"entities":[(0,20,"LOC")]}),
("Academiei de Studii Economice din București",{"entities":[(0,44,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Ministerului Educației Naționale",{"entities":[(0,34,"ORG")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Ecaterina Andronescu",{"entities":[(0,20,"PER")]}),
("Vasile-Daniel Suciu",{"entities":[(0,19,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("12 iunie 2019",{"entities":[(0,13,"TIME")]}),
("ASE București",{"entities":[(0,14,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("ASE București",{"entities":[(0,14,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Piața Romană nr. 7",{"entities":[(0,20,"LOC")]}),
("Ministerul Educației Naționale",{"entities":[(0,32,"ORG")]}),
("Academia de Studii Economice din București",{"entities":[(0,43,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("București",{"entities":[(0,10,"LOC")]}),
("sectorul 1",{"entities":[(0,10,"LOC")]}),
("Piața Romană nr. 7",{"entities":[(0,20,"LOC")]}),
("21.01.2019",{"entities":[(0,10,"TIME")]}),
("21.01.2019",{"entities":[(0,10,"TIME")]}),
("Academiei de Studii Economice din București",{"entities":[(0,44,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("Ministerului Educației Naționale",{"entities":[(0,34,"ORG")]}),
("LEGE nr. 221 din 18 noiembrie 2019",{"entities":[(0,34,"LAW")]}),
("18 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("Legii educației naționale nr. 1 / 2011",{"entities":[(0,40,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("19 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("Parlamentul României",{"entities":[(0,21,"ORG")]}),
("Legea educației naționale nr. 1 / 2011",{"entities":[(0,40,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("10 ianuarie 2011",{"entities":[(0,16,"TIME")]}),
("Ministerul Educației și Cercetării",{"entities":[(0,37,"ORG")]}),
("Ministerul Afacerilor Interne",{"entities":[(0,29,"ORG")]}),
("Legea educației naționale nr. 1 / 2011",{"entities":[(0,40,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Ministerul Educației și Cercetării",{"entities":[(0,37,"ORG")]}),
("Legea educației naționale nr. 1 / 2011",{"entities":[(0,40,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("2020-2021",{"entities":[(0,9,"TIME")]}),
("Parlamentul României",{"entities":[(0,21,"ORG")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("României",{"entities":[(0,9,"LOC")]}),
("FLORIN IORDACHE",{"entities":[(0,15,"PER")]}),
("SENATULUI",{"entities":[(0,9,"ORG")]}),
("CAMEREI DEPUTAȚILOR",{"entities":[(0,20,"ORG")]}),
("TEODOR-VIOREL MELEȘCANU",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("18 noiembrie 2019",{"entities":[(0,17,"TIME")]}),
("României",{"entities":[(0,9,"LOC")]}),
("20 de ore pe săptămână",{"entities":[(0,26,"TIME")]}),
("25 de ore pe săptămână",{"entities":[(0,26,"TIME")]}),
("0 de ore pe săptămână",{"entities":[(0,25,"TIME")]}),
("90 de zile",{"entities":[(0,10,"TIME")]}),
("90 de zile",{"entities":[(0,10,"TIME")]}),
("ORDIN nr. 782 din 30 august 2019",{"entities":[(0,32,"LAW")]}),
("30 august 2019",{"entities":[(0,14,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("2 septembrie 2019",{"entities":[(0,17,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("29.08.2019",{"entities":[(0,10,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("30.08.2019",{"entities":[(0,10,"TIME")]}),
("Hotărârea Guvernului nr. 140 / 2018",{"entities":[(0,37,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("2018-2019",{"entities":[(0,9,"TIME")]}),
("Hotărârii Guvernului nr. 643 / 2019",{"entities":[(0,37,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Ordinului",{"entities":[(0,9,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Hotărârii Guvernului nr. 140 / 2018",{"entities":[(0,37,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("2018-2019",{"entities":[(0,9,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("nr. 980 / 610 / 2019",{"entities":[(0,20,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Hotărârii Guvernului nr. 140 / 2018",{"entities":[(0,37,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("2018-2019",{"entities":[(0,9,"TIME")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Statutul Casei Naționale de Asigurări de Sănătate",{"entities":[(0,53,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Hotărârea Guvernului nr. 972 / 2006",{"entities":[(0,37,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("26 aprilie 2018",{"entities":[(0,15,"TIME")]}),
("septembrie 2019",{"entities":[(0,15,"TIME")]}),
("1 septembrie 2019",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Vasile Ciurchea",{"entities":[(0,15,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("30 august 2019",{"entities":[(0,14,"TIME")]}),
("Ordinului președintelui Casei Naționale de Asigurări de Sănătate nr. 881 / 2018",{"entities":[(0,84,"LAW")]}),
("Referatul de aprobare al Direcției generale relații contractuale a Casei Naționale de Asigurări de Sănătate nr. DRC 693 / 29.08.2019 și al Direcției generale medic-șef nr. MS 3.006 din 30.08.2019",{"entities":[(0,204,"LAW")]}),
("Direcției generale relații contractuale a Casei Naționale de Asigurări de Sănătate",{"entities":[(0,88,"ORG")]}),
("Ordinului ministrului sănătății și al președintelui Casei Naționale de Asigurări de Sănătate nr. 397 / 836 / 2018",{"entities":[(0,123,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Ordinului ministrului sănătății și al președintelui Casei Naționale de Asigurări de Sănătate nr. 397 / 836 / 2018",{"entities":[(0,123,"LAW")]}),
("Ordinul președintelui Casei Naționale de Asigurări de Sănătate nr. 881 / 2018",{"entities":[(0,82,"LAW")]}),
("ORDIN nr. 1.559 din 4 decembrie 2018",{"entities":[(0,36,"LAW")]}),
("4 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 720 / 2008",{"entities":[(0,37,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("18 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Referatul de aprobare nr. DG 5.229 din 4.12.2018",{"entities":[(0,48,"LAW")]}),
("4.12.2018",{"entities":[(0,9,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Statutul Casei Naționale de Asigurări de Sănătate",{"entities":[(0,53,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Hotărârea Guvernului nr. 972 / 2006",{"entities":[(0,37,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 720 / 2008",{"entities":[(0,37,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Hotărârea Guvernului nr. 720 / 2008",{"entities":[(0,37,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Statutul Casei Naționale de Asigurări de Sănătate",{"entities":[(0,53,"LAW")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Hotărârea Guvernului nr. 972 / 2006",{"entities":[(0,37,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 720 / 2008",{"entities":[(0,37,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("28 februarie 2017",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("București",{"entities":[(0,10,"LOC")]}),
("șos. Panduri nr. 1",{"entities":[(0,19,"LOC")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Răzvan Teohari Vulcănescu",{"entities":[(0,27,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("4 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("Casei Naționalede Asigurări de Sănătate",{"entities":[(0,43,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ordinul președintelui Casei Naționale de Asigurări de Sănătate nr. 141 / 2017",{"entities":[(0,82,"LAW")]}),
("Ordinul ministrului sănătății publice și al președintelui Casei Naționale de Asigurări de Sănătate nr. 1.301 / 500 / 2008",{"entities":[(0,131,"LAW")]}),
("Ordinul președintelui Casei Naționale de Asigurări de Sănătate nr. 141 / 2017",{"entities":[(0,82,"LAW")]}),
("Ordinul președintelui Casei Naționalede Asigurări de Sănătate nr. 141 / 2017",{"entities":[(0,81,"LAW")]})
]

# %%
TRAIN_DATA=[("ORDIN nr. 1.615 din 19 noiembrie 2018",{"entities":[(0,37,"LAW")]}),
("19 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("Dolj",{"entities":[(0,4,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("7 decembrie 2018",{"entities":[(0,16,"TIME")]}),
("Legea cadastrului și a publicității imobiliare nr. 7 / 1996",{"entities":[(0,62,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Legea cadastrului și a publicității imobiliare nr. 7 / 1996",{"entities":[(0,62,"LAW")]}),
("1996",{"entities":[(0,4,"TIME")]}),
("Agenției Naționale de Cadastru și Publicitate Imobiliară",{"entities":[(0,60,"ORG")]}),
("Dolj",{"entities":[(0,4,"LOC")]}),
("27 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("01 februarie 2019",{"entities":[(0,17,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Agenției Naționale de Cadastru și Publicitate Imobiliară",{"entities":[(0,60,"ORG")]}),
("Radu-Codruț Ștefănescu",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("19 noiembrie 2018",{"entities":[(0,17,"TIME")]}),
("01-02-2019",{"entities":[(0,10,"TIME")]}),
("ORDIN nr. 1.519 din 19 decembrie 2018",{"entities":[(0,37,"LAW")]}),
("19 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Grădiștea - Terasă din județul Călărași,",{"entities":[(0,101,"ORG")]}),
("Călărași",{"entities":[(0,11,"LOC")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("27 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Referatul de aprobare nr. 293.908 / 2018",{"entities":[(0,40,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Călărași",{"entities":[(0,11,"LOC")]}),
("Organizației utilizatorilor de apă pentru irigații Grădiștea - Terasă din județul Călărași",{"entities":[(0,100,"ORG")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("5 zile",{"entities":[(0,6,"TIME")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("organizația utilizatorilor de apă pentru irigații",{"entities":[(0,52,"ORG")]}),
("30 de zile",{"entities":[(0,10,"TIME")]}),
("Legea îmbunătățirilor funciare nr. 138 / 2004",{"entities":[(0,49,"LAW")]}),
("2004",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Dumitru Daniel Botănoiu",{"entities":[(0,24,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("19 decembrie 2018",{"entities":[(0,17,"TIME")]}),
("Agenției Naționale de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizației utilizatorilor de apă pentru irigații Grădiștea - Terasă din județul Călărași",{"entities":[(0,100,"ORG")]}),
("Călărași",{"entities":[(0,11,"LOC")]}),
("Ordinul ministrului finanțelor publice nr. 668 / 2014",{"entities":[(0,54,"LAW")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Agenția Națională de Îmbunătățiri Funciare",{"entities":[(0,49,"ORG")]}),
("Organizația utilizatorilor de apă pentru irigații Grădiștea - Terasă",{"entities":[(0,74,"ORG")]}),
("Grădiștea",{"entities":[(0,11,"LOC")]}),
("S.C. Arfis Impex - S.R.L.",{"entities":[(0,25,"ORG")]}),
("Grădiștea",{"entities":[(0,11,"LOC")]}),
("Călărași",{"entities":[(0,11,"LOC")]}),
("Registrul național al organizațiilor de îmbunătățiri funciare cu nr. 318 din 22.11.2007",{"entities":[(0,93,"LAW")]}),
("22.11.2007",{"entities":[(0,10,"TIME")]}),
("Grădiștea",{"entities":[(0,11,"LOC")]}),
("Brăila",{"entities":[(0,7,"LOC")]}),
("Grădiștea",{"entities":[(0,11,"LOC")]}),
("Brăila",{"entities":[(0,7,"LOC")]}),
("ORDIN nr. 940 / 944 / 650 / 2019",{"entities":[(0,32,"LAW")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("10 iulie 2019",{"entities":[(0,13,"TIME")]}),
("Legea nr. 95 / 2006",{"entities":[(0,19,"LAW")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 50 / 2015",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("Autorității Naționale pentru Persoanele cu Dizabilități",{"entities":[(0,60,"ORG")]}),
("Hotărârea Guvernului nr. 12 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Muncii și Justiției Sociale",{"entities":[(0,42,"ORG")]}),
("Hotărârea Guvernului nr. 144 / 2010",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2010",{"entities":[(0,4,"TIME")]}),
("Ministerului Sănătății",{"entities":[(0,26,"ORG")]}),
("Hotărârea Guvernului nr. 972 / 2006",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("12.06.2019",{"entities":[(0,10,"TIME")]}),
("25.06.2019",{"entities":[(0,10,"TIME")]}),
("3.07.2019",{"entities":[(0,9,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("2019",{"entities":[(0,4,"TIME")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("3 aprilie 2019",{"entities":[(0,14,"TIME")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Mergeani Nicea",{"entities":[(0,14,"PER")]}),
("Sorina Pintea",{"entities":[(0,13,"PER")]}),
("Casei Naționale de Asigurări de Sănătate",{"entities":[(0,44,"ORG")]}),
("Răzvan Teohari Vulcănescu",{"entities":[(0,27,"PER")]}),
("HOTĂRÂRE nr. 26 din 25 ianuarie 2019",{"entities":[(0,38,"LAW")]}),
("25 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Direcția Generală Anticorupție",{"entities":[(0,33,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("30 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Constituția României",{"entities":[(0,22,"LAW")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Legea nr. 213 / 1998",{"entities":[(0,20,"LAW")]}),
("1998",{"entities":[(0,4,"TIME")]}),
("Legea nr. 287 / 2009",{"entities":[(0,20,"LAW")]}),
("2009",{"entities":[(0,4,"TIME")]}),
("Codul civil",{"entities":[(0,11,"LAW")]}),
("Guvernul",{"entities":[(0,8,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ministerului Apărării Naționale î",{"entities":[(0,37,"ORG")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Direcția Generală Anticorupție",{"entities":[(0,33,"ORG")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("60 de zile",{"entities":[(0,10,"TIME")]}),
("Ministerul Apărării Naționale",{"entities":[(0,32,"ORG")]}),
("Ministerul Afacerilor Interne",{"entities":[(0,29,"ORG")]}),
("Ministerul Finanțelor Publice",{"entities":[(0,30,"ORG")]}),
("Hotărârea Guvernului nr. 1.705 / 2006",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2006",{"entities":[(0,4,"TIME")]}),
("VASILICA-VIORICA DĂNCILĂ",{"entities":[(0,26,"PER")]}),
("Gabriel-Beniamin Leș",{"entities":[(0,21,"PER")]}),
("Carmen Daniela Dan",{"entities":[(0,18,"PER")]}),
("Eugen Orlando Teodorovici",{"entities":[(0,25,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("25 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ordonanța Guvernului nr. 81 / 2003",{"entities":[(0,35,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Legea nr. 493 / 2003",{"entities":[(0,20,"LAW")]}),
("2003",{"entities":[(0,4,"TIME")]}),
("Ordinului ministrului finanțelor publice nr. 1.718 / 2011",{"entities":[(0,58,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Ministerului Apărării Naționale",{"entities":[(0,34,"ORG")]}),
("Ministerului Afacerilor Interne",{"entities":[(0,31,"ORG")]}),
("Direcția Generală Anticorupție",{"entities":[(0,33,"ORG")]}),
("Ordinului ministrului finanțelor publice nr. 1.718 / 2011",{"entities":[(0,58,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("ORDIN nr. 58 din 17 ianuarie 2019",{"entities":[(0,33,"LAW")]}),
("17 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("2019-2023",{"entities":[(0,9,"TIME")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("30 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("Referatul de aprobare al Direcției generale politici agricole nr. 243.259 din 26.11.2018",{"entities":[(0,89,"LAW")]}),
("Direcției generale politici agricole",{"entities":[(0,37,"ORG")]}),
("26.11.2018",{"entities":[(0,10,"TIME")]}),
("Regulamentului (UE) nr. 1.306 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("17 decembrie 2013",{"entities":[(0,17,"TIME")]}),
("Regulamentelor (CEE) nr. 352 / 78",{"entities":[(0,33,"LAW")]}),
("(CE) nr. 165 / 94",{"entities":[(0,17,"LAW")]}),
("(CE) nr. 2.799 / 98",{"entities":[(0,19,"LAW")]}),
("(CE) nr. 814 / 2000",{"entities":[(0,19,"LAW")]}),
("(CE) nr. 1.290 / 2005",{"entities":[(0,21,"LAW")]}),
("(CE) nr. 485 / 2008",{"entities":[(0,19,"LAW")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("2000",{"entities":[(0,4,"TIME")]}),
("2005",{"entities":[(0,4,"TIME")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Regulamentului (UE) nr. 1.308 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("17 decembrie 2013",{"entities":[(0,17,"TIME")]}),
("Regulamentelor (CEE) nr. 922 / 72",{"entities":[(0,33,"LAW")]}),
("(CEE) nr. 234 / 79",{"entities":[(0,18,"LAW")]}),
("(CE) nr. 1.037 / 2001",{"entities":[(0,21,"LAW")]}),
("(CE) nr. 1.234 / 2007",{"entities":[(0,21,"LAW")]}),
("2001",{"entities":[(0,4,"TIME")]}),
("2007",{"entities":[(0,4,"TIME")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Regulamentului (UE) 2016 / 1.149",{"entities":[(0,32,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Regulamentului (UE) nr. 1.308 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Regulamentului (CE) nr. 555 / 2008",{"entities":[(0,34,"LAW")]}),
("2008",{"entities":[(0,4,"TIME")]}),
("Comisiei",{"entities":[(0,8,"ORG")]}),
("Regulamentului (UE) 2016 / 1.150",{"entities":[(0,32,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Regulamentului (UE) nr. 1.308 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Regulamentului de punere în aplicare (UE) 2017 / 256",{"entities":[(0,53,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Regulamentului de punere în aplicare (UE) 2016 / 1.150",{"entities":[(0,55,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Regulamentului (UE) nr. 1.308 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Ordonanței de urgență a Guvernului nr. 49 / 2015",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2015",{"entities":[(0,4,"TIME")]}),
("2014-2020",{"entities":[(0,9,"TIME")]}),
("Legea nr. 56 / 2016",{"entities":[(0,19,"LAW")]}),
("2016",{"entities":[(0,4,"TIME")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("Ordonanței de urgență a Guvernului nr. 66 / 2011",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("Legea nr. 142 / 2012",{"entities":[(0,20,"LAW")]}),
("2012",{"entities":[(0,4,"TIME")]}),
("Ordonanței de urgență a Guvernului nr. 98 / 2017",{"entities":[(0,51,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Legea nr. 186 / 2018",{"entities":[(0,20,"LAW")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Hotărârea Guvernului nr. 868 / 2018",{"entities":[(0,37,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2018",{"entities":[(0,4,"TIME")]}),
("Uniunii Europene",{"entities":[(0,16,"ORG")]}),
("2019-2023",{"entities":[(0,9,"TIME")]}),
("Hotărârea Guvernului nr. 30 / 2017",{"entities":[(0,36,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2017",{"entities":[(0,4,"TIME")]}),
("Ministerului Agriculturii și Dezvoltării Rurale",{"entities":[(0,49,"ORG")]}),
("Hotărârea Guvernului nr. 1.186 / 2014",{"entities":[(0,39,"LAW")]}),
("Guvernului",{"entities":[(0,10,"ORG")]}),
("2014",{"entities":[(0,4,"TIME")]}),
("Autorității pentru Administrarea Sistemului Național Antigrindină și de Creștere a Precipitațiilor",{"entities":[(0,105,"ORG")]}),
("2019-2023",{"entities":[(0,9,"TIME")]}),
("Regulamentului (UE) nr. 1.308 / 2013",{"entities":[(0,36,"LAW")]}),
("UE",{"entities":[(0,2,"ORG")]}),
("2013",{"entities":[(0,4,"TIME")]}),
("Parlamentului European",{"entities":[(0,22,"ORG")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("17 decembrie 2013",{"entities":[(0,17,"TIME")]}),
("Regulamentelor (CEE) nr. 922 / 72",{"entities":[(0,33,"LAW")]}),
("(CEE) nr. 234 / 79",{"entities":[(0,18,"LAW")]}),
("(CE) nr. 1.037 / 2001",{"entities":[(0,21,"LAW")]}),
("(CE) nr. 1.234 / 2007",{"entities":[(0,21,"LAW")]}),
("Consiliului",{"entities":[(0,11,"ORG")]}),
("Monitorul Oficial",{"entities":[(0,17,"ORG")]}),
("României",{"entities":[(0,9,"LOC")]}),
("Petre Daea",{"entities":[(0,10,"PER")]}),
("București",{"entities":[(0,10,"LOC")]}),
("17 ianuarie 2019",{"entities":[(0,16,"TIME")]}),
("2019-2023",{"entities":[(0,9,"TIME")]}),
("HOTĂRÂRE nr. 431 din 23 martie 2019",{"entities":[(0,37,"LAW")]}),
("23 martie 2019",{"entities":[(0,14,"TIME")]}),
("Hotărârea Consiliului Uniunii Naționale a Barourilor din România nr. 64 / 2011",{"entities":[(0,82,"LAW")]}),
("2011",{"entities":[(0,4,"TIME")]}),
("România",{"entities":[(0,8,"LOC")]}),
("Consiliului Uniunii Naționale a Barourilor din România",{"entities":[(0,56,"ORG")]}),
("MONITORUL OFICIAL",{"entities":[(0,17,"ORG")]}),
("12 aprilie 2019",{"entities":[(0,15,"TIME")]}),
("Legea nr. 51 / 1995",{"entities":[(0,19,"LAW")]}),
("1995",{"entities":[(0,4,"TIME")]}),
("Hotărârea Congresului Avocaților nr. 5 din 20-21 aprilie 2018",{"entities":[(0,64,"LAW")]}),
("20-21 aprilie 2018",{"entities":[(0,18,"TIME")]}),
("Consiliul Uniunii Naționale a Barourilor din România",{"entities":[(0,54,"ORG")]}),
("România",{"entities":[(0,8,"LOC")]}),
("U.N.B.R.",{"entities":[(0,8,"ORG")]})
]

# %% [markdown]
# # INITIALIZE

# %%
pip install -U spacy

# %%
import spacy.cli
spacy.cli.download("ro_core_news_lg")
# Out:
# ✘ No compatible model found for 'ro_core_news_lg' (spaCy v2.2.4).
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # TRAIN

# %%
import spacy
import random
from spacy.util import minibatch, compounding
from pathlib import Path

# Define output folder to save new model
model_dir = 'C:\\Users\\Carol Luca\\Desktop\\Code\\RACAI'

# Train new NER model
def train_new_NER(model=None, output_dir=model_dir, n_iter=10):
#    """Load the model, set up the pipeline and train the entity recognizer."""
    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("ro")  # create blank Language class
        print("Created blank 'ro' model")

    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")

    # add labels
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):  # only train NER
        # reset and initialize the weights randomly – but only if we're
        # training a new model
        if model is None:
            nlp.begin_training()
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            # batch up the examples using spaCy's minibatch
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,  # dropout - make it harder to memorise data
                    losses=losses,
                )
            print("Losses", losses)

    # test the trained model
    for text, _ in TRAIN_DATA:
        doc = nlp(text)
        print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
        print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

    # save model to output directory
    if output_dir is not None:
        output_dir = Path(output_dir)
        if not output_dir.exists():
            output_dir.mkdir()
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

        # test the saved model
        print("Loading from", output_dir)
        nlp2 = spacy.load(output_dir)
        for text, _ in TRAIN_DATA:
            doc = nlp2(text)
            print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
            print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])
            
# Finally train the model by calling above function
train_new_NER()
# Out:
# Created blank 'ro' model
# Losses {'ner': 361.2340251971036}
# Losses {'ner': 282.5368289985927}
# Losses {'ner': 132.09671874706473}
# Losses {'ner': 71.90414184734391}
# Losses {'ner': 45.801998963489844}
# Losses {'ner': 42.05407456330928}
# Losses {'ner': 34.03276917842336}
# Losses {'ner': 38.44775628955284}
# Losses {'ner': 20.525517979738623}
# Losses {'ner': 22.600647998242977}
# Entities [('Guvernului', 'ORG')]
# Tokens [('Guvernului', 'ORG', 3)]
# Entities [('Guvernului', 'ORG')]
# Tokens [('Guvernului', 'ORG', 3)]
# Entities [('2008', 'TIME')]
# Tokens [('2008', 'TIME', 3)]
# Entities [('Guvernului', 'ORG')]
# Tokens [('Guvernului', 'ORG', 3)]
# Entities [('Guvernul', 'ORG')]
# Tokens [('Guvernul', 'ORG', 3)]
# Entities [('2012', 'TIME')]
# Tokens [('2012', 'TIME', 3)]
# Entities [('Dolj', 'LOC')]
# Tokens [('Dolj', 'LOC', 3)]
# Entities [('2016', 'TIME')]
# Tokens [('2016', 'TIME', 3)]
# Entities [('Ordonanței de urgență a Guvernului nr.', 'PER'), ('66 / 2011', 'TIME')]
# ...

# %% [markdown]
# # TEST

# %%
# Use new trained saved model
import spacy
# model_dir = 'C:\\Users\\Carol Luca\\AppData\\Local\\Programs\\Python\\Python39\\Lib\\site-packages\\ro_core_news_lg\\ro_core_news_lg-3.0.0\\ner\\model'
print("Loading trained model from:", model_dir)
nlp2 = spacy.load(model_dir)
doc2 = nlp2('Guvern')

for token in doc2:
    print(token, token.ent_type_)
# Out:
# Loading trained model from: C:\Users\Carol Luca\Desktop\Code\RACAI
# Guvern ORG

# %%
# calculate p-r-f values for every entity type
import spacy
from spacy.gold import GoldParse
from spacy.scorer import Scorer

def evaluate(nlp, examples, ent='TIME'):
    scorer = Scorer()
    for input_, annot in examples:
        text_entities = []
        for entity in annot.get('entities'):
            if ent in entity:
                text_entities.append(entity)
        doc_gold_text = nlp.make_doc(input_)
        gold = GoldParse(doc_gold_text, entities=text_entities)
        pred_value = nlp(input_)
        scorer.score(pred_value, gold)
    return scorer.scores


results = evaluate(nlp2, TRAIN_DATA2)
print(results)
# Out:
# {'uas': 0.0, 'las': 0.0, 'las_per_type': {'': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'ents_p': 26.72858617131063, 'ents_r': 97.98234552332913, 'ents_f': 42.00000000000001, 'ents_per_type': {'LAW': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'TIME': {'p': 80.85327783558793, 'r': 97.98234552332913, 'f': 88.59749144811859}, 'LOC': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'ORG': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'PER': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'tags_acc': 0.0, 'token_acc': 100.0, 'textcat_score': 0.0, 'textcats_per_cat': {}}

# %% [markdown]
# # UPDATE

# %%
model_dir = 'C:\\Users\\Carol Luca\\Desktop\\Code\\RACAI'

## Update existing spacy model and store into a folder
def update_model(model='ro_core_news_lg', output_dir=model_dir, n_iter=100):
#    """Load the model, set up the pipeline and train the entity recognizer."""
    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")

    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")

    # add labels
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):  # only train NER
        # reset and initialize the weights randomly – but only if we're
        # training a new model
        if model is None:
            nlp.begin_training()
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            # batch up the examples using spaCy's minibatch
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,  # dropout - make it harder to memorise data
                    losses=losses,
                )
            print("Losses", losses)

    # test the trained model
    for text, _ in TRAIN_DATA:
        doc = nlp(text)
        print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
        print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

    # save model to output directory
    if output_dir is not None:
        output_dir = Path(output_dir)
        if not output_dir.exists():
            output_dir.mkdir()
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

# Finally train the model by calling above function        
update_model()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-10fcf0f30fd7> in <module>()
#      62
#      63 # Finally train the model by calling above function
# ---> 64 update_model()
#
# <ipython-input-5-10fcf0f30fd7> in update_model(model, output_dir, n_iter)
#       5 #    """Load the model, set up the pipeline and train the entity recognizer."""
#       6     if model is not None:
# ----> 7         nlp = spacy.load(model)  # load existing spaCy model
#       8         print("Loaded model '%s'" % model)
#       9     else:
#
# /usr/local/lib/python3.7/dist-packages/spacy/__init__.py in load(name, **overrides)
#      28     if depr_path not in (True, False, None):
#      29         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 30     return util.load_model(name, **overrides)
#      31
#      32
#
# ...

# %%
# Use updated saved model
print("Loading updated model from:", updated_model_dir)
nlp2 = spacy.load(model_dir)
doc2 = nlp2('Who is Shaka Khan?')

for token in doc2:
    print(token, token.ent_type_)
